# %% [markdown]
# # D3 Graphing
#
# -------------------------------------------------
#
# The raw code for this Jupyter notebook is by default hidden for easier reading. The main focus of this particular page of the notebook is on the graphs and their interpretation. To toggle on/off the raw code, click below:

# %%
# Setup Code toggle button
from IPython.core.display import HTML  

HTML(''' 
<center><h3>
<a href="javascript:code_toggle()">Talk is cheap, show me the code.</a>
</center></h3>
<script>
    var code_show=true; //true -> hide code at first

    function code_toggle() {
        $('div.prompt').hide(); // always hide prompt

        if (code_show){
            $('div.input').hide();
        } else {
            $('div.input').show();
        }
        code_show = !code_show
    }
    $( document ).ready(code_toggle);
</script>
''')
# Out:
#
# <center><h3>
# <a href="javascript:code_toggle()">Talk is cheap, show me the code.</a>
# </center></h3>
# <script>
#     var code_show=true; //true -> hide code at first
#
#     function code_toggle() {
#         $('div.prompt').hide(); // always hide prompt
#
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
# </script>

# %%
# Setup notebook theme
from jupyterthemes import get_themes
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme(get_themes()[1])
# Out:
# <style> @font-face {
#  font-family: 'Droid Sans Mono';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Droid Sans Mono'), url('fonts/droid-sans-mono.woff') format('woff');
# }
# @font-face {
#  font-family: 'Exo_2';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Exo_2'), url('fonts/exo-II-regular.ttf') format('truetype');
# }
# @font-face {
#  font-family: 'Fira Code';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Fira Code'), url('fonts/firacode.otf') format('opentype');
# }
# @font-face {
#  font-family: 'Lora';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Lora'), url('fonts/Lora-Regular.ttf') format('truetype');
# }
# div#notebook {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #303030;
# }
# body,
# div.body {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  color: #303030;
#  background-color: #ffffff;
#  background: #ffffff;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #ffffff;
#  background: #ffffff;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: "Exo_2", sans-serif;
#  color: #303030;
# }
# a:hover,
# a:focus {
#  color: #2f2f2f;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #2f2f2f;
#  background-color: #ffffff;
# }
# div#cluster_list_header.row.list_header,
# div#running .row.list_header {
#  font-size: 14pt;
#  color: #303030;
#  background: #eeeeee;
#  background-color: #eeeeee;
#  border-bottom: 2px solid rgba(180,180,180,.30);
# }
# div#cluster_list > div.list_item.row,
# div#cluster_list > div.list_item.row:hover {
#  background: #f7f7f7;
#  background-color: #f7f7f7;
# }
# div#clusters.tab-pane.active {
#  font-size: 12.0pt;
#  padding: 4px 0 4px 0;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #303030;
#  padding: 8px 8px;
#  background: #eeeeee;
#  background-color: #eeeeee;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #303030;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #303030;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #f7f7f7;
#  background-color: #f7f7f7;
#  padding: 2px;
#  border-bottom: 2px solid rgba(180,180,180,.30);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #f7f7f7;
#  background-color: #f7f7f7;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# div.running_list_info.toolbar_info {
#  font-size: 12.0pt;
#  padding: 4px 0 4px 0;
#  height: inherit;
#  line-height: inherit;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #ff7823;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# #project_name {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  margin-bottom: -20px;
#  text-align: -webkit-auto;
#  vertical-align: text-top;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: "Exo_2", sans-serif;
#  font-size: 12.0pt;
# }
# .toolbar_info {
#  font-family: "Exo_2", sans-serif;
#  font-size: 12.0pt;
#  color: #303030;
#  text-shadow: none;
#  border: none;
#  height: inherit;
#  line-height: inherit;
# }
# .list_container {
#  font-size: 12.0pt;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(180,180,180,.14);
#  font-size: 12.0pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-left: 0px;
# }
# .list_header > div input,
# .list_item > div input {
#  top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 12.0pt;
# }
# .item_icon {
#  font-size: 12.0pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: auto;
#  width: 20%;
#  margin: 6px 0 0;
#  margin-top: 1px;
# }
# #button-select-all {
#  height: auto;
#  font-size: 12.0pt;
#  padding: 5px;
#  min-width: 65px;
#  z-index: 0;
# }
# button#tree-selector-btn {
#  height: auto;
#  font-size: 12.0pt;
#  padding: 5px;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 5px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin: 6px 0 0;
#  margin-top: 1px;
#  line-height: normal;
# }
# .list_container a {
#  font-size: 17px;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #2f2f2f;
# }
# div.list_item:hover {
#  background-color: #fafafa;
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
# }
# ul#tabs a {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  font-weight: normal;
#  font-style: normal;
#  border-color: transparent;
#  text-shadow: none !important;
# }
# .nav-tabs {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  font-weight: normal;
#  font-style: normal;
#  background: #ffffff;
#  text-shadow: none !important;
#  border-color: transparent;
#  border-bottom-color: rgba(180,180,180,.30);
# }
# .nav-tabs > li > a:hover {
#  color: #2f2f2f;
#  background-color: rgba(180,180,180,.14);
# }
# .nav-tabs > li > a:active,
# .nav-tabs > li > a:focus,
# .nav-tabs > li.active > a,
# .nav-tabs > li.active > a:focus,
# .nav-tabs > li.active > a:hover,
# .nav-tabs > li.active > a,
# .nav-tabs > li.active > a:hover,
# .nav-tabs > li.active > a:focus {
#  color: #1c1c1c;
#  background-color: #eeeeee;
#  border: 1px solid transparent;
#  border-bottom-color: transparent;
#  cursor: default;
# }
# .nav > li > a:hover,
# .nav > li > a:focus {
#  text-decoration: none;
#  background-color: rgba(180,180,180,.14);
# }
# .nav > li.disabled > a,
# .nav > li.disabled > a:hover {
#  color: #aaaaaa;
# }
# div#notebook {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  padding-top: 4px;
# }
# .notebook_app {
#  background-color: #ffffff;
# }
# #notebook-container {
#  padding: 13px;
#  background-color: #ffffff;
#  min-height: 0px;
#  box-shadow: none;
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
# }
# div#ipython-main-app.container {
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
#  margin-right: auto;
#  margin-left: auto;
# }
# .container {
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
# }
# .notebook_app #header {
#  box-shadow: none !important;
#  background-color: #ffffff;
#  border-bottom: 2px solid rgba(180,180,180,.14);
# }
# #header {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  box-shadow: none;
#  background-color: #ffffff;
# }
# #header .header-bar {
#  background: #ffffff;
#  background-color: #ffffff;
# }
# body > #header .header-bar {
#  width: 100%;
#  background: #ffffff;
# }
# #menubar {
#  background-color: #ffffff;
# }
# #menubar .navbar,
# .navbar-default {
#  background-color: #ffffff;
#  margin-bottom: 0px;
# }
# .navbar {
#  border: none;
# }
# .navbar-default {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  background-color: #ffffff;
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
#  padding-bottom: 0px;
# }
# .navbar-default .navbar-nav > li > a {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  color: #303030;
#  display: block;
#  line-height: 1.5em;
#  padding-top: 8px;
#  padding-bottom: 6px;
# }
# .navbar-default .navbar-nav > li > a:hover,
# .navbar-default .navbar-nav > li > a:focus {
#  color: #2f2f2f;
#  background-color: rgba(180,180,180,.14);
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
# }
# .navbar-default .navbar-nav > .open > a,
# .navbar-default .navbar-nav > .open > a:hover,
# .navbar-default .navbar-nav > .open > a:focus {
#  color: #1c1c1c;
#  background-color: rgba(180,180,180,.14);
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
# }
# .edit_mode .modal_indicator:before {
#  font-size: 13pt;
#  color: #2c85f7;
#  content: "\f040";
# }
# .item_icon {
#  color: #126dce;
# }
# .item_buttons .kernel-name {
#  font-size: 13pt;
#  color: #126dce;
#  line-height: 22px;
# }
# .running_notebook_icon:before {
#  color: #009e07 !important;
# }
# .item_buttons .running-indicator {
#  padding-top: 2px;
#  color: #009e07;
# }
# #modal_indicator {
#  float: right !importan

# %% [markdown]
# &nbsp;
#
# ## Get the Data
#
# The data was stored in `graph_data.json`.
#
# &nbsp;

# %%
import json

data_file = '../data/graph_data.json'
with open(data_file, 'r') as infile:
    data = json.load(infile)

data
# Out:
# {'links': [{'source': 'ryacca', 'target': 'shebin'},
#   {'source': 'shebin', 'target': 'ryacca'},
#   {'source': 'ryacca', 'target': 'phonedude_mln'},
#   {'source': 'shebin', 'target': 'phonedude_mln'},
#   {'source': 'ycpdan', 'target': 'CassPF'},
#   {'source': 'ycpdan', 'target': 'internetarchive'},
#   {'source': 'ycpdan', 'target': 'ruebot'},
#   {'source': 'ycpdan', 'target': 'DataG'},
#   {'source': 'ycpdan', 'target': 'liblaura'},
#   {'source': 'ycpdan', 'target': 'taylor_amy'},
#   {'source': 'ycpdan', 'target': 'ianmilligan1'},
#   {'source': 'ycpdan', 'target': 'dchud'},
#   {'source': 'ycpdan', 'target': 'WebSciDL'},
#   {'source': 'ycpdan', 'target': 'AVArchivist'},
#   {'source': 'AVArchivist', 'target': 'ycpdan'},
#   {'source': 'ycpdan', 'target': 'smalljones'},
#   {'source': 'ycpdan', 'target': 'abrennr'},
#   {'source': 'ycpdan', 'target': 'archiveitorg'},
#   {'source': 'ycpdan', 'target': 'phonedude_mln'},
#   {'source': 'BexAnnalisa', 'target': 'internetarchive'},
#   {'source': 'BexAnnalisa', 'target': 'SPARC_NA'},
#   {'source': 'BexAnnalisa', 'target': 'palewire'},
#   {'source': 'BexAnnalisa', 'target': 'edsu'},
#   {'source': 'BexAnnalisa', 'target': 'NDSA2'},
#   {'source': 'BexAnnalisa', 'target': 'phonedude_mln'},
#   {'source': 'degruyter_lib', 'target': 'HBee2015'},
#   {'source': 'HBee2015', 'target': 'degruyter_lib'},
#   {'source': 'degruyter_lib', 'target': 'internetarchive'},
#   {'source': 'degruyter_lib', 'target': 'CLIRDLF'},
#   {'source': 'degruyter_lib', 'target': 'EmeraldLibrary'},
#   {'source': 'degruyter_lib', 'target': 'StanfordLibs'},
#   {'source': 'degruyter_lib', 'target': 'digitalfay'},
#   {'source': 'degruyter_lib', 'target': 'lorcanD'},
#   {'source': 'degruyter_lib', 'target': 'WebSciDL'},
#   {'source': 'degruyter_lib', 'target': 'mjgiarlo'},
#   {'source': 'degruyter_lib', 'target': 'NDSA2'},
#   {'source': 'degruyter_lib', 'target': 'mart1nkle1n'},
#   {'source': 'degruyter_lib', 'target': 'sshreeves'},
#   {'source': 'degruyter_lib', 'target': 'phonedude_mln'},
#   {'source': 'mixnode', 'target': 'arjenpdevries'},
#   {'source': 'mixnode', 'target': 'TueHLarsen'},
#   {'source': 'mixnode', 'target': 'DanKerchner'},
#   {'source': 'mixnode', 'target': 'keesone'},
#   {'source': 'mixnode', 'target': 'euanc'},
#   {'source': 'euanc', 'target': 'mixnode'},
#   {'source': 'mixnode', 'target': 'daniel_rehn'},
#   {'source': 'mixnode', 'target': 'skhartmann'},
#   {'source': 'mixnode', 'target': 'kingswebit'},
#   {'source': 'mixnode', 'target': 'maikhanhlam'},
#   {'source': 'mixnode', 'target': 'NielsBr'},
#   {'source': 'mixnode', 'target': 'williamjturkel'},
#   {'source': 'mixnode', 'target': 'Moha_Magdy'},
#   {'source': 'mixnode', 'target': 'IgorBrigadir'},
#   {'source': 'mixnode', 'target': 'WebART12'},
#   {'source': 'mixnode', 'target': 'digitalfay'},
#   {'source': 'mixnode', 'target': 'mgallinger'},
#   {'source': 'mixnode', 'target': 'jesseajohnston'},
#   {'source': 'mixnode', 'target': 'webrecorder_io'},
#   {'source': 'mixnode', 'target': 'GrahamSeaman'},
#   {'source': 'mixnode', 'target': 'this_phillips'},
#   {'source': 'mixnode', 'target': 'DLWebBnF'},
#   {'source': 'mixnode', 'target': 'DLWeb_Seb'},
#   {'source': 'mixnode', 'target': 'acocciolo'},
#   {'source': 'mixnode', 'target': 'jefferson_bail'},
#   {'source': 'mixnode', 'target': 'jasonmarkwebber'},
#   {'source': 'mixnode', 'target': 'ianmilligan1'},
#   {'source': 'mixnode', 'target': 'erinengle'},
#   {'source': 'mixnode', 'target': 'AnnaPerricci'},
#   {'source': 'mixnode', 'target': 'beatles__beatle'},
#   {'source': 'mixnode', 'target': 'PeterOnymos'},
#   {'source': 'mixnode', 'target': 'Philipp_Mayr'},
#   {'source': 'mixnode', 'target': 'kvanmalssen'},
#   {'source': 'mixnode', 'target': 'TessaFallon'},
#   {'source': 'mixnode', 'target': 'kristsi'},
#   {'source': 'mixnode', 'target': 'athurman'},
#   {'source': 'athurman', 'target': 'mixnode'},
#   {'source': 'mixnode', 'target': 'pj_webster'},
#   {'source': 'mixnode', 'target': 'archiveis'},
#   {'source': 'mixnode', 'target': 'UKWebArchive'},
#   {'source': 'mixnode', 'target': 'inadlweb'},
#   {'source': 'mixnode', 'target': 'kzakza'},
#   {'source': 'mixnode', 'target': 'WSUNDSA'},
#   {'source': 'mixnode', 'target': 'rdhyee'},
#   {'source': 'mixnode', 'target': 'trevormunoz'},
#   {'source': 'mixnode', 'target': 'WebArchivists'},
#   {'source': 'mixnode', 'target': 'bfluzin'},
#   {'source': 'mixnode', 'target': 'AlephArchives'},
#   {'source': 'mixnode', 'target': 'WPKefi'},
#   {'source': 'mixnode', 'target': 'gmj2053'},
#   {'source': 'mixnode', 'target': 'atomotic'},
#   {'source': 'mixnode', 'target': 'fmccown'},
#   {'source': 'mixnode', 'target': 'lljohnston'},
#   {'source': 'mixnode', 'target': 'mart1nkle1n'},
#   {'source': 'mixnode', 'target': 'aalsum'},
#   {'source': 'mixnode', 'target': 'sorgentelinda'},
#   {'source': 'mixnode', 'target': 'sspranay'},
#   {'source': 'mixnode', 'target': 'Galsondor'},
#   {'source': 'mixnode', 'target': 'shawnmjones'},
#   {'source': 'mixnode', 'target': 'kboughida'},
#   {'source': 'mixnode', 'target': 'nullhandle'},
#   {'source': 'mixnode', 'target': 'phonedude_mln'},
#   {'source': 'no_identd', 'target': 'Hindawi'},
#   {'source': 'no_identd', 'target': 'arjenpdevries'},
#   {'source': 'no_identd', 'target': 'internetarchive'},
#   {'source': 'no_identd', 'target': 'tjowens'},
#   {'source': 'no_identd', 'target': 'lestextesR'},
#   {'source': 'no_identd', 'target': 'JonesWCaleb'},
#   {'source': 'no_identd', 'target': 'AllThingsGraph'},
#   {'source': 'no_identd', 'target': 'jteevan'},
#   {'source': 'no_identd', 'target': 'MaxKemman'},
#   {'source': 'no_identd', 'target': 'phonedude_mln'},
#   {'source': 'JCrueger', 'target': 'BL_Labs'},
#   {'source': 'JCrueger', 'target': 'pampel'},
#   {'source': 'JCrueger', 'target': 'internetarchive'},
#   {'source': 'JCrueger', 'target': 'PolitAdArchive'},
#   {'source': 'JCrueger', 'target': 'nwatzman'},
#   {'source': 'JCrueger', 'target': 'CLIRDLF'},
#   {'source': 'JCrueger', 'target': 'NicolaJBingham'},
#   {'source': 'JCrueger', 'target': 'j_w_baker'},
#   {'source': 'JCrueger', 'target': 'archivportal'},
#   {'source': 'archivportal', 'target': 'JCrueger'},
#   {'source': 'JCrueger', 'target': 'tjowens'},
#   {'source': 'JCrueger', 'target': 'silvertje'},
#   {'source': 'JCrueger', 'target': 'NielsBr'},
#   {'source': 'JCrueger', 'target': 'HistWebArchives'},
#   {'source': 'HistWebArchives', 'target': 'JCrueger'},
#   {'source': 'JCrueger', 'target': 'prwheatley'},
#   {'source': 'JCrueger', 'target': 'webrecorder_io'},
#   {'source': 'JCrueger', 'target': 'forschungsdaten'},
#   {'source': 'JCrueger', 'target': 'DLWebBnF'},
#   {'source': 'JCrueger', 'target': 'jasonmarkwebber'},
#   {'source': 'JCrueger', 'target': 'ianmilligan1'},
#   {'source': 'ianmilligan1', 'target': 'JCrueger'},
#   {'source': 'JCrueger', 'target': 'WebSciDL'},
#   {'source': 'JCrueger', 'target': 'pj_webster'},
#   {'source': 'pj_webster', 'target': 'JCrueger'},
#   {'source': 'JCrueger', 'target': 'UKWebArchive'},
#   {'source': 'JCrueger', 'target': 'edsu'},
#   {'source': 'JCrueger', 'target': 'NetPreserve'},
#   {'source': 'JCrueger', 'target': 'NDSA2'},
#   {'source': 'JCrueger', 'target': 'hhockx'},
#   {'source': 'JCrueger', 'target': 'AT_Webarchive'},
#   {'source': 'AT_Webarchive', 'target': 'JCrueger'},
#   {'source': 'sorgentelinda', 'target': 'JCrueger'},
#   {'source': 'JCrueger', 'target': 'agrotke'},
#   {'source': 'JCrueger', 'target': 'sshreeves'},
#   {'source': 'JCrueger', 'target': 'nullhandle'},
#   {'source': 'JCrueger', 'target': 'phonedude_mln'},
#   {'source': 'lissertations', 'target': 'CassPF'},
#   {'source': 'lissertations', 'target': 'pmyoung84'},
#   {'source': 'pmyoung84', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'BL_Labs'},
#   {'source': 'BL_Labs', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'HBee2015'},
#   {'source': 'HBee2015', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'permacc'},
#   {'source': 'lissertations', 'target': 'Mementoweb'},
#   {'source': 'lissertations', 'target': 'internetarchive'},
#   {'source': 'lissertations', 'target': 'bitarchivist'},
#   {'source': 'bitarchivist', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'DavidUnderdown9'},
#   {'source': 'DavidUnderdown9', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'CLIRDLF'},
#   {'source': 'lissertations', 'target': 'NicolaJBingham'},
#   {'source': 'lissertations', 'target': '1n9r1d'},
#   {'source': '1n9r1d', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'oaisdujour'},
#   {'source': 'oaisdujour', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'NetLab_dk'},
#   {'source': 'lissertations', 'target': 'EmeraldLibrary'},
#   {'source': 'lissertations', 'target': 'digiarchiveteam'},
#   {'source': 'digiarchiveteam', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'andrewjbtw'},
#   {'source': 'lissertations', 'target': 'documentnow'},
#   {'source': 'lissertations', 'target': 'j_w_baker'},
#   {'source': 'lissertations', 'target': 'tjowens'},
#   {'source': 'lissertations', 'target': 'keesone'},
#   {'source': 'keesone', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'euanc'},
#   {'source': 'samalanmeister', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'shirapeltzman'},
#   {'source': 'shirapeltzman', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'daniel_rehn'},
#   {'source': 'daniel_rehn', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'wwwtxt'},
#   {'source': 'wwwtxt', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'TaksNz'},
#   {'source': 'TaksNz', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'NielsBr'},
#   {'source': 'NielsBr', 'target': 'lissertations'},
#   {'source': 'Arkivum', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'palewire'},
#   {'source': 'palewire', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'downey_cara'},
#   {'source': 'downey_cara', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'Reloaded2Boot'},
#   {'source': 'lissertations', 'target': 'williamjturkel'},
#   {'source': 'williamjturkel', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'bertramlyons'},
#   {'source': 'bertramlyons', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'HistWebArchives'},
#   {'source': 'lissertations', 'target': 'bindonlane'},
#   {'source': 'bindonlane', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'archivelle'},
#   {'source': 'lissertations', 'target': 'webrecorder_io'},
#   {'source': 'lissertations', 'target': 'DLWebBnF'},
#   {'source': 'lissertations', 'target': 'jefferson_bail'},
#   {'source': 'lissertations', 'target': 'jasonmarkwebber'},
#   {'source': 'jasonmarkwebber', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'unstablearchive'},
#   {'source': 'lissertations', 'target': 'WebSciDL'},
#   {'source': 'lissertations', 'target': 'NKrabben'},
#   {'source': 'lissertations', 'target': 'UKWebArchive'},
#   {'source': 'lissertations', 'target': 'inadlweb'},
#   {'source': 'lissertations', 'target': 'archivetype'},
#   {'source': 'lissertations', 'target': 'hryanski'},
#   {'source': 'hryanski', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'WebArchivists'},
#   {'source': 'lissertations', 'target': 'atomotic'},
#   {'source': 'atomotic', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'edsu'},
#   {'source': 'edsu', 'target': 'lissertations'},
#   {'source': 'lissertations', 'target': 'NetPreserve'},
#   {'source': 'lissertations', 'target': 'NDSA2'},
#   {'source': 'lissertations', 'target': 'archiveitorg'},
#   {'source': 'lissertations', 'target': 'anjacks0n'},
#   {'source': 'lissertations', 'target': 'agrotke'},
#   {'source': 'lissertations', 'target': 'nullhandle'},
#   {'source': 'lissertations', 'target': 'blefurgy'},
#   {'source': 'lissertations', 'target': 'azaroth42'},
#   {'source': 'lissertations', 'target': 'phonedude_mln'},
#   {'source': 'grantatVA', 'target': 'phonedude_mln'},
#   {'source': 'mmicros1', 'target': 'phonedude_mln'},
#   {'source': '74paddycakes', 'target': 'phonedude_mln'},
#   {'source': 'digitopia_nl', 'target': 'internetarchive'},
#   {'source': 'digitopia_nl', 'target': 'dbpedia'},
#   {'source': 'digitopia_nl', 'target': 'keesone'},
#   {'source': 'keesone', 'target': 'digitopia_nl'},
#   {'source': 'digitopia_nl', 'target': 'prwheatley'},
#   {'source': 'digitopia_nl', 'target': 'saschel'},
#   {'source': 'digitopia_nl', 'target': 'atomotic'},
#   {'source': 'atomotic', 'target': 'digitopia_nl'},
#   {'source': 'digitopia_nl', 'target': 'machawk1'},
#   {'source': 'digitopia_nl', 'target': 'NetPreserve'},
#   {'source': 'digitopia_nl', 'target': 'hhockx'},
#   {'source': 'digitopia_nl', 'target': 'anjacks0n'},
#   {'source': 'anjacks0n', 'target': 'digitopia_nl'},
#   {'source': 'digitopia_nl', 'target': 'mart1nkle1n'},
#   {'source': 'digitopia_nl', 'target': 'azaroth42'},
#   {'source': 'digitopia_nl', 'target': 'hvdsomp'},
#   {'source': 'digitopia_nl', 'target': 'phonedude_mln'},
#   {'source': 'ARLIS_NY', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'mre1920'},
#   {'source': 'PruittAL', 'target': 'bitarchivist'},
#   {'source': 'bitarchivist', 'target': 'PruittAL'},
#   {'source': 'oaisdujour', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'lookouthoney'},
#   {'source': 'GardnerCampbell', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'landlibrarian'},
#   {'source': 'landlibrarian', 'target': 'PruittAL'},
#   {'source': 'samalanmeister', 'target': 'PruittAL'},
#   {'source': 'shirapeltzman', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'bertramlyons'},
#   {'source': 'bertramlyons', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'save4use'},
#   {'source': 'save4use', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'archivelle'},
#   {'source': 'PruittAL', 'target': 'BergisJules'},
#   {'source': 'PruittAL', 'target': 'K4arkive'},
#   {'source': 'K4arkive', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'bethcron'},
#   {'source': 'bethcron', 'target': 'PruittAL'},
#   {'source': 'PruittAL', 'target': 'archivesmatter'},
#   {'source': 'PruittAL', 'target': 'archivetype'},
#   {'source': 'PruittAL', 'target': 'archiveitorg'},
#   {'source': 'PruittAL', 'target': 'diglib'},
#   {'source': 'PruittAL', 'target': 'phonedude_mln'},
#   {'source': 'brendaberkelaar', 'target': 'foucaultwelles'},
#   {'source': 'erikaris', 'target': 'brendaberkelaar'},
#   {'source': 'brendaberkelaar', 'target': 'docmattweber'},
#   {'source': 'docmattweber', 'target': 'brendaberkelaar'},
#   {'source': 'brendaberkelaar', 'target': 'LulwahMA'},
#   {'source': 'LulwahMA', 'target': 'brendaberkelaar'},
#   {'source': 'brendaberkelaar', 'target': 'phonedude_mln'},
#   {'source': 'pmyoung84', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'kzwa'},
#   {'source': 'RJIJDNA', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'internetarchive'},
#   {'source': 'CassPF', 'target': 'bitarchivist'},
#   {'source': 'bitarchivist', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'DavidUnderdown9'},
#   {'source': 'DavidUnderdown9', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'CLIRDLF'},
#   {'source': 'CassPF', 'target': '1n9r1d'},
#   {'source': '1n9r1d', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'oaisdujour'},
#   {'source': 'oaisdujour', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'lookouthoney'},
#   {'source': 'lookouthoney', 'target': 'CassPF'},
#   {'source': 'digiarchiveteam', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'landlibrarian'},
#   {'source': 'CassPF', 'target': 'andrewjbtw'},
#   {'source': 'andrewjbtw', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'documentnow'},
#   {'source': 'documentnow', 'target': 'CassPF'},
#   {'source': 'archivportal', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'tjowens'},
#   {'source': 'tjowens', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'euanc'},
#   {'source': 'euanc', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'samalanmeister'},
#   {'source': 'samalanmeister', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'shirapeltzman'},
#   {'source': 'shirapeltzman', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'daniel_rehn'},
#   {'source': 'daniel_rehn', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'wwwtxt'},
#   {'source': 'wwwtxt', 'target': 'CassPF'},
#   {'source': 'kingswebit', 'target': 'CassPF'},
#   {'source': 'TaksNz', 'target': 'CassPF'},
#   {'source': 'Arkivum', 'target': 'CassPF'},
#   {'source': 'downey_cara', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'bertramlyons'},
#   {'source': 'bertramlyons', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'prwheatley'},
#   {'source': 'prwheatley', 'target': 'CassPF'},
#   {'source': 'jessogden', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'StanfordLibs'},
#   {'source': 'CassPF', 'target': 'digitalfay'},
#   {'source': 'digitalfay', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'todrobbins'},
#   {'source': 'todrobbins', 'target': 'CassPF'},
#   {'source': 'mgallinger', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'archivelle'},
#   {'source': 'CassPF', 'target': 'BergisJules'},
#   {'source': 'BergisJules', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'webrecorder_io'},
#   {'source': 'CassPF', 'target': 'jefferson_bail'},
#   {'source': 'jefferson_bail', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'ianmilligan1'},
#   {'source': 'ianmilligan1', 'target': 'CassPF'},
#   {'source': 'PeterOnymos', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'jschneider'},
#   {'source': 'CassPF', 'target': 'kvanmalssen'},
#   {'source': 'kvanmalssen', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'NKrabben'},
#   {'source': 'NKrabben', 'target': 'CassPF'},
#   {'source': 'UKWebArchive', 'target': 'CassPF'},
#   {'source': 'bethcron', 'target': 'CassPF'},
#   {'source': 'kzakza', 'target': 'CassPF'},
#   {'source': 'archivesmatter', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'archivetype'},
#   {'source': 'archivetype', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'trevormunoz'},
#   {'source': 'trevormunoz', 'target': 'CassPF'},
#   {'source': 'OpenResearchExe', 'target': 'CassPF'},
#   {'source': 'atomotic', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'edsu'},
#   {'source': 'edsu', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'NDSA2'},
#   {'source': 'CassPF', 'target': 'archiveitorg'},
#   {'source': 'archiveitorg', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'anjacks0n'},
#   {'source': 'anjacks0n', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'lljohnston'},
#   {'source': 'lljohnston', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'agrotke'},
#   {'source': 'shawnmjones', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'nullhandle'},
#   {'source': 'CassPF', 'target': 'blefurgy'},
#   {'source': 'blefurgy', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'hvdsomp'},
#   {'source': 'hvdsomp', 'target': 'CassPF'},
#   {'source': 'CassPF', 'target': 'phonedude_mln'},
#   {'source': 'OKMotovlog', 'target': 'phonedude_mln'},
#   {'source': 'mekonkol', 'target': 'pvanhaitsma'},
#   {'source': 'pvanhaitsma', 'target': 'mekonkol'},
#   {'source': 'mekonkol', 'target': 'internetarchive'},
#   {'source': 'mekonkol', 'target': 'CLIRDLF'},
#   {'source': 'mekonkol', 'target': 'j_w_baker'},
#   {'source': 'mekonkol', 'target': 'williamjturkel'},
#   {'source': 'williamjturkel', 'target': 'mekonkol'},
#   {'source': 'mekonkol', 'target': 'WebSciDL'},
#   {'source': 'mekonkol', 'target': 'phonedude_mln'},
#   {'source': 'phonedude_mln', 'target': 'mekonkol'},
#   {'source': 'Stesker3D', 'target': 'BL_Labs'},
#   {'source': 'Stesker3D', 'target': 'CLIRDLF'},
#   {'source': 'Stesker3D', 'target': 'SPARC_NA'},
#   {'source': 'Stesker3D', 'target': 'daniel_rehn'},
#   {'source': 'Stesker3D', 'target': 'kevingashley'},
#   {'source': 'Stesker3D', 'target': 'mjgiarlo'},
#   {'source': 'Stesker3D', 'target': 'NDSA2'},
#   {'source': 'Stesker3D', 'target': 'azaroth42'},
#   {'source': 'Stesker3D', 'target': 'hvdsomp'},
#   {'source': 'Stesker3D', 'target': 'phonedude_mln'},
#   {'source': 'HussamHallak1', 'target': 'jefferson_bail'},
#   {'source': 'HussamHallak1', 'target': 'weiglemc'},
#   {'source': 'HussamHallak1', 'target': 'phonedude_mln'}],
#  'nodes': [{'default_profile_image': False,
#    'id': 59860290,
#    'name': 'Ryan Yacyshyn',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/796184339687931905/--nSmCcF_normal.jpg',
#    'screen_name': 'ryacca'},
#   {'default_profile_image': False,
#    'id': 9421452,
#    'name': 'Shebin',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/608858046731673600/nwm8reMF_normal.jpg',
#    'screen_name': 'shebin'},
#   {'default_profile_image': False,
#    'id': 265517884,
#    'name': 'Daniel',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2839957630/6742066915c916b9448b513314bab9f2_normal.jpeg',
#    'screen_name': 'ycpdan'},
#   {'default_profile_image': False,
#    'id': 3979114762,
#    'name': 'Rebecca Dallavalle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822219089049452546/yjbE3trx_normal.jpg',
#    'screen_name': 'BexAnnalisa'},
#   {'default_profile_image': False,
#    'id': 756135755190198273,
#    'name': 'De Gruyter Libraries',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/756137216254980096/2Bj3kfSP_normal.jpg',
#    'screen_name': 'degruyter_lib'},
#   {'default_profile_image': False,
#    'id': 3158073120,
#    'name': 'Mixnode',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/804823765964029952/3h6CTIMX_normal.jpg',
#    'screen_name': 'mixnode'},
#   {'default_profile_image': False,
#    'id': 481260788,
#    'name': '@no identd',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/758644713201238016/HX7JPMfX_normal.jpg',
#    'screen_name': 'no_identd'},
#   {'default_profile_image': False,
#    'id': 1429810189,
#    'name': 'Jens Crueger',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/765152493877751808/FolWjb2D_normal.jpg',
#    'screen_name': 'JCrueger'},
#   {'default_profile_image': False,
#    'id': 4008474733,
#    'name': 'Alissa M.',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/738710122512285697/Zkf_pHcT_normal.jpg',
#    'screen_name': 'lissertations'},
#   {'default_profile_image': True,
#    'id': 821042028800802816,
#    'name': 'Grant Atkins',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'grantatVA'},
#   {'default_profile_image': True,
#    'id': 827268804359053313,
#    'name': 'MichaelMicros',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#    'screen_name': 'mmicros1'},
#   {'default_profile_image': False,
#    'id': 789293970677456896,
#    'name': 'Patrick Cox',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/789296122233847808/fmHjla7Q_normal.jpg',
#    'screen_name': '74paddycakes'},
#   {'default_profile_image': False,
#    'id': 799272100599046145,
#    'name': 'René Voorburg',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799931370516647940/K0TkfBPi_normal.jpg',
#    'screen_name': 'digitopia_nl'},
#   {'default_profile_image': False,
#    'id': 203096228,
#    'name': 'Adrienne Pruitt',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/717376345865478144/HcRuXWSC_normal.jpg',
#    'screen_name': 'PruittAL'},
#   {'default_profile_image': False,
#    'id': 81650379,
#    'name': 'Brenda Berkelaar',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/665158896525312000/O9o0G7Wd_normal.jpg',
#    'screen_name': 'brendaberkelaar'},
#   {'default_profile_image': False,
#    'id': 47899646,
#    'name': 'Cassie Findlay',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/503770380146716672/-ZqPskdq_normal.jpeg',
#    'screen_name': 'CassPF'},
#   {'default_profile_image': False,
#    'id': 899863316,
#    'name': 'OK Rider/Motorcu',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/747873690654769154/TaKbM-_u_normal.jpg',
#    'screen_name': 'OKMotovlog'},
#   {'default_profile_image': False,
#    'id': 30802131,
#    'name': 'Margaret Konkol',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/612467215862927360/zgZk9y9K_normal.jpg',
#    'screen_name': 'mekonkol'},
#   {'default_profile_image': False,
#    'id': 761396027446398976,
#    'name': 'Stesker3D',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/777132624846348288/lYylOWVP_normal.jpg',
#    'screen_name': 'Stesker3D'},
#   {'default_profile_image': False,
#    'id': 825218681252765696,
#    'name': 'Hussam Hallak',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/828693167197204481/LezWYLYV_normal.jpg',
#    'screen_name': 'HussamHallak1'},
#   {'default_profile_image': True,
#    'id': 20255236,
#    'name': 'Carol Castle',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#    'screen_name': 'carolc16'},
#   {'default_profile_image': False,
#    'id': 825049390998024192,
#    'name': 'Printuu',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/825421424718389249/vd2bmbni_normal.jpg',
#    'screen_name': 'printuu'},
#   {'default_profile_image': False,
#    'id': 733536950963994624,
#    'name': 'Data Science',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/828865856021155840/fordY9bZ_normal.jpg',
#    'screen_name': 'dtscnc'},
#   {'default_profile_image': False,
#    'id': 737852660183932928,
#    'name': 'Tunazzina Islam',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/744945448964751360/BYD6pYSi_normal.jpg',
#    'screen_name': 'Tunaz_Islam'},
#   {'default_profile_image': False,
#    'id': 9630082,
#    'name': 'Meredith Artley',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/421350001134948352/oWP39w4L_normal.jpeg',
#    'screen_name': 'MeredithA'},
#   {'default_profile_image': False,
#    'id': 258599525,
#    'name': 'Meghan Hoyer',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/643884814119104512/9Pew3YSv_normal.jpg',
#    'screen_name': 'MeghanHoyer'},
#   {'default_profile_image': False,
#    'id': 3122708646,
#    'name': 'Anton',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/756657049606512644/geQDpH31_normal.jpg',
#    'screen_name': 'AntonJRasmussen'},
#   {'default_profile_image': False,
#    'id': 1634706151,
#    'name': 'Bram Luyten',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/740611666887462912/cAztghSl_normal.jpg',
#    'screen_name': 'LuytenBram'},
#   {'default_profile_image': False,
#    'id': 399805362,
#    'name': 'Mohd Kamal',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/588399194395652096/tS649QUm_normal.jpg',
#    'screen_name': 'MohdKamal6'},
#   {'default_profile_image': False,
#    'id': 269424738,
#    'name': 'Paul Young',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/698409181653684224/ZTJHMEvy_normal.jpg',
#    'screen_name': 'pmyoung84'},
#   {'default_profile_image': True,
#    'id': 810540893396733953,
#    'name': 'Karki',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#    'screen_name': 'Karki693'},
#   {'default_profile_image': False,
#    'id': 1119502988,
#    'name': 'British Library Labs',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/458627032255963136/LrfmDsum_normal.png',
#    'screen_name': 'BL_Labs'},
#   {'default_profile_image': False,
#    'id': 783440136,
#    'name': 'Pôle #AI au #Québec',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/807696707089813504/VA-7_NUn_normal.jpg',
#    'screen_name': 'IntelligenceTV'},
#   {'default_profile_image': True,
#    'id': 808893873766432768,
#    'name': 'Maheedhar Gunnam',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#    'screen_name': 'maheedhargunnam'},
#   {'default_profile_image': False,
#    'id': 58880930,
#    'name': 'Nattiya Kanhabua',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3727028789/2c275bed6ef62c97f7071c82877d4445_normal.png',
#    'screen_name': 'nattiyak'},
#   {'default_profile_image': False,
#    'id': 47985362,
#    'name': 'Marcin Wilkowski',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/461050206742540288/0WEsLaiN_normal.jpeg',
#    'screen_name': 'marcinwilkowski'},
#   {'default_profile_image': False,
#    'id': 801186507931455488,
#    'name': 'James Dill',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/801704756116762625/XySpif1b_normal.jpg',
#    'screen_name': 'minornotez'},
#   {'default_profile_image': False,
#    'id': 19203768,
#    'name': 'Kate Starbird',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822692976304340993/jMQjWo1h_normal.jpg',
#    'screen_name': 'katestarbird'},
#   {'default_profile_image': False,
#    'id': 2190533245,
#    'name': 'ACM SIGIR',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/776809490909896704/OVX1OArZ_normal.jpg',
#    'screen_name': 'ACMSIGIR'},
#   {'default_profile_image': False,
#    'id': 89504686,
#    'name': 'Ralf Claussnitzer',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/747697618122334208/ZvNFvCNv_normal.jpg',
#    'screen_name': 'claussni'},
#   {'default_profile_image': False,
#    'id': 192964243,
#    'name': 'NJ Computer Group',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/643449617858719744/bZNSoGOy_normal.png',
#    'screen_name': 'njcomputergroup'},
#   {'default_profile_image': False,
#    'id': 113647306,
#    'name': 'ARLIS/NA New York',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1192193415/twitter_normal.jpg',
#    'screen_name': 'ARLIS_NY'},
#   {'default_profile_image': False,
#    'id': 2936496598,
#    'name': 'Sumitra Duncan',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/553623454000222208/IZUaqZve_normal.jpeg',
#    'screen_name': 'artlibrariannyc'},
#   {'default_profile_image': False,
#    'id': 3281181511,
#    'name': 'WikiCite',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/739367095532703744/3hhZSGOn_normal.jpg',
#    'screen_name': 'Wikicite'},
#   {'default_profile_image': False,
#    'id': 258032124,
#    'name': 'ussr.io',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/768894884543463424/FGaQuAar_normal.jpg',
#    'screen_name': 'ChiefScientist'},
#   {'default_profile_image': False,
#    'id': 3447506422,
#    'name': 'ODU Peninsula Center',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/796765515972833280/KTxASFB8_normal.jpg',
#    'screen_name': 'ODUPeninsulaCtr'},
#   {'default_profile_image': False,
#    'id': 16564030,
#    'name': 'Lance Mercereau',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/560111601043243009/xfgOG4by_normal.jpeg',
#    'screen_name': 'lmercereau'},
#   {'default_profile_image': False,
#    'id': 30047063,
#    'name': 'Hindawi',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/771636621741395968/oBKO_LC1_normal.jpg',
#    'screen_name': 'Hindawi'},
#   {'default_profile_image': False,
#    'id': 1695487818,
#    'name': 'Esperanza Salazar',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/712373189884530688/i-6-HCic_normal.jpg',
#    'screen_name': 'es_land'},
#   {'default_profile_image': False,
#    'id': 2973715954,
#    'name': 'Kenneth Diedrich',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/554395111883161600/07kSP8Z0_normal.jpeg',
#    'screen_name': 'KennyDiedrich'},
#   {'default_profile_image': False,
#    'id': 774187456191160320,
#    'name': 'Joffrey Decourselle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/774188246679056384/DU3oHLC1_normal.jpg',
#    'screen_name': 'JDecourselle'},
#   {'default_profile_image': False,
#    'id': 3849211272,
#    'name': 'Riker',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/673899174002167808/XAsJadQe_normal.jpg',
#    'screen_name': 'RikerHampton'},
#   {'default_profile_image': False,
#    'id': 57750231,
#    'name': 'ODUAlumniAssociation',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/531839614709796864/ArNBPO_0_normal.jpeg',
#    'screen_name': 'ODUAlumni'},
#   {'default_profile_image': False,
#    'id': 19258241,
#    'name': 'Heinz Pampel',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000761485499/2e08c904773ac15d05a7c43b1e702800_normal.jpeg',
#    'screen_name': 'pampel'},
#   {'default_profile_image': False,
#    'id': 146209930,
#    'name': 'Katrina Stierholz',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000039320464/3c6afd264d037cfb5316a3059053eb03_normal.jpeg',
#    'screen_name': 'stierholz'},
#   {'default_profile_image': False,
#    'id': 4481168962,
#    'name': 'School of Salamanca',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/827135250534907906/AWab8rL1_normal.jpg',
#    'screen_name': 'salamancaschool'},
#   {'default_profile_image': False,
#    'id': 16868154,
#    'name': 'Arjen P. de Vries',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2875589913/b361e1c80a05f80c887c97619cc1b6fe_normal.jpeg',
#    'screen_name': 'arjenpdevries'},
#   {'default_profile_image': False,
#    'id': 3354096993,
#    'name': 'Helena Byrne',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/687005921659215872/30iKj1xn_normal.jpg',
#    'screen_name': 'HBee2015'},
#   {'default_profile_image': False,
#    'id': 193063049,
#    'name': 'Ben Vershbow',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1251454027/doppelganger_normal.jpg',
#    'screen_name': 'subsublibrary'},
#   {'default_profile_image': False,
#    'id': 468735081,
#    'name': 'Julie Rogers',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/839248056751165440/E-YyhQD8_normal.jpg',
#    'screen_name': 'jubrogers'},
#   {'default_profile_image': False,
#    'id': 138161380,
#    'name': 'Matías Butelman',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/751793992883380224/4Czuql6q_normal.jpg',
#    'screen_name': 'mbutel'},
#   {'default_profile_image': False,
#    'id': 17271698,
#    'name': 'andrea davis',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/794631184001052672/XVRqXj_m_normal.jpg',
#    'screen_name': 'detailmatters'},
#   {'default_profile_image': False,
#    'id': 3365719153,
#    'name': 'UCLA Acquisitions',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/637406673070493696/3WGMAjWH_normal.png',
#    'screen_name': 'acquire_UCLA'},
#   {'default_profile_image': False,
#    'id': 74541831,
#    'name': 'Kate Zwaard',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/765274696547962880/IHHBZH3P_normal.jpg',
#    'screen_name': 'kzwa'},
#   {'default_profile_image': False,
#    'id': 5894872,
#    'name': 'Harald Sack',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799905753087803392/5CUa32Or_normal.jpg',
#    'screen_name': 'lysander07'},
#   {'default_profile_image': False,
#    'id': 13645402,
#    'name': 'ChrisAldrich',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000823803940/e500bc8cba99417f27ac3392e7503aa0_normal.jpeg',
#    'screen_name': 'ChrisAldrich'},
#   {'default_profile_image': False,
#    'id': 729223119030751232,
#    'name': 'www.sheershasamachar',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/739958609904205824/YXMRGiUw_normal.jpg',
#    'screen_name': 'sheershasamach1'},
#   {'default_profile_image': False,
#    'id': 739900844531974144,
#    'name': 'JCDL2017',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/783699658459770880/6ToHFp2t_normal.jpg',
#    'screen_name': 'jcdl2017'},
#   {'default_profile_image': False,
#    'id': 1668275245,
#    'name': 'perma.cc',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/744949592618209280/QlVQwm-X_normal.jpg',
#    'screen_name': 'permacc'},
#   {'default_profile_image': True,
#    'id': 781886520978444288,
#    'name': 'Kh Talha',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#    'screen_name': 'KhTalha6'},
#   {'default_profile_image': False,
#    'id': 570294703,
#    'name': 'Jan Strack',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/746824862249914369/rQMEiGO2_normal.jpg',
#    'screen_name': 'Jack_Stran'},
#   {'default_profile_image': False,
#    'id': 24713262,
#    'name': 'Angela Woodall',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000475083959/a8e8d6a253012ace417926b216c273cc_normal.jpeg',
#    'screen_name': 'AngelaWoodall'},
#   {'default_profile_image': True,
#    'id': 66188615,
#    'name': 'Bruno Leonard',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_3_normal.png',
#    'screen_name': 'bruno_leonard_'},
#   {'default_profile_image': False,
#    'id': 774263152544452608,
#    'name': 'Data Cartel',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/774274418390528000/kgf38QtT_normal.jpg',
#    'screen_name': 'datacartel1'},
#   {'default_profile_image': False,
#    'id': 2806160786,
#    'name': 'JDNA',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/638719030350622720/YqAoN5AH_normal.jpg',
#    'screen_name': 'RJIJDNA'},
#   {'default_profile_image': False,
#    'id': 1551367058,
#    'name': 'Fredericik Begbeder',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000710311151/9cbd8006a5899a6118dc8368f790d274_normal.jpeg',
#    'screen_name': 'FredericikB'},
#   {'default_profile_image': False,
#    'id': 2852131203,
#    'name': 'Pamela VanHaitsma',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/839647802384842755/jAKXKwDo_normal.jpg',
#    'screen_name': 'pvanhaitsma'},
#   {'default_profile_image': False,
#    'id': 4508117621,
#    'name': 'Robin Ruggaber',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/807640801790595072/yYBSC7oJ_normal.jpg',
#    'screen_name': 'robin_ruggaber'},
#   {'default_profile_image': False,
#    'id': 237086573,
#    'name': 'Charlene Finley',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/775198667783282688/LjZDMnds_normal.jpg',
#    'screen_name': 'Cee_Finley'},
#   {'default_profile_image': False,
#    'id': 161598558,
#    'name': 'Roceys',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2359431553/i7mwta6u4h90lmcvfr3y_normal.jpeg',
#    'screen_name': 'woilgoo'},
#   {'default_profile_image': False,
#    'id': 11164692,
#    'name': 'Seamus Lawless',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1662654879/SciCom_Profile_normal.jpg',
#    'screen_name': 'seamuslawless'},
#   {'default_profile_image': False,
#    'id': 737342173079736321,
#    'name': 'Kevin Levrone',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/737368290222346241/YjvgWlJt_normal.jpg',
#    'screen_name': 'KevinLevrone3'},
#   {'default_profile_image': False,
#    'id': 4738176435,
#    'name': 'MementoWeb',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/770345340344082433/RdLol102_normal.jpg',
#    'screen_name': 'Mementoweb'},
#   {'default_profile_image': False,
#    'id': 7377862,
#    'name': 'Jason Casden',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285825913/casden_hood_garden_normal.jpg',
#    'screen_name': 'cazzerson'},
#   {'default_profile_image': False,
#    'id': 833373624,
#    'name': 'Brooke F Welles',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2626756569/Brooke-Headshot-Small_normal.jpg',
#    'screen_name': 'foucaultwelles'},
#   {'default_profile_image': False,
#    'id': 1393107912,
#    'name': 'Micah Zeller',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/816351501916454914/SAEtdwW__normal.jpg',
#    'screen_name': 'mdzellerCDAL'},
#   {'default_profile_image': False,
#    'id': 48592998,
#    'name': 'Robin M. Katz',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/590689039776411648/U97Pn_IQ_normal.jpg',
#    'screen_name': 'robinmkatz'},
#   {'default_profile_image': False,
#    'id': 3321913552,
#    'name': 'Christopher Chyr',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/610957360320765952/a5OOcBKO_normal.jpg',
#    'screen_name': 'mrchyr'},
#   {'default_profile_image': False,
#    'id': 134569763,
#    'name': 'Meredith Evans',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/481629489051361281/V8hh32Pv_normal.jpeg',
#    'screen_name': 'mre1920'},
#   {'default_profile_image': False,
#    'id': 3412095995,
#    'name': 'Saad Ehsan',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/630638865850703872/-zYYKKCo_normal.png',
#    'screen_name': 'saadaitomation'},
#   {'default_profile_image': False,
#    'id': 729563714475700224,
#    'name': 'Jessica Smith',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/729568662642823170/6BVoSMfV_normal.jpg',
#    'screen_name': 'jessicasmith541'},
#   {'default_profile_image': False,
#    'id': 267189586,
#    'name': 'bakare oluwabunmi',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/775045842411655168/VK1D_sfL_normal.jpg',
#    'screen_name': 'bumdots4eva'},
#   {'default_profile_image': False,
#    'id': 605923,
#    'name': 'Shawn Walker',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1256136674/shawn_normal.jpg',
#    'screen_name': 'walkeroh'},
#   {'default_profile_image': True,
#    'id': 3189940844,
#    'name': '.',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#    'screen_name': 'CRajaharsha'},
#   {'default_profile_image': False,
#    'id': 14338221,
#    'name': 'Laura J. Smart',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/723280931235069952/kcVyyYGC_normal.jpg',
#    'screen_name': 'infod1va'},
#   {'default_profile_image': False,
#    'id': 33736942,
#    'name': 'Liz Neely',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/764516080828186628/LHlRWO-b_normal.jpg',
#    'screen_name': 'lili_czarina'},
#   {'default_profile_image': False,
#    'id': 745643383188758528,
#    'name': 'Oorlogsbronnen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/748180024793120768/biWSprjf_normal.jpg',
#    'screen_name': 'Oorlogsbronnen'},
#   {'default_profile_image': False,
#    'id': 745385398134661120,
#    'name': 'Annika Hinze',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/745386763586240512/HPTiHaEi_normal.jpg',
#    'screen_name': 'annika_hinze'},
#   {'default_profile_image': False,
#    'id': 18957805,
#    'name': 'Internet Archive',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/717127559134056448/BYGRuZmj_normal.jpg',
#    'screen_name': 'internetarchive'},
#   {'default_profile_image': False,
#    'id': 708690890974470145,
#    'name': 'Mridul Sen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/774509666080612352/bSts9phn_normal.jpg',
#    'screen_name': 'mridulish'},
#   {'default_profile_image': False,
#    'id': 118078818,
#    'name': 'Abd El-Fatah',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/757461371973885952/ynT2yK3a_normal.jpg',
#    'screen_name': 'Dr_Abomohra'},
#   {'default_profile_image': False,
#    'id': 220983330,
#    'name': 'Helge Holzmann',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000254082716/b168fa08a6f03ea6520759a73f2c5dbe_normal.jpeg',
#    'screen_name': 'helgeho'},
#   {'default_profile_image': False,
#    'id': 9308852,
#    'name': 'Îďȫʞ Šĕčủrıtƴ',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/573613604089393152/Y3URTCCY_normal.jpeg',
#    'screen_name': 'idokius'},
#   {'default_profile_image': False,
#    'id': 744784018919432194,
#    'name': 'Zhaohuan Wang',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832587358977482752/22n7eDNz_normal.jpg',
#    'screen_name': 'zhaohuan_wang'},
#   {'default_profile_image': False,
#    'id': 4497126976,
#    'name': 'PoliticalTVAdArchive',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/677600361742393344/2SU5t8q7_normal.png',
#    'screen_name': 'PolitAdArchive'},
#   {'default_profile_image': False,
#    'id': 7591252,
#    'name': 'Nancy Watzman',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/460868826301607936/UT81WeaF_normal.png',
#    'screen_name': 'nwatzman'},
#   {'default_profile_image': False,
#    'id': 24257870,
#    'name': 'John Howard',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2375478079/145tl6jf9vlcosn2v0wb_normal.jpeg',
#    'screen_name': 'John_B_Howard'},
#   {'default_profile_image': False,
#    'id': 753571748860293120,
#    'name': 'Context Scout',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/753585746729111552/lc4VNXJ1_normal.jpg',
#    'screen_name': 'CScoutTech'},
#   {'default_profile_image': False,
#    'id': 2416303724,
#    'name': 'Ava Forte Vitali',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/449622377203122176/5nauM2wG_normal.jpeg',
#    'screen_name': 'avadigs'},
#   {'default_profile_image': False,
#    'id': 45411436,
#    'name': 'Malte',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/549269273315528705/RouLc2qh_normal.png',
#    'screen_name': 'XYOU'},
#   {'default_profile_image': False,
#    'id': 25187570,
#    'name': 'theo van veen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000591868880/b4218d0c3ed1f355b8630efe803414ff_normal.jpeg',
#    'screen_name': 'theovv'},
#   {'default_profile_image': False,
#    'id': 24092133,
#    'name': 'nick ruest',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/842569942373347328/UlrQ4KCD_normal.jpg',
#    'screen_name': 'ruebot'},
#   {'default_profile_image': False,
#    'id': 83170793,
#    'name': 'Michael Stevenson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3708722324/db88b85e00e6489d531ef98f355f14c5_normal.jpeg',
#    'screen_name': '_mstevenson'},
#   {'default_profile_image': False,
#    'id': 1836330308,
#    'name': 'Stephanie A Kingsley',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/767900043206537216/GdMbgQR1_normal.jpg',
#    'screen_name': 'KingsleySteph'},
#   {'default_profile_image': False,
#    'id': 373385155,
#    'name': 'Andrea Goethals',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1775755066/Dp01_white_small_normal.png',
#    'screen_name': 'AndreaGoethals'},
#   {'default_profile_image': False,
#    'id': 256118545,
#    'name': 'Norman Meuschke',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/745982367869902848/A1JUKXNM_normal.jpg',
#    'screen_name': 'normeu'},
#   {'default_profile_image': False,
#    'id': 455827771,
#    'name': 'Bela',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000476238431/9d88000e3889e6bf18771991938efebf_normal.jpeg',
#    'screen_name': 'BelaGipp'},
#   {'default_profile_image': False,
#    'id': 1200468920,
#    'name': 'Myriam',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/780532806141304833/J-sI3XW0_normal.jpg',
#    'screen_name': 'MyriamCTraub'},
#   {'default_profile_image': False,
#    'id': 238653576,
#    'name': "Brendan O'Hallarn",
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1218358427/WhiteKnucklesSquare2_normal.jpg',
#    'screen_name': 'White__Knuckles'},
#   {'default_profile_image': False,
#    'id': 168780501,
#    'name': 'TEI Landmark',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/722804725591093249/k0Fi8aH0_normal.jpg',
#    'screen_name': 'TEILandmark'},
#   {'default_profile_image': False,
#    'id': 38438084,
#    'name': 'tmeehleib',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/663796679867539456/cSax5DdB_normal.png',
#    'screen_name': 'tmeehleib'},
#   {'default_profile_image': True,
#    'id': 742243474485956608,
#    'name': 'Mohammad Obaidullah',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#    'screen_name': 'Mohamma47262302'},
#   {'default_profile_image': False,
#    'id': 41353586,
#    'name': 'DBpedia',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/721301450962432000/L9ehCZfC_normal.jpg',
#    'screen_name': 'dbpedia'},
#   {'default_profile_image': False,
#    'id': 326644141,
#    'name': 'aml eyde',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/740846073648939009/uRO1YGQj_normal.jpg',
#    'screen_name': 'amlhasbat'},
#   {'default_profile_image': False,
#    'id': 1009549428,
#    'name': 'Tim Walsh',
# ...
#    'name': 'Michael A. Herzog',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/756744495815884800/U8V4r63S_normal.jpg',
#    'screen_name': 'maherzog'},
#   {'default_profile_image': False,
#    'id': 132916189,
#    'name': 'Margy Avery',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/528667158285664256/XuAICK_t_normal.jpeg',
#    'screen_name': 'margymavery'},
#   {'default_profile_image': False,
#    'id': 45752188,
#    'name': 'Paul Logasa Bogen II',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/766026693056266240/pDg1R0oS_normal.jpg',
#    'screen_name': 'plbogen'},
#   {'default_profile_image': True,
#    'id': 497825678,
#    'name': 'xuxomln',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'xuxomln'},
#   {'default_profile_image': False,
#    'id': 385020618,
#    'name': 'SHAGGreenbrier',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1587093050/Greenbrier_normal.png',
#    'screen_name': 'SouthernKiaGB'},
#   {'default_profile_image': False,
#    'id': 199205892,
#    'name': 'Raffaele Messuti',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/682508583649570816/T1t6M1PI_normal.png',
#    'screen_name': 'atomotic'},
#   {'default_profile_image': False,
#    'id': 14331818,
#    'name': 'Ed Summers',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/803663094777974784/jgMuBer0_normal.jpg',
#    'screen_name': 'edsu'},
#   {'default_profile_image': False,
#    'id': 479894950,
#    'name': 'Mat Kelly',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/598110235920834560/lFLE-mX7_normal.png',
#    'screen_name': 'machawk1'},
#   {'default_profile_image': False,
#    'id': 34713020,
#    'name': 'Kyle Williams',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/676785599693615104/ifMpRS-8_normal.jpg',
#    'screen_name': 'kylewilliams87'},
#   {'default_profile_image': False,
#    'id': 470775438,
#    'name': 'Alisia',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/825152020193619968/yx56M7kr_normal.jpg',
#    'screen_name': 'Alisia1092'},
#   {'default_profile_image': True,
#    'id': 112950384,
#    'name': 'matpre',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#    'screen_name': 'pre11e'},
#   {'default_profile_image': False,
#    'id': 15831818,
#    'name': 'Tyler Walters',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/58153334/tyler0704_normal.jpg',
#    'screen_name': 'tywalters1'},
#   {'default_profile_image': False,
#    'id': 28178451,
#    'name': 'Lee Dirks',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/117754788/Mmm_Beer_normal.jpg',
#    'screen_name': 'ldirks'},
#   {'default_profile_image': False,
#    'id': 413130434,
#    'name': 'jcdl2012',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1640378418/jcdl_logo_normal.gif',
#    'screen_name': 'jcdl2012'},
#   {'default_profile_image': False,
#    'id': 100660566,
#    'name': 'Lisa Lande',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/619247417/landeart_normal.jpg',
#    'screen_name': 'landeart'},
#   {'default_profile_image': False,
#    'id': 411169790,
#    'name': 'John McManus',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1636194783/image_normal.jpg',
#    'screen_name': 'witch_doctor81'},
#   {'default_profile_image': False,
#    'id': 259850415,
#    'name': 'IIPC',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2179744751/IIPC_Twitter_ProfilePic_normal.gif',
#    'screen_name': 'NetPreserve'},
#   {'default_profile_image': False,
#    'id': 402772312,
#    'name': 'NDSA',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/723223701836181505/yShs_hqK_normal.jpg',
#    'screen_name': 'NDSA2'},
#   {'default_profile_image': False,
#    'id': 1711171,
#    'name': 'Peter Keane',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/634320167/Photo_35_normal.jpg',
#    'screen_name': 'pkeane'},
#   {'default_profile_image': False,
#    'id': 5641552,
#    'name': 'Miriam Blake',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/24241162/ebook_normal.jpg',
#    'screen_name': 'meblake'},
#   {'default_profile_image': True,
#    'id': 34698911,
#    'name': 'teknicaldy',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#    'screen_name': 'unknown_6'},
#   {'default_profile_image': True,
#    'id': 387069830,
#    'name': 'Darryl Young',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'BizApproved'},
#   {'default_profile_image': False,
#    'id': 20610488,
#    'name': 'Erik Freiser',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/747217925791055872/2yCk_Uy7_normal.jpg',
#    'screen_name': 'Erikfreiser'},
#   {'default_profile_image': False,
#    'id': 278198164,
#    'name': 'Abdulla Alasaadi',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838796115742961664/qkOgpCsi_normal.jpg',
#    'screen_name': 'AAlasaadi'},
#   {'default_profile_image': False,
#    'id': 355773903,
#    'name': 'Archive-It',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/750715520534675456/RD0TeRLZ_normal.jpg',
#    'screen_name': 'archiveitorg'},
#   {'default_profile_image': False,
#    'id': 366605043,
#    'name': 'Brooks Childers',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1553616744/110313-133951_normal.jpg',
#    'screen_name': 'awptix'},
#   {'default_profile_image': False,
#    'id': 338504977,
#    'name': 'Kasey McNamara',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1451138485/21980_1391365183312_1207598399_31173717_286737_n_normal.jpg',
#    'screen_name': 'klhiggins33'},
#   {'default_profile_image': False,
#    'id': 35883240,
#    'name': 'Sebastian Resano',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/776206440352677888/hnGSK1Hu_normal.jpg',
#    'screen_name': 'ChuChoResano'},
#   {'default_profile_image': False,
#    'id': 14149525,
#    'name': 'Frank McCown',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2565544139/klyl8kkare4d2vnb6pyg_normal.jpeg',
#    'screen_name': 'fmccown'},
#   {'default_profile_image': False,
#    'id': 14119157,
#    'name': 'diglib',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/634436589855178752/Eo3MdjLI_normal.jpg',
#    'screen_name': 'diglib'},
#   {'default_profile_image': False,
#    'id': 21586018,
#    'name': 'Helen Hockx-Yu',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/612142333065330688/7km0xDHs_normal.jpg',
#    'screen_name': 'hhockx'},
#   {'default_profile_image': False,
#    'id': 77997105,
#    'name': 'Rob Vesse',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000349276734/a092a1a7f910c343f6710554b0fd82b4_normal.jpeg',
#    'screen_name': 'RobVesse'},
#   {'default_profile_image': False,
#    'id': 1701371,
#    'name': 'Andy Jackson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/748614773831516160/lY83E4kt_normal.jpg',
#    'screen_name': 'anjacks0n'},
#   {'default_profile_image': True,
#    'id': 106536714,
#    'name': 'Faryaneh',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#    'screen_name': 'Faryane'},
#   {'default_profile_image': False,
#    'id': 19450230,
#    'name': 'Leslie Johnston',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3213794593/62e2f31b19d414b13dd145c479311ae4_normal.jpeg',
#    'screen_name': 'lljohnston'},
#   {'default_profile_image': False,
#    'id': 337124515,
#    'name': 'Martin Klein',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1446884840/mklein_normal.jpg',
#    'screen_name': 'mart1nkle1n'},
#   {'default_profile_image': False,
#    'id': 320276384,
#    'name': 'MPV SEAT COVERS UK',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1406318434/img2_normal.jpg',
#    'screen_name': 'smartfit_atees'},
#   {'default_profile_image': True,
#    'id': 40903501,
#    'name': 'Richard Furuta',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#    'screen_name': 'furuta'},
#   {'default_profile_image': True,
#    'id': 36045574,
#    'name': 'Ahmed Ghozia',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#    'screen_name': 'Ghozia'},
#   {'default_profile_image': False,
#    'id': 278661116,
#    'name': 'Ahmed AlSum',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1398121692/n586360620_2280741_4881_normal.jpg',
#    'screen_name': 'aalsum'},
#   {'default_profile_image': False,
#    'id': 32495546,
#    'name': 'Joan Smith',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2971076407/6190a113bbf895966099782c23aa171a_normal.png',
#    'screen_name': 'joansm1th'},
#   {'default_profile_image': False,
#    'id': 191032987,
#    'name': 'Martha Anderson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1266727478/Martha_001_crop_normal.PNG',
#    'screen_name': 'MarthaBunton'},
#   {'default_profile_image': False,
#    'id': 132900528,
#    'name': 'Web@rchive Austria',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1019901278/LOGO_kl_swift_normal.png',
#    'screen_name': 'AT_Webarchive'},
#   {'default_profile_image': False,
#    'id': 133035766,
#    'name': 'Sorgente Linda',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1307654561/sorgentlinda_normal.png',
#    'screen_name': 'sorgentelinda'},
#   {'default_profile_image': False,
#    'id': 48082526,
#    'name': 'Abbie Grotke',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1407170838/abportraitiris_normal.jpg',
#    'screen_name': 'agrotke'},
#   {'default_profile_image': False,
#    'id': 264874122,
#    'name': 'Pranay Pramod',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/671750996507365376/OczUtImF_normal.png',
#    'screen_name': 'sspranay'},
#   {'default_profile_image': False,
#    'id': 32747579,
#    'name': 'Scott Ainsworth',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000635279956/062717d96d474df009b302dd65197c91_normal.jpeg',
#    'screen_name': 'Galsondor'},
#   {'default_profile_image': False,
#    'id': 22826489,
#    'name': 'Shawn M. Jones',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/460655715896410113/_ZuI5SPe_normal.jpeg',
#    'screen_name': 'shawnmjones'},
#   {'default_profile_image': False,
#    'id': 7136612,
#    'name': 'James Smith',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/55367959/Photo_6-cropped_normal.jpg',
#    'screen_name': 'jgsmith'},
#   {'default_profile_image': False,
#    'id': 44583052,
#    'name': 'Bernhard Haslhofer',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3372122721/04416e32afd6420d3f3cf0812163dc37_normal.jpeg',
#    'screen_name': 'bhaslhofer'},
#   {'default_profile_image': False,
#    'id': 14077727,
#    'name': 'Sarah Shreeves',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3161392231/487de8f10fe8f9bb910e46effcbfb19a_normal.jpeg',
#    'screen_name': 'sshreeves'},
#   {'default_profile_image': False,
#    'id': 211104907,
#    'name': 'TagTrees',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1157958643/logo_tag_only_500x500_normal.png',
#    'screen_name': 'TagTrees'},
#   {'default_profile_image': False,
#    'id': 48356887,
#    'name': 'Karim B Boughida',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/616615420565393408/TTXob14b_normal.jpg',
#    'screen_name': 'kboughida'},
#   {'default_profile_image': False,
#    'id': 18638955,
#    'name': 'Moustafa Emara',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1631118205/flight_normal.jpg',
#    'screen_name': 'mousta'},
#   {'default_profile_image': True,
#    'id': 241865283,
#    'name': 'Teri Berg',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#    'screen_name': 'TeriBerg96'},
#   {'default_profile_image': False,
#    'id': 15044465,
#    'name': 'Nicholas Taylor',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/541064285019832320/QivgOAYK_normal.jpeg',
#    'screen_name': 'nullhandle'},
#   {'default_profile_image': False,
#    'id': 71089109,
#    'name': 'Marko A. Rodriguez',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/395313322/exterminator_normal.png',
#    'screen_name': 'twarko'},
#   {'default_profile_image': False,
#    'id': 12509892,
#    'name': 'Kaitlin L. Costello',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834514964677160962/bRYViWNQ_normal.jpg',
#    'screen_name': 'k8lin'},
#   {'default_profile_image': False,
#    'id': 205922124,
#    'name': 'OFFTHEHOOK',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1149731517/smallothlogo_normal.jpg',
#    'screen_name': 'OTHSEAFOOD'},
#   {'default_profile_image': False,
#    'id': 17002009,
#    'name': 'Gene Golovchinsky',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/384632718/LW3N3435-crop_normal.jpg',
#    'screen_name': 'HCIR_GeneG'},
#   {'default_profile_image': False,
#    'id': 201612370,
#    'name': 'Hany SalahEldeen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/589006417966850048/oS_M-9wr_normal.jpg',
#    'screen_name': 'hanysalaheldeen'},
#   {'default_profile_image': False,
#    'id': 14320209,
#    'name': 'Patrick Hochstenbach',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/483484131427229699/zeLlmy4j_normal.jpeg',
#    'screen_name': 'hochstenbach'},
#   {'default_profile_image': False,
#    'id': 8500742,
#    'name': 'Carlton Northern',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/732036478784708608/djVrvXp9_normal.jpg',
#    'screen_name': 'carltonnorthern'},
#   {'default_profile_image': False,
#    'id': 17369964,
#    'name': 'John S. Erickson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1205664680/erickson_twit_normal.jpg',
#    'screen_name': 'olyerickson'},
#   {'default_profile_image': False,
#    'id': 55361508,
#    'name': 'William J Nixon',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/305911187/william_normal.jpg',
#    'screen_name': 'williamjnixon'},
#   {'default_profile_image': False,
#    'id': 180473295,
#    'name': 'Justin F Brunelle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/643489094476132353/lWNbAJj3_normal.jpg',
#    'screen_name': 'justinfbrunelle'},
#   {'default_profile_image': False,
#    'id': 75550501,
#    'name': 'Michele Weigle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/466648768389980160/3m8QCmnl_normal.jpeg',
#    'screen_name': 'weiglemc'},
#   {'default_profile_image': False,
#    'id': 16464166,
#    'name': 'Uma Murthy',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/66818453/uma_normal.JPG',
#    'screen_name': 'umurthy'},
#   {'default_profile_image': False,
#    'id': 17163698,
#    'name': 'Bill LeFurgy',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/422052725459668992/vJ4zBpAw_normal.jpeg',
#    'screen_name': 'blefurgy'},
#   {'default_profile_image': True,
#    'id': 123740183,
#    'name': 'Julianne Allen',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'Julibabe21'},
#   {'default_profile_image': False,
#    'id': 20148603,
#    'name': 'Rob Sanderson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/759196947567697920/ZgO6hvaH_normal.jpg',
#    'screen_name': 'azaroth42'},
#   {'default_profile_image': False,
#    'id': 90083746,
#    'name': 'Herbert',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/844985057811054592/y1eCtANW_normal.jpg',
#    'screen_name': 'hvdsomp'},
#   {'default_profile_image': False,
#    'id': 11137722,
#    'name': 'cathy marshall',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1802710015/me-blurry_normal.jpg',
#    'screen_name': 'ccmarshall'},
#   {'default_profile_image': False,
#    'id': 151901549,
#    'name': 'Michael L. Nelson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/959295176/mln-ad-100x130_normal.jpg',
#    'screen_name': 'phonedude_mln'}]}

# %% [markdown]
# &nbsp;
#
# ## Graph
#
# The standard graphing libraries are out when working with D3:
#
#
# *    [Matplotlib](http://matplotlib.org/)
# *    [Bokeh](http://bokeh.pydata.org/en/latest/)
# *    [Seaborn](http://seaborn.pydata.org/)
# *    [Lightning](http://lightning-viz.org/)
# *    [Plotly](https://plot.ly/)
# *    [Pandas built-in plotting](http://pandas.pydata.org/pandas-docs/stable/visualization.html)
# *    [HoloViews](http://holoviews.org/)
# *    [VisPy](http://vispy.org/)
# *    [pygg](http://www.github.com/sirrice/pygg)
#
# The question is:
#
# > D3 is nontrivial to learn so what libraries are there?
#
# To graph the data using [D3](https://github.com/d3/d3) the jupyter notebook can use [javascript magic](http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/JavaScript%20Notebook%20Extensions.html) with `%%javascript`, and the [Pandas](http://pandas.pydata.org/) library supports output of dataframes to compatible json with `to_json` then use `from IPython.display import Javascript` to run it much like the code used to toggle code visibility at the beginning of this notebook. But there is also a [D3 magic](https://github.com/ResidentMario/py_d3) that can be used `py_d3`. But from `py_d3`:
#
# > Force graphs don't work at all. Use ipython-d3networkx instead
#
# The [ipython-d3networkx](https://github.com/jdfreder/ipython-d3networkx) library looks like it hasn't been updated for 2 years and it is not even on [PyPi](https://pypi.org/search/?q=ipython-d3networkx), and indeed it can not even be imported without errors about multiple packages being renamed or depreciated. So now on to [visJS2Jupyter](https://github.com/ucsd-ccbb/visJS2jupyter) a library that uses D3, maybe it is finally something useful. But it is not, even trying to import it gives an error and there is zero documentation.
#
# ```python
# import visJS2jupyter.visualizations as visualizations
# ```
#
# ```python
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-dbc230bacbc2> in <module>()
#       2 import matplotlib as mpl
#       3 import networkx as nx
# ----> 4 import visJS2jupyter.visualizations
#
# /usr/local/lib/python3.4/dist-packages/visJS2jupyter/visualizations.py in <module>()
#      17 import pandas as pd
#      18 from py2cytoscape import util
# ---> 19 import visJS_module as visJS_module
#      20
#      21 def draw_graph_overlap(G1, G2,
#
# ImportError: No module named 'visJS_module'
# ```
#
# Nobody has time to deal with that. Finally something mature, it looks like [altair](https://github.com/altair-viz/altair) might actually work. It uses the [vega-lite](https://github.com/vega/vega-lite) JSON specification and D3 v4. From a very high level this looks like:
#
# $$
# \text{Altair (Dataframe)} \rightarrow \text{Vega-Lite (JSON)} \rightarrow \text{Vega} \rightarrow \text{D3}
# $$
#
# But then it does not do networks.
#
# &nbsp;
#
# #### Well, looks like it is time to just roll up the sleaves and do it yourself.
#
# It is possible to [create D3 ready JSON using networkx](https://networkx.github.io/documentation/networkx-1.10/reference/readwrite.json_graph.html). So get the data in there and dump it to the right format. `networkx` will throw a fit if the data is left as is complaining about:
#
# ```python
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-92d991454db7> in <module>()
#      11                                image='profile_image_url',
#      12                                source='source',
# ---> 13                                target='target'
#      14                            )
#      15                       )
#
# /usr/local/lib/python3.4/dist-packages/networkx/readwrite/json_graph/node_link.py in node_link_graph(data, directed, multigraph, attrs)
#     168             edgedata = dict((make_str(k), v) for k, v in d.items()
#     169                             if k != source and k != target and k != key)
# --> 170             graph.add_edge(mapping[src], mapping[tgt], ky, **edgedata)
#     171     return graph
#
# TypeError: list indices must be integers, not str
# ```
#
# Well next time I'll know, but to fix this we can either do an `id` lookup for each, or just hash the usernames for a unique id. But it seems that it wants them to be `list` indices, so sequentially numbered starting from zero. Could add a new attribute to each node then do a lookup for each link.
#
# &nbsp;

# %%
index = 0
for node in data['nodes']:
    node.update({'index': index})
    index += 1

for link in data['links']:
    target_done = False
    source_done = False
    for node in data['nodes']:
        if link['target'] == node['screen_name']:
            link['target'] = node['index']
            target_done = True
        if link['source'] == node['screen_name']:
            link['source'] = node['index']
            source_done = True
        if target_done and source_done:
            break

data
# Out:
# {'links': [{'source': 0, 'target': 1},
#   {'source': 1, 'target': 0},
#   {'source': 0, 'target': 634},
#   {'source': 1, 'target': 634},
#   {'source': 2, 'target': 15},
#   {'source': 2, 'target': 98},
#   {'source': 2, 'target': 111},
#   {'source': 2, 'target': 310},
#   {'source': 2, 'target': 329},
#   {'source': 2, 'target': 357},
#   {'source': 2, 'target': 415},
#   {'source': 2, 'target': 435},
#   {'source': 2, 'target': 459},
#   {'source': 2, 'target': 479},
#   {'source': 479, 'target': 2},
#   {'source': 2, 'target': 488},
#   {'source': 2, 'target': 517},
#   {'source': 2, 'target': 585},
#   {'source': 2, 'target': 634},
#   {'source': 3, 'target': 98},
#   {'source': 3, 'target': 142},
#   {'source': 3, 'target': 285},
#   {'source': 3, 'target': 567},
#   {'source': 3, 'target': 578},
#   {'source': 3, 'target': 634},
#   {'source': 4, 'target': 57},
#   {'source': 57, 'target': 4},
#   {'source': 4, 'target': 98},
#   {'source': 4, 'target': 131},
#   {'source': 4, 'target': 183},
#   {'source': 4, 'target': 349},
#   {'source': 4, 'target': 350},
#   {'source': 4, 'target': 417},
#   {'source': 4, 'target': 459},
#   {'source': 4, 'target': 530},
#   {'source': 4, 'target': 578},
#   {'source': 4, 'target': 596},
#   {'source': 4, 'target': 611},
#   {'source': 4, 'target': 634},
#   {'source': 5, 'target': 56},
#   {'source': 5, 'target': 148},
#   {'source': 5, 'target': 161},
#   {'source': 5, 'target': 203},
#   {'source': 5, 'target': 212},
#   {'source': 212, 'target': 5},
#   {'source': 5, 'target': 220},
#   {'source': 5, 'target': 225},
#   {'source': 5, 'target': 257},
#   {'source': 5, 'target': 270},
#   {'source': 5, 'target': 280},
#   {'source': 5, 'target': 300},
#   {'source': 5, 'target': 341},
#   {'source': 5, 'target': 344},
#   {'source': 5, 'target': 345},
#   {'source': 5, 'target': 350},
#   {'source': 5, 'target': 384},
#   {'source': 5, 'target': 392},
#   {'source': 5, 'target': 396},
#   {'source': 5, 'target': 403},
#   {'source': 5, 'target': 405},
#   {'source': 5, 'target': 407},
#   {'source': 5, 'target': 408},
#   {'source': 5, 'target': 410},
#   {'source': 5, 'target': 411},
#   {'source': 5, 'target': 412},
#   {'source': 5, 'target': 415},
#   {'source': 5, 'target': 439},
#   {'source': 5, 'target': 445},
#   {'source': 5, 'target': 455},
#   {'source': 5, 'target': 457},
#   {'source': 5, 'target': 465},
#   {'source': 5, 'target': 469},
#   {'source': 5, 'target': 472},
#   {'source': 5, 'target': 490},
#   {'source': 5, 'target': 491},
#   {'source': 491, 'target': 5},
#   {'source': 5, 'target': 494},
#   {'source': 5, 'target': 496},
#   {'source': 5, 'target': 500},
#   {'source': 5, 'target': 502},
#   {'source': 5, 'target': 508},
#   {'source': 5, 'target': 513},
#   {'source': 5, 'target': 520},
#   {'source': 5, 'target': 532},
#   {'source': 5, 'target': 533},
#   {'source': 5, 'target': 534},
#   {'source': 5, 'target': 536},
#   {'source': 5, 'target': 545},
#   {'source': 5, 'target': 553},
#   {'source': 5, 'target': 566},
#   {'source': 5, 'target': 589},
#   {'source': 5, 'target': 595},
#   {'source': 5, 'target': 596},
#   {'source': 5, 'target': 600},
#   {'source': 5, 'target': 604},
#   {'source': 5, 'target': 606},
#   {'source': 5, 'target': 607},
#   {'source': 5, 'target': 608},
#   {'source': 5, 'target': 613},
#   {'source': 5, 'target': 616},
#   {'source': 5, 'target': 634},
#   {'source': 6, 'target': 47},
#   {'source': 6, 'target': 56},
#   {'source': 6, 'target': 98},
#   {'source': 6, 'target': 200},
#   {'source': 6, 'target': 296},
#   {'source': 6, 'target': 321},
#   {'source': 6, 'target': 324},
#   {'source': 6, 'target': 434},
#   {'source': 6, 'target': 458},
#   {'source': 6, 'target': 634},
#   {'source': 7, 'target': 31},
#   {'source': 7, 'target': 53},
#   {'source': 7, 'target': 98},
#   {'source': 7, 'target': 104},
#   {'source': 7, 'target': 105},
#   {'source': 7, 'target': 131},
#   {'source': 7, 'target': 133},
#   {'source': 7, 'target': 197},
#   {'source': 7, 'target': 198},
#   {'source': 198, 'target': 7},
#   {'source': 7, 'target': 200},
#   {'source': 7, 'target': 228},
#   {'source': 7, 'target': 280},
#   {'source': 7, 'target': 318},
#   {'source': 318, 'target': 7},
#   {'source': 7, 'target': 320},
#   {'source': 7, 'target': 396},
#   {'source': 7, 'target': 401},
#   {'source': 7, 'target': 407},
#   {'source': 7, 'target': 412},
#   {'source': 7, 'target': 415},
#   {'source': 415, 'target': 7},
#   {'source': 7, 'target': 459},
#   {'source': 7, 'target': 494},
#   {'source': 494, 'target': 7},
#   {'source': 7, 'target': 500},
#   {'source': 7, 'target': 567},
#   {'source': 7, 'target': 577},
#   {'source': 7, 'target': 578},
#   {'source': 7, 'target': 591},
#   {'source': 7, 'target': 603},
#   {'source': 603, 'target': 7},
#   {'source': 604, 'target': 7},
#   {'source': 7, 'target': 605},
#   {'source': 7, 'target': 611},
#   {'source': 7, 'target': 616},
#   {'source': 7, 'target': 634},
#   {'source': 8, 'target': 15},
#   {'source': 8, 'target': 29},
#   {'source': 29, 'target': 8},
#   {'source': 8, 'target': 31},
#   {'source': 31, 'target': 8},
#   {'source': 8, 'target': 57},
#   {'source': 57, 'target': 8},
#   {'source': 8, 'target': 68},
#   {'source': 8, 'target': 82},
#   {'source': 8, 'target': 98},
#   {'source': 8, 'target': 124},
#   {'source': 124, 'target': 8},
#   {'source': 8, 'target': 128},
#   {'source': 128, 'target': 8},
#   {'source': 8, 'target': 131},
#   {'source': 8, 'target': 133},
#   {'source': 8, 'target': 137},
#   {'source': 137, 'target': 8},
#   {'source': 8, 'target': 143},
#   {'source': 143, 'target': 8},
#   {'source': 8, 'target': 178},
#   {'source': 8, 'target': 183},
#   {'source': 8, 'target': 185},
#   {'source': 185, 'target': 8},
#   {'source': 8, 'target': 192},
#   {'source': 8, 'target': 193},
#   {'source': 8, 'target': 197},
#   {'source': 8, 'target': 200},
#   {'source': 8, 'target': 203},
#   {'source': 203, 'target': 8},
#   {'source': 8, 'target': 212},
#   {'source': 214, 'target': 8},
#   {'source': 8, 'target': 215},
#   {'source': 215, 'target': 8},
#   {'source': 8, 'target': 220},
#   {'source': 220, 'target': 8},
#   {'source': 8, 'target': 221},
#   {'source': 221, 'target': 8},
#   {'source': 8, 'target': 262},
#   {'source': 262, 'target': 8},
#   {'source': 8, 'target': 280},
#   {'source': 280, 'target': 8},
#   {'source': 282, 'target': 8},
#   {'source': 8, 'target': 285},
#   {'source': 285, 'target': 8},
#   {'source': 8, 'target': 288},
#   {'source': 288, 'target': 8},
#   {'source': 8, 'target': 289},
#   {'source': 8, 'target': 300},
#   {'source': 300, 'target': 8},
#   {'source': 8, 'target': 305},
#   {'source': 305, 'target': 8},
#   {'source': 8, 'target': 318},
#   {'source': 8, 'target': 378},
#   {'source': 378, 'target': 8},
#   {'source': 8, 'target': 391},
#   {'source': 8, 'target': 396},
#   {'source': 8, 'target': 407},
#   {'source': 8, 'target': 411},
#   {'source': 8, 'target': 412},
#   {'source': 412, 'target': 8},
#   {'source': 8, 'target': 450},
#   {'source': 8, 'target': 459},
#   {'source': 8, 'target': 485},
#   {'source': 8, 'target': 500},
#   {'source': 8, 'target': 502},
#   {'source': 8, 'target': 518},
#   {'source': 8, 'target': 521},
#   {'source': 521, 'target': 8},
#   {'source': 8, 'target': 533},
#   {'source': 8, 'target': 566},
#   {'source': 566, 'target': 8},
#   {'source': 8, 'target': 567},
#   {'source': 567, 'target': 8},
#   {'source': 8, 'target': 577},
#   {'source': 8, 'target': 578},
#   {'source': 8, 'target': 585},
#   {'source': 8, 'target': 593},
#   {'source': 8, 'target': 605},
#   {'source': 8, 'target': 616},
#   {'source': 8, 'target': 629},
#   {'source': 8, 'target': 631},
#   {'source': 8, 'target': 634},
#   {'source': 9, 'target': 634},
#   {'source': 10, 'target': 634},
#   {'source': 11, 'target': 634},
#   {'source': 12, 'target': 98},
#   {'source': 12, 'target': 122},
#   {'source': 12, 'target': 203},
#   {'source': 203, 'target': 12},
#   {'source': 12, 'target': 320},
#   {'source': 12, 'target': 421},
#   {'source': 12, 'target': 566},
#   {'source': 566, 'target': 12},
#   {'source': 12, 'target': 568},
#   {'source': 12, 'target': 577},
#   {'source': 12, 'target': 591},
#   {'source': 12, 'target': 593},
#   {'source': 593, 'target': 12},
#   {'source': 12, 'target': 596},
#   {'source': 12, 'target': 631},
#   {'source': 12, 'target': 632},
#   {'source': 12, 'target': 634},
#   {'source': 41, 'target': 13},
#   {'source': 13, 'target': 88},
#   {'source': 13, 'target': 124},
#   {'source': 124, 'target': 13},
#   {'source': 143, 'target': 13},
#   {'source': 13, 'target': 149},
#   {'source': 151, 'target': 13},
#   {'source': 13, 'target': 188},
#   {'source': 188, 'target': 13},
#   {'source': 214, 'target': 13},
#   {'source': 215, 'target': 13},
#   {'source': 13, 'target': 305},
#   {'source': 305, 'target': 13},
#   {'source': 13, 'target': 389},
#   {'source': 389, 'target': 13},
#   {'source': 13, 'target': 391},
#   {'source': 13, 'target': 394},
#   {'source': 13, 'target': 427},
#   {'source': 427, 'target': 13},
#   {'source': 13, 'target': 501},
#   {'source': 501, 'target': 13},
#   {'source': 13, 'target': 511},
#   {'source': 13, 'target': 518},
#   {'source': 13, 'target': 585},
#   {'source': 13, 'target': 590},
#   {'source': 13, 'target': 634},
#   {'source': 14, 'target': 84},
#   {'source': 195, 'target': 14},
#   {'source': 14, 'target': 222},
#   {'source': 222, 'target': 14},
#   {'source': 14, 'target': 380},
#   {'source': 380, 'target': 14},
#   {'source': 14, 'target': 634},
#   {'source': 29, 'target': 15},
#   {'source': 15, 'target': 63},
#   {'source': 74, 'target': 15},
#   {'source': 15, 'target': 98},
#   {'source': 15, 'target': 124},
#   {'source': 124, 'target': 15},
#   {'source': 15, 'target': 128},
#   {'source': 128, 'target': 15},
#   {'source': 15, 'target': 131},
#   {'source': 15, 'target': 137},
#   {'source': 137, 'target': 15},
#   {'source': 15, 'target': 143},
#   {'source': 143, 'target': 15},
#   {'source': 15, 'target': 149},
#   {'source': 149, 'target': 15},
#   {'source': 185, 'target': 15},
#   {'source': 15, 'target': 188},
#   {'source': 15, 'target': 192},
#   {'source': 192, 'target': 15},
#   {'source': 15, 'target': 193},
#   {'source': 193, 'target': 15},
#   {'source': 198, 'target': 15},
#   {'source': 15, 'target': 200},
#   {'source': 200, 'target': 15},
#   {'source': 15, 'target': 212},
#   {'source': 212, 'target': 15},
#   {'source': 15, 'target': 214},
#   {'source': 214, 'target': 15},
#   {'source': 15, 'target': 215},
#   {'source': 215, 'target': 15},
#   {'source': 15, 'target': 220},
#   {'source': 220, 'target': 15},
#   {'source': 15, 'target': 221},
#   {'source': 221, 'target': 15},
#   {'source': 257, 'target': 15},
#   {'source': 262, 'target': 15},
#   {'source': 282, 'target': 15},
#   {'source': 288, 'target': 15},
#   {'source': 15, 'target': 305},
#   {'source': 305, 'target': 15},
#   {'source': 15, 'target': 320},
#   {'source': 320, 'target': 15},
#   {'source': 326, 'target': 15},
#   {'source': 15, 'target': 349},
#   {'source': 15, 'target': 350},
#   {'source': 350, 'target': 15},
#   {'source': 15, 'target': 354},
#   {'source': 354, 'target': 15},
#   {'source': 384, 'target': 15},
#   {'source': 15, 'target': 391},
#   {'source': 15, 'target': 394},
#   {'source': 394, 'target': 15},
#   {'source': 15, 'target': 396},
#   {'source': 15, 'target': 411},
#   {'source': 411, 'target': 15},
#   {'source': 15, 'target': 415},
#   {'source': 415, 'target': 15},
#   {'source': 457, 'target': 15},
#   {'source': 15, 'target': 462},
#   {'source': 15, 'target': 469},
#   {'source': 469, 'target': 15},
#   {'source': 15, 'target': 485},
#   {'source': 485, 'target': 15},
#   {'source': 500, 'target': 15},
#   {'source': 501, 'target': 15},
#   {'source': 508, 'target': 15},
#   {'source': 511, 'target': 15},
#   {'source': 15, 'target': 518},
#   {'source': 518, 'target': 15},
#   {'source': 15, 'target': 532},
#   {'source': 532, 'target': 15},
#   {'source': 539, 'target': 15},
#   {'source': 566, 'target': 15},
#   {'source': 15, 'target': 567},
#   {'source': 567, 'target': 15},
#   {'source': 15, 'target': 578},
#   {'source': 15, 'target': 585},
#   {'source': 585, 'target': 15},
#   {'source': 15, 'target': 593},
#   {'source': 593, 'target': 15},
#   {'source': 15, 'target': 595},
#   {'source': 595, 'target': 15},
#   {'source': 15, 'target': 605},
#   {'source': 608, 'target': 15},
#   {'source': 15, 'target': 616},
#   {'source': 15, 'target': 629},
#   {'source': 629, 'target': 15},
#   {'source': 15, 'target': 632},
#   {'source': 632, 'target': 15},
#   {'source': 15, 'target': 634},
#   {'source': 16, 'target': 634},
#   {'source': 17, 'target': 76},
#   {'source': 76, 'target': 17},
#   {'source': 17, 'target': 98},
#   {'source': 17, 'target': 131},
#   {'source': 17, 'target': 197},
#   {'source': 17, 'target': 300},
#   {'source': 300, 'target': 17},
#   {'source': 17, 'target': 459},
#   {'source': 17, 'target': 634},
#   {'source': 634, 'target': 17},
#   {'source': 18, 'target': 31},
#   {'source': 18, 'target': 131},
#   {'source': 18, 'target': 142},
#   {'source': 18, 'target': 220},
#   {'source': 18, 'target': 529},
#   {'source': 18, 'target': 530},
#   {'source': 18, 'target': 578},
#   {'source': 18, 'target': 631},
#   {'source': 18, 'target': 632},
#   {'source': 18, 'target': 634},
#   {'source': 19, 'target': 411},
#   {'source': 19, 'target': 627},
#   {'source': 19, 'target': 634}],
#  'nodes': [{'default_profile_image': False,
#    'id': 59860290,
#    'index': 0,
#    'name': 'Ryan Yacyshyn',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/796184339687931905/--nSmCcF_normal.jpg',
#    'screen_name': 'ryacca'},
#   {'default_profile_image': False,
#    'id': 9421452,
#    'index': 1,
#    'name': 'Shebin',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/608858046731673600/nwm8reMF_normal.jpg',
#    'screen_name': 'shebin'},
#   {'default_profile_image': False,
#    'id': 265517884,
#    'index': 2,
#    'name': 'Daniel',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2839957630/6742066915c916b9448b513314bab9f2_normal.jpeg',
#    'screen_name': 'ycpdan'},
#   {'default_profile_image': False,
#    'id': 3979114762,
#    'index': 3,
#    'name': 'Rebecca Dallavalle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822219089049452546/yjbE3trx_normal.jpg',
#    'screen_name': 'BexAnnalisa'},
#   {'default_profile_image': False,
#    'id': 756135755190198273,
#    'index': 4,
#    'name': 'De Gruyter Libraries',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/756137216254980096/2Bj3kfSP_normal.jpg',
#    'screen_name': 'degruyter_lib'},
#   {'default_profile_image': False,
#    'id': 3158073120,
#    'index': 5,
#    'name': 'Mixnode',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/804823765964029952/3h6CTIMX_normal.jpg',
#    'screen_name': 'mixnode'},
#   {'default_profile_image': False,
#    'id': 481260788,
#    'index': 6,
#    'name': '@no identd',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/758644713201238016/HX7JPMfX_normal.jpg',
#    'screen_name': 'no_identd'},
#   {'default_profile_image': False,
#    'id': 1429810189,
#    'index': 7,
#    'name': 'Jens Crueger',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/765152493877751808/FolWjb2D_normal.jpg',
#    'screen_name': 'JCrueger'},
#   {'default_profile_image': False,
#    'id': 4008474733,
#    'index': 8,
#    'name': 'Alissa M.',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/738710122512285697/Zkf_pHcT_normal.jpg',
#    'screen_name': 'lissertations'},
#   {'default_profile_image': True,
#    'id': 821042028800802816,
#    'index': 9,
#    'name': 'Grant Atkins',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'grantatVA'},
#   {'default_profile_image': True,
#    'id': 827268804359053313,
#    'index': 10,
#    'name': 'MichaelMicros',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#    'screen_name': 'mmicros1'},
#   {'default_profile_image': False,
#    'id': 789293970677456896,
#    'index': 11,
#    'name': 'Patrick Cox',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/789296122233847808/fmHjla7Q_normal.jpg',
#    'screen_name': '74paddycakes'},
#   {'default_profile_image': False,
#    'id': 799272100599046145,
#    'index': 12,
#    'name': 'René Voorburg',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799931370516647940/K0TkfBPi_normal.jpg',
#    'screen_name': 'digitopia_nl'},
#   {'default_profile_image': False,
#    'id': 203096228,
#    'index': 13,
#    'name': 'Adrienne Pruitt',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/717376345865478144/HcRuXWSC_normal.jpg',
#    'screen_name': 'PruittAL'},
#   {'default_profile_image': False,
#    'id': 81650379,
#    'index': 14,
#    'name': 'Brenda Berkelaar',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/665158896525312000/O9o0G7Wd_normal.jpg',
#    'screen_name': 'brendaberkelaar'},
#   {'default_profile_image': False,
#    'id': 47899646,
#    'index': 15,
#    'name': 'Cassie Findlay',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/503770380146716672/-ZqPskdq_normal.jpeg',
#    'screen_name': 'CassPF'},
#   {'default_profile_image': False,
#    'id': 899863316,
#    'index': 16,
#    'name': 'OK Rider/Motorcu',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/747873690654769154/TaKbM-_u_normal.jpg',
#    'screen_name': 'OKMotovlog'},
#   {'default_profile_image': False,
#    'id': 30802131,
#    'index': 17,
#    'name': 'Margaret Konkol',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/612467215862927360/zgZk9y9K_normal.jpg',
#    'screen_name': 'mekonkol'},
#   {'default_profile_image': False,
#    'id': 761396027446398976,
#    'index': 18,
#    'name': 'Stesker3D',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/777132624846348288/lYylOWVP_normal.jpg',
#    'screen_name': 'Stesker3D'},
#   {'default_profile_image': False,
#    'id': 825218681252765696,
#    'index': 19,
#    'name': 'Hussam Hallak',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/828693167197204481/LezWYLYV_normal.jpg',
#    'screen_name': 'HussamHallak1'},
#   {'default_profile_image': True,
#    'id': 20255236,
#    'index': 20,
#    'name': 'Carol Castle',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#    'screen_name': 'carolc16'},
#   {'default_profile_image': False,
#    'id': 825049390998024192,
#    'index': 21,
#    'name': 'Printuu',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/825421424718389249/vd2bmbni_normal.jpg',
#    'screen_name': 'printuu'},
#   {'default_profile_image': False,
#    'id': 733536950963994624,
#    'index': 22,
#    'name': 'Data Science',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/828865856021155840/fordY9bZ_normal.jpg',
#    'screen_name': 'dtscnc'},
#   {'default_profile_image': False,
#    'id': 737852660183932928,
#    'index': 23,
#    'name': 'Tunazzina Islam',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/744945448964751360/BYD6pYSi_normal.jpg',
#    'screen_name': 'Tunaz_Islam'},
#   {'default_profile_image': False,
#    'id': 9630082,
#    'index': 24,
#    'name': 'Meredith Artley',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/421350001134948352/oWP39w4L_normal.jpeg',
#    'screen_name': 'MeredithA'},
#   {'default_profile_image': False,
#    'id': 258599525,
#    'index': 25,
#    'name': 'Meghan Hoyer',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/643884814119104512/9Pew3YSv_normal.jpg',
#    'screen_name': 'MeghanHoyer'},
#   {'default_profile_image': False,
#    'id': 3122708646,
#    'index': 26,
#    'name': 'Anton',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/756657049606512644/geQDpH31_normal.jpg',
#    'screen_name': 'AntonJRasmussen'},
#   {'default_profile_image': False,
#    'id': 1634706151,
#    'index': 27,
#    'name': 'Bram Luyten',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/740611666887462912/cAztghSl_normal.jpg',
#    'screen_name': 'LuytenBram'},
#   {'default_profile_image': False,
#    'id': 399805362,
#    'index': 28,
#    'name': 'Mohd Kamal',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/588399194395652096/tS649QUm_normal.jpg',
#    'screen_name': 'MohdKamal6'},
#   {'default_profile_image': False,
#    'id': 269424738,
#    'index': 29,
#    'name': 'Paul Young',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/698409181653684224/ZTJHMEvy_normal.jpg',
#    'screen_name': 'pmyoung84'},
#   {'default_profile_image': True,
#    'id': 810540893396733953,
#    'index': 30,
#    'name': 'Karki',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#    'screen_name': 'Karki693'},
#   {'default_profile_image': False,
#    'id': 1119502988,
#    'index': 31,
#    'name': 'British Library Labs',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/458627032255963136/LrfmDsum_normal.png',
#    'screen_name': 'BL_Labs'},
#   {'default_profile_image': False,
#    'id': 783440136,
#    'index': 32,
#    'name': 'Pôle #AI au #Québec',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/807696707089813504/VA-7_NUn_normal.jpg',
#    'screen_name': 'IntelligenceTV'},
#   {'default_profile_image': True,
#    'id': 808893873766432768,
#    'index': 33,
#    'name': 'Maheedhar Gunnam',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#    'screen_name': 'maheedhargunnam'},
#   {'default_profile_image': False,
#    'id': 58880930,
#    'index': 34,
#    'name': 'Nattiya Kanhabua',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3727028789/2c275bed6ef62c97f7071c82877d4445_normal.png',
#    'screen_name': 'nattiyak'},
#   {'default_profile_image': False,
#    'id': 47985362,
#    'index': 35,
#    'name': 'Marcin Wilkowski',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/461050206742540288/0WEsLaiN_normal.jpeg',
#    'screen_name': 'marcinwilkowski'},
#   {'default_profile_image': False,
#    'id': 801186507931455488,
#    'index': 36,
#    'name': 'James Dill',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/801704756116762625/XySpif1b_normal.jpg',
#    'screen_name': 'minornotez'},
#   {'default_profile_image': False,
#    'id': 19203768,
#    'index': 37,
#    'name': 'Kate Starbird',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822692976304340993/jMQjWo1h_normal.jpg',
#    'screen_name': 'katestarbird'},
#   {'default_profile_image': False,
#    'id': 2190533245,
#    'index': 38,
#    'name': 'ACM SIGIR',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/776809490909896704/OVX1OArZ_normal.jpg',
#    'screen_name': 'ACMSIGIR'},
#   {'default_profile_image': False,
#    'id': 89504686,
#    'index': 39,
#    'name': 'Ralf Claussnitzer',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/747697618122334208/ZvNFvCNv_normal.jpg',
#    'screen_name': 'claussni'},
#   {'default_profile_image': False,
#    'id': 192964243,
#    'index': 40,
#    'name': 'NJ Computer Group',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/643449617858719744/bZNSoGOy_normal.png',
#    'screen_name': 'njcomputergroup'},
#   {'default_profile_image': False,
#    'id': 113647306,
#    'index': 41,
#    'name': 'ARLIS/NA New York',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1192193415/twitter_normal.jpg',
#    'screen_name': 'ARLIS_NY'},
#   {'default_profile_image': False,
#    'id': 2936496598,
#    'index': 42,
#    'name': 'Sumitra Duncan',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/553623454000222208/IZUaqZve_normal.jpeg',
#    'screen_name': 'artlibrariannyc'},
#   {'default_profile_image': False,
#    'id': 3281181511,
#    'index': 43,
#    'name': 'WikiCite',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/739367095532703744/3hhZSGOn_normal.jpg',
#    'screen_name': 'Wikicite'},
#   {'default_profile_image': False,
#    'id': 258032124,
#    'index': 44,
#    'name': 'ussr.io',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/768894884543463424/FGaQuAar_normal.jpg',
#    'screen_name': 'ChiefScientist'},
#   {'default_profile_image': False,
#    'id': 3447506422,
#    'index': 45,
#    'name': 'ODU Peninsula Center',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/796765515972833280/KTxASFB8_normal.jpg',
#    'screen_name': 'ODUPeninsulaCtr'},
#   {'default_profile_image': False,
#    'id': 16564030,
#    'index': 46,
#    'name': 'Lance Mercereau',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/560111601043243009/xfgOG4by_normal.jpeg',
#    'screen_name': 'lmercereau'},
#   {'default_profile_image': False,
#    'id': 30047063,
#    'index': 47,
#    'name': 'Hindawi',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/771636621741395968/oBKO_LC1_normal.jpg',
#    'screen_name': 'Hindawi'},
#   {'default_profile_image': False,
#    'id': 1695487818,
#    'index': 48,
#    'name': 'Esperanza Salazar',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/712373189884530688/i-6-HCic_normal.jpg',
#    'screen_name': 'es_land'},
#   {'default_profile_image': False,
#    'id': 2973715954,
#    'index': 49,
#    'name': 'Kenneth Diedrich',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/554395111883161600/07kSP8Z0_normal.jpeg',
#    'screen_name': 'KennyDiedrich'},
#   {'default_profile_image': False,
#    'id': 774187456191160320,
#    'index': 50,
#    'name': 'Joffrey Decourselle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/774188246679056384/DU3oHLC1_normal.jpg',
#    'screen_name': 'JDecourselle'},
#   {'default_profile_image': False,
#    'id': 3849211272,
#    'index': 51,
#    'name': 'Riker',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/673899174002167808/XAsJadQe_normal.jpg',
#    'screen_name': 'RikerHampton'},
#   {'default_profile_image': False,
#    'id': 57750231,
#    'index': 52,
#    'name': 'ODUAlumniAssociation',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/531839614709796864/ArNBPO_0_normal.jpeg',
#    'screen_name': 'ODUAlumni'},
#   {'default_profile_image': False,
#    'id': 19258241,
#    'index': 53,
#    'name': 'Heinz Pampel',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000761485499/2e08c904773ac15d05a7c43b1e702800_normal.jpeg',
#    'screen_name': 'pampel'},
#   {'default_profile_image': False,
#    'id': 146209930,
#    'index': 54,
#    'name': 'Katrina Stierholz',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000039320464/3c6afd264d037cfb5316a3059053eb03_normal.jpeg',
#    'screen_name': 'stierholz'},
#   {'default_profile_image': False,
#    'id': 4481168962,
#    'index': 55,
#    'name': 'School of Salamanca',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/827135250534907906/AWab8rL1_normal.jpg',
#    'screen_name': 'salamancaschool'},
#   {'default_profile_image': False,
#    'id': 16868154,
#    'index': 56,
#    'name': 'Arjen P. de Vries',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2875589913/b361e1c80a05f80c887c97619cc1b6fe_normal.jpeg',
#    'screen_name': 'arjenpdevries'},
#   {'default_profile_image': False,
#    'id': 3354096993,
#    'index': 57,
#    'name': 'Helena Byrne',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/687005921659215872/30iKj1xn_normal.jpg',
#    'screen_name': 'HBee2015'},
#   {'default_profile_image': False,
#    'id': 193063049,
#    'index': 58,
#    'name': 'Ben Vershbow',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1251454027/doppelganger_normal.jpg',
#    'screen_name': 'subsublibrary'},
#   {'default_profile_image': False,
#    'id': 468735081,
#    'index': 59,
#    'name': 'Julie Rogers',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/839248056751165440/E-YyhQD8_normal.jpg',
#    'screen_name': 'jubrogers'},
#   {'default_profile_image': False,
#    'id': 138161380,
#    'index': 60,
#    'name': 'Matías Butelman',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/751793992883380224/4Czuql6q_normal.jpg',
#    'screen_name': 'mbutel'},
#   {'default_profile_image': False,
#    'id': 17271698,
#    'index': 61,
#    'name': 'andrea davis',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/794631184001052672/XVRqXj_m_normal.jpg',
#    'screen_name': 'detailmatters'},
#   {'default_profile_image': False,
#    'id': 3365719153,
#    'index': 62,
#    'name': 'UCLA Acquisitions',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/637406673070493696/3WGMAjWH_normal.png',
#    'screen_name': 'acquire_UCLA'},
#   {'default_profile_image': False,
#    'id': 74541831,
#    'index': 63,
#    'name': 'Kate Zwaard',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/765274696547962880/IHHBZH3P_normal.jpg',
#    'screen_name': 'kzwa'},
#   {'default_profile_image': False,
#    'id': 5894872,
#    'index': 64,
#    'name': 'Harald Sack',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/799905753087803392/5CUa32Or_normal.jpg',
#    'screen_name': 'lysander07'},
#   {'default_profile_image': False,
#    'id': 13645402,
#    'index': 65,
#    'name': 'ChrisAldrich',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000823803940/e500bc8cba99417f27ac3392e7503aa0_normal.jpeg',
#    'screen_name': 'ChrisAldrich'},
#   {'default_profile_image': False,
#    'id': 729223119030751232,
#    'index': 66,
#    'name': 'www.sheershasamachar',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/739958609904205824/YXMRGiUw_normal.jpg',
#    'screen_name': 'sheershasamach1'},
#   {'default_profile_image': False,
#    'id': 739900844531974144,
#    'index': 67,
#    'name': 'JCDL2017',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/783699658459770880/6ToHFp2t_normal.jpg',
#    'screen_name': 'jcdl2017'},
#   {'default_profile_image': False,
#    'id': 1668275245,
#    'index': 68,
#    'name': 'perma.cc',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/744949592618209280/QlVQwm-X_normal.jpg',
#    'screen_name': 'permacc'},
#   {'default_profile_image': True,
#    'id': 781886520978444288,
#    'index': 69,
#    'name': 'Kh Talha',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#    'screen_name': 'KhTalha6'},
#   {'default_profile_image': False,
#    'id': 570294703,
#    'index': 70,
#    'name': 'Jan Strack',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/746824862249914369/rQMEiGO2_normal.jpg',
#    'screen_name': 'Jack_Stran'},
#   {'default_profile_image': False,
#    'id': 24713262,
#    'index': 71,
#    'name': 'Angela Woodall',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000475083959/a8e8d6a253012ace417926b216c273cc_normal.jpeg',
#    'screen_name': 'AngelaWoodall'},
#   {'default_profile_image': True,
#    'id': 66188615,
#    'index': 72,
#    'name': 'Bruno Leonard',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_3_normal.png',
#    'screen_name': 'bruno_leonard_'},
#   {'default_profile_image': False,
#    'id': 774263152544452608,
#    'index': 73,
#    'name': 'Data Cartel',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/774274418390528000/kgf38QtT_normal.jpg',
#    'screen_name': 'datacartel1'},
#   {'default_profile_image': False,
#    'id': 2806160786,
#    'index': 74,
#    'name': 'JDNA',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/638719030350622720/YqAoN5AH_normal.jpg',
#    'screen_name': 'RJIJDNA'},
#   {'default_profile_image': False,
#    'id': 1551367058,
#    'index': 75,
#    'name': 'Fredericik Begbeder',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000710311151/9cbd8006a5899a6118dc8368f790d274_normal.jpeg',
#    'screen_name': 'FredericikB'},
#   {'default_profile_image': False,
#    'id': 2852131203,
#    'index': 76,
#    'name': 'Pamela VanHaitsma',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/839647802384842755/jAKXKwDo_normal.jpg',
#    'screen_name': 'pvanhaitsma'},
#   {'default_profile_image': False,
#    'id': 4508117621,
#    'index': 77,
#    'name': 'Robin Ruggaber',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/807640801790595072/yYBSC7oJ_normal.jpg',
#    'screen_name': 'robin_ruggaber'},
#   {'default_profile_image': False,
#    'id': 237086573,
#    'index': 78,
#    'name': 'Charlene Finley',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/775198667783282688/LjZDMnds_normal.jpg',
#    'screen_name': 'Cee_Finley'},
#   {'default_profile_image': False,
#    'id': 161598558,
#    'index': 79,
#    'name': 'Roceys',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2359431553/i7mwta6u4h90lmcvfr3y_normal.jpeg',
#    'screen_name': 'woilgoo'},
#   {'default_profile_image': False,
#    'id': 11164692,
#    'index': 80,
#    'name': 'Seamus Lawless',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1662654879/SciCom_Profile_normal.jpg',
#    'screen_name': 'seamuslawless'},
#   {'default_profile_image': False,
#    'id': 737342173079736321,
#    'index': 81,
#    'name': 'Kevin Levrone',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/737368290222346241/YjvgWlJt_normal.jpg',
#    'screen_name': 'KevinLevrone3'},
#   {'default_profile_image': False,
#    'id': 4738176435,
#    'index': 82,
#    'name': 'MementoWeb',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/770345340344082433/RdLol102_normal.jpg',
#    'screen_name': 'Mementoweb'},
#   {'default_profile_image': False,
#    'id': 7377862,
#    'index': 83,
#    'name': 'Jason Casden',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1285825913/casden_hood_garden_normal.jpg',
#    'screen_name': 'cazzerson'},
#   {'default_profile_image': False,
#    'id': 833373624,
#    'index': 84,
#    'name': 'Brooke F Welles',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2626756569/Brooke-Headshot-Small_normal.jpg',
#    'screen_name': 'foucaultwelles'},
#   {'default_profile_image': False,
#    'id': 1393107912,
#    'index': 85,
#    'name': 'Micah Zeller',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/816351501916454914/SAEtdwW__normal.jpg',
#    'screen_name': 'mdzellerCDAL'},
#   {'default_profile_image': False,
#    'id': 48592998,
#    'index': 86,
#    'name': 'Robin M. Katz',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/590689039776411648/U97Pn_IQ_normal.jpg',
#    'screen_name': 'robinmkatz'},
#   {'default_profile_image': False,
#    'id': 3321913552,
#    'index': 87,
#    'name': 'Christopher Chyr',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/610957360320765952/a5OOcBKO_normal.jpg',
#    'screen_name': 'mrchyr'},
#   {'default_profile_image': False,
#    'id': 134569763,
#    'index': 88,
#    'name': 'Meredith Evans',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/481629489051361281/V8hh32Pv_normal.jpeg',
#    'screen_name': 'mre1920'},
#   {'default_profile_image': False,
#    'id': 3412095995,
#    'index': 89,
#    'name': 'Saad Ehsan',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/630638865850703872/-zYYKKCo_normal.png',
#    'screen_name': 'saadaitomation'},
#   {'default_profile_image': False,
#    'id': 729563714475700224,
#    'index': 90,
#    'name': 'Jessica Smith',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/729568662642823170/6BVoSMfV_normal.jpg',
#    'screen_name': 'jessicasmith541'},
#   {'default_profile_image': False,
#    'id': 267189586,
#    'index': 91,
#    'name': 'bakare oluwabunmi',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/775045842411655168/VK1D_sfL_normal.jpg',
#    'screen_name': 'bumdots4eva'},
#   {'default_profile_image': False,
#    'id': 605923,
#    'index': 92,
#    'name': 'Shawn Walker',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1256136674/shawn_normal.jpg',
#    'screen_name': 'walkeroh'},
#   {'default_profile_image': True,
#    'id': 3189940844,
#    'index': 93,
#    'name': '.',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#    'screen_name': 'CRajaharsha'},
#   {'default_profile_image': False,
#    'id': 14338221,
#    'index': 94,
#    'name': 'Laura J. Smart',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/723280931235069952/kcVyyYGC_normal.jpg',
#    'screen_name': 'infod1va'},
#   {'default_profile_image': False,
#    'id': 33736942,
#    'index': 95,
#    'name': 'Liz Neely',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/764516080828186628/LHlRWO-b_normal.jpg',
#    'screen_name': 'lili_czarina'},
#   {'default_profile_image': False,
#    'id': 745643383188758528,
#    'index': 96,
#    'name': 'Oorlogsbronnen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/748180024793120768/biWSprjf_normal.jpg',
#    'screen_name': 'Oorlogsbronnen'},
#   {'default_profile_image': False,
#    'id': 745385398134661120,
#    'index': 97,
#    'name': 'Annika Hinze',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/745386763586240512/HPTiHaEi_normal.jpg',
#    'screen_name': 'annika_hinze'},
#   {'default_profile_image': False,
#    'id': 18957805,
#    'index': 98,
#    'name': 'Internet Archive',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/717127559134056448/BYGRuZmj_normal.jpg',
#    'screen_name': 'internetarchive'},
#   {'default_profile_image': False,
#    'id': 708690890974470145,
#    'index': 99,
#    'name': 'Mridul Sen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/774509666080612352/bSts9phn_normal.jpg',
#    'screen_name': 'mridulish'},
#   {'default_profile_image': False,
#    'id': 118078818,
#    'index': 100,
#    'name': 'Abd El-Fatah',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/757461371973885952/ynT2yK3a_normal.jpg',
#    'screen_name': 'Dr_Abomohra'},
#   {'default_profile_image': False,
#    'id': 220983330,
#    'index': 101,
#    'name': 'Helge Holzmann',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000254082716/b168fa08a6f03ea6520759a73f2c5dbe_normal.jpeg',
#    'screen_name': 'helgeho'},
#   {'default_profile_image': False,
#    'id': 9308852,
#    'index': 102,
#    'name': 'Îďȫʞ Šĕčủrıtƴ',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/573613604089393152/Y3URTCCY_normal.jpeg',
#    'screen_name': 'idokius'},
#   {'default_profile_image': False,
#    'id': 744784018919432194,
#    'index': 103,
#    'name': 'Zhaohuan Wang',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/832587358977482752/22n7eDNz_normal.jpg',
#    'screen_name': 'zhaohuan_wang'},
#   {'default_profile_image': False,
#    'id': 4497126976,
#    'index': 104,
#    'name': 'PoliticalTVAdArchive',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/677600361742393344/2SU5t8q7_normal.png',
#    'screen_name': 'PolitAdArchive'},
#   {'default_profile_image': False,
#    'id': 7591252,
#    'index': 105,
#    'name': 'Nancy Watzman',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/460868826301607936/UT81WeaF_normal.png',
#    'screen_name': 'nwatzman'},
#   {'default_profile_image': False,
#    'id': 24257870,
#    'index': 106,
#    'name': 'John Howard',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2375478079/145tl6jf9vlcosn2v0wb_normal.jpeg',
#    'screen_name': 'John_B_Howard'},
#   {'default_profile_image': False,
#    'id': 753571748860293120,
#    'index': 107,
#    'name': 'Context Scout',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/753585746729111552/lc4VNXJ1_normal.jpg',
#    'screen_name': 'CScoutTech'},
#   {'default_profile_image': False,
#    'id': 2416303724,
#    'index': 108,
#    'name': 'Ava Forte Vitali',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/449622377203122176/5nauM2wG_normal.jpeg',
#    'screen_name': 'avadigs'},
#   {'default_profile_image': False,
#    'id': 45411436,
#    'index': 109,
#    'name': 'Malte',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/549269273315528705/RouLc2qh_normal.png',
#    'screen_name': 'XYOU'},
#   {'default_profile_image': False,
#    'id': 25187570,
#    'index': 110,
#    'name': 'theo van veen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000591868880/b4218d0c3ed1f355b8630efe803414ff_normal.jpeg',
#    'screen_name': 'theovv'},
#   {'default_profile_image': False,
#    'id': 24092133,
#    'index': 111,
#    'name': 'nick ruest',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/842569942373347328/UlrQ4KCD_normal.jpg',
#    'screen_name': 'ruebot'},
#   {'default_profile_image': False,
#    'id': 83170793,
#    'index': 112,
#    'name': 'Michael Stevenson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3708722324/db88b85e00e6489d531ef98f355f14c5_normal.jpeg',
#    'screen_name': '_mstevenson'},
#   {'default_profile_image': False,
#    'id': 1836330308,
#    'index': 113,
#    'name': 'Stephanie A Kingsley',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/767900043206537216/GdMbgQR1_normal.jpg',
#    'screen_name': 'KingsleySteph'},
#   {'default_profile_image': False,
#    'id': 373385155,
#    'index': 114,
#    'name': 'Andrea Goethals',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1775755066/Dp01_white_small_normal.png',
#    'screen_name': 'AndreaGoethals'},
#   {'default_profile_image': False,
#    'id': 256118545,
#    'index': 115,
#    'name': 'Norman Meuschke',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/745982367869902848/A1JUKXNM_normal.jpg',
#    'screen_name': 'normeu'},
#   {'default_profile_image': False,
#    'id': 455827771,
#    'index': 116,
#    'name': 'Bela',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000476238431/9d88000e3889e6bf18771991938efebf_normal.jpeg',
#    'screen_name': 'BelaGipp'},
#   {'default_profile_image': False,
#    'id': 1200468920,
#    'index': 117,
#    'name': 'Myriam',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/780532806141304833/J-sI3XW0_normal.jpg',
#    'screen_name': 'MyriamCTraub'},
#   {'default_profile_image': False,
#    'id': 238653576,
#    'index': 118,
#    'name': "Brendan O'Hallarn",
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1218358427/WhiteKnucklesSquare2_normal.jpg',
#    'screen_name': 'White__Knuckles'},
#   {'default_profile_image': False,
#    'id': 168780501,
#    'index': 119,
#    'name': 'TEI Landmark',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/722804725591093249/k0Fi8aH0_normal.jpg',
#    'screen_name': 'TEILandmark'},
#   {'default_profile_image': False,
#    'id': 38438084,
#    'index': 120,
#    'name': 'tmeehleib',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/663796679867539456/cSax5DdB_normal.png',
#    'screen_name': 'tmeehleib'},
#   {'default_profile_image': True,
#    'id': 742243474485956608,
#    'index': 121,
#    'name': 'Mohammad Obaidullah',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#    'screen_name': 'Mohamma47262302'},
#   {'default_profile_image': False,
#    'id': 41353586,
#    'index': 122,
#    'name': 'DBpedia',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/721301450962432000/L9ehCZfC_normal.jpg',
#    'screen_name': 'dbpedia'},
#   {'default_profile_image': False,
#    'id': 326644141,
#    'index': 123,
#    'name': 'aml eyde',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/740846073648939009/uRO1YGQj_normal.jpg',
#    'screen_name': 'amlhasbat'},
#   {'default_profile_image': False,
#    'id': 1009549428,
#    'index': 124,
#    'name': 'Tim Walsh',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834043436634349568/xIUU-7Zc_normal.jpg',
#    'screen_name': 'bitarchivist'},
#   {'default_profile_image': True,
#    'id': 734457556006010885,
#    'index': 125,
#    'name': 'Rebecca Holte',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#    'screen_name': 'rebeccaholte'},
#   {'default_profile_image': False,
#    'id': 173013762,
#    'index': 126,
#    'name': 'Hung V. Do',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/732767610098593792/jxOfVd82_normal.jpg',
#    'screen_name': 'doviethung'},
#   {'default_profile_image': False,
#    'id': 3935341,
#    'index': 127,
#    'name': 'Chris Freeland',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/771773683425746944/0XhwTy28_normal.jpg',
#    'screen_name': 'chrisfreeland'},
#   {'default_profile_image': False,
#    'id': 277409211,
#    'index': 128,
#    'name': 'David Underdown',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1301232266/profile_pic_normal.jpg',
#    'screen_name': 'DavidUnderdown9'},
#   {'default_profile_image': True,
#    'id': 3111336135,
#    'index': 129,
#    'name': 'sooraya sadulla',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#    'screen_name': 'sooraya_sadulla'},
#   {'default_profile_image': False,
#    'id': 415881007,
#    'index': 130,
#    'name': 'Jake Orlowitz',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000605465423/a2cdf125277b292f48ef09aaa9ec78b4_normal.jpeg',
#    'screen_name': 'JakeOrlowitz'},
#   {'default_profile_image': False,
#    'id': 188811710,
#    'index': 131,
#    'name': 'The DLF',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2281460457/kwiy5bwtqifnubwguo4n_normal.jpeg',
#    'screen_name': 'CLIRDLF'},
#   {'default_profile_image': False,
#    'id': 86044173,
#    'index': 132,
#    'name': 'Peeter Rahuvarm',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/496527267/Picture-007_normal.jpg',
#    'screen_name': 'kraabus'},
#   {'default_profile_image': False,
#    'id': 2769879696,
#    'index': 133,
#    'name': 'N J Bingham',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/757564608701923329/_VukIVy-_normal.jpg',
#    'screen_name': 'NicolaJBingham'},
#   {'default_profile_image': False,
#    'id': 90033276,
#    'index': 134,
#    'name': 'Carole Gagné',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/719134990085275648/vOIxcVCc_normal.jpg',
#    'screen_name': 'carole_gagne'},
#   {'default_profile_image': True,
#    'id': 4151123165,
#    'index': 135,
#    'name': 'Fernando Melo',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'Fernando___Melo'},
#   {'default_profile_image': False,
#    'id': 720282585277063168,
#    'index': 136,
#    'name': 'Hugo Viana',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/720721845574594563/7fr-SoUI_normal.jpg',
#    'screen_name': 'HugoAViana'},
#   {'default_profile_image': False,
#    'id': 164478889,
#    'index': 137,
#    'name': 'Ingrid Mason',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/730195200346181632/65zdisgN_normal.jpg',
#    'screen_name': '1n9r1d'},
#   {'default_profile_image': True,
#    'id': 543394546,
#    'index': 138,
#    'name': 'Michelle  M',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#    'screen_name': 'Mittrach_garten'},
#   {'default_profile_image': False,
#    'id': 106677153,
#    'index': 139,
#    'name': 'Arnoud Goos',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/720315609846710272/O90HKTK6_normal.jpg',
#    'screen_name': 'ArnoudGoos'},
#   {'default_profile_image': False,
#    'id': 3042711,
#    'index': 140,
#    'name': 'Mark Graham',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/656968483679305728/fe5IAXyK_normal.jpg',
#    'screen_name': 'MarkGraham'},
#   {'default_profile_image': False,
#    'id': 6021062,
#    'index': 141,
#    'name': 'Holly Croft',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/790361524930015232/Dtj8uuv8_normal.jpg',
#    'screen_name': 'HollyCroft'},
#   {'default_profile_image': False,
#    'id': 46299743,
#    'index': 142,
#    'name': 'SPARC',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/686944586095280128/2qdjeRBm_normal.jpg',
#    'screen_name': 'SPARC_NA'},
#   {'default_profile_image': False,
#    'id': 708538857940070400,
#    'index': 143,
#    'name': 'OAIS du Jour',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/708668570050306048/9i7kDvSk_normal.jpg',
#    'screen_name': 'oaisdujour'},
#   {'default_profile_image': True,
#    'id': 2495140081,
#    'index': 144,
#    'name': 'Karen Vaughan',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'KarenKvaughan'},
#   {'default_profile_image': False,
#    'id': 719570834487144448,
#    'index': 145,
#    'name': 'عبدالاله رحومه',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/719844201945571329/_GvbVmU1_normal.jpg',
#    'screen_name': '6T7VXu11XcTiAbd'},
#   {'default_profile_image': False,
#    'id': 1606632924,
#    'index': 146,
#    'name': 'Daniel Bicho',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/648253528411119616/8gJkwJdb_normal.jpg',
#    'screen_name': 'bicho_daniel'},
#   {'default_profile_image': False,
#    'id': 309420446,
#    'index': 147,
# ...
#    'screen_name': 'atomotic'},
#   {'default_profile_image': False,
#    'id': 14331818,
#    'index': 567,
#    'name': 'Ed Summers',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/803663094777974784/jgMuBer0_normal.jpg',
#    'screen_name': 'edsu'},
#   {'default_profile_image': False,
#    'id': 479894950,
#    'index': 568,
#    'name': 'Mat Kelly',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/598110235920834560/lFLE-mX7_normal.png',
#    'screen_name': 'machawk1'},
#   {'default_profile_image': False,
#    'id': 34713020,
#    'index': 569,
#    'name': 'Kyle Williams',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/676785599693615104/ifMpRS-8_normal.jpg',
#    'screen_name': 'kylewilliams87'},
#   {'default_profile_image': False,
#    'id': 470775438,
#    'index': 570,
#    'name': 'Alisia',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/825152020193619968/yx56M7kr_normal.jpg',
#    'screen_name': 'Alisia1092'},
#   {'default_profile_image': True,
#    'id': 112950384,
#    'index': 571,
#    'name': 'matpre',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#    'screen_name': 'pre11e'},
#   {'default_profile_image': False,
#    'id': 15831818,
#    'index': 572,
#    'name': 'Tyler Walters',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/58153334/tyler0704_normal.jpg',
#    'screen_name': 'tywalters1'},
#   {'default_profile_image': False,
#    'id': 28178451,
#    'index': 573,
#    'name': 'Lee Dirks',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/117754788/Mmm_Beer_normal.jpg',
#    'screen_name': 'ldirks'},
#   {'default_profile_image': False,
#    'id': 413130434,
#    'index': 574,
#    'name': 'jcdl2012',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1640378418/jcdl_logo_normal.gif',
#    'screen_name': 'jcdl2012'},
#   {'default_profile_image': False,
#    'id': 100660566,
#    'index': 575,
#    'name': 'Lisa Lande',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/619247417/landeart_normal.jpg',
#    'screen_name': 'landeart'},
#   {'default_profile_image': False,
#    'id': 411169790,
#    'index': 576,
#    'name': 'John McManus',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1636194783/image_normal.jpg',
#    'screen_name': 'witch_doctor81'},
#   {'default_profile_image': False,
#    'id': 259850415,
#    'index': 577,
#    'name': 'IIPC',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2179744751/IIPC_Twitter_ProfilePic_normal.gif',
#    'screen_name': 'NetPreserve'},
#   {'default_profile_image': False,
#    'id': 402772312,
#    'index': 578,
#    'name': 'NDSA',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/723223701836181505/yShs_hqK_normal.jpg',
#    'screen_name': 'NDSA2'},
#   {'default_profile_image': False,
#    'id': 1711171,
#    'index': 579,
#    'name': 'Peter Keane',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/634320167/Photo_35_normal.jpg',
#    'screen_name': 'pkeane'},
#   {'default_profile_image': False,
#    'id': 5641552,
#    'index': 580,
#    'name': 'Miriam Blake',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/24241162/ebook_normal.jpg',
#    'screen_name': 'meblake'},
#   {'default_profile_image': True,
#    'id': 34698911,
#    'index': 581,
#    'name': 'teknicaldy',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#    'screen_name': 'unknown_6'},
#   {'default_profile_image': True,
#    'id': 387069830,
#    'index': 582,
#    'name': 'Darryl Young',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'BizApproved'},
#   {'default_profile_image': False,
#    'id': 20610488,
#    'index': 583,
#    'name': 'Erik Freiser',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/747217925791055872/2yCk_Uy7_normal.jpg',
#    'screen_name': 'Erikfreiser'},
#   {'default_profile_image': False,
#    'id': 278198164,
#    'index': 584,
#    'name': 'Abdulla Alasaadi',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/838796115742961664/qkOgpCsi_normal.jpg',
#    'screen_name': 'AAlasaadi'},
#   {'default_profile_image': False,
#    'id': 355773903,
#    'index': 585,
#    'name': 'Archive-It',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/750715520534675456/RD0TeRLZ_normal.jpg',
#    'screen_name': 'archiveitorg'},
#   {'default_profile_image': False,
#    'id': 366605043,
#    'index': 586,
#    'name': 'Brooks Childers',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1553616744/110313-133951_normal.jpg',
#    'screen_name': 'awptix'},
#   {'default_profile_image': False,
#    'id': 338504977,
#    'index': 587,
#    'name': 'Kasey McNamara',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1451138485/21980_1391365183312_1207598399_31173717_286737_n_normal.jpg',
#    'screen_name': 'klhiggins33'},
#   {'default_profile_image': False,
#    'id': 35883240,
#    'index': 588,
#    'name': 'Sebastian Resano',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/776206440352677888/hnGSK1Hu_normal.jpg',
#    'screen_name': 'ChuChoResano'},
#   {'default_profile_image': False,
#    'id': 14149525,
#    'index': 589,
#    'name': 'Frank McCown',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2565544139/klyl8kkare4d2vnb6pyg_normal.jpeg',
#    'screen_name': 'fmccown'},
#   {'default_profile_image': False,
#    'id': 14119157,
#    'index': 590,
#    'name': 'diglib',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/634436589855178752/Eo3MdjLI_normal.jpg',
#    'screen_name': 'diglib'},
#   {'default_profile_image': False,
#    'id': 21586018,
#    'index': 591,
#    'name': 'Helen Hockx-Yu',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/612142333065330688/7km0xDHs_normal.jpg',
#    'screen_name': 'hhockx'},
#   {'default_profile_image': False,
#    'id': 77997105,
#    'index': 592,
#    'name': 'Rob Vesse',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000349276734/a092a1a7f910c343f6710554b0fd82b4_normal.jpeg',
#    'screen_name': 'RobVesse'},
#   {'default_profile_image': False,
#    'id': 1701371,
#    'index': 593,
#    'name': 'Andy Jackson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/748614773831516160/lY83E4kt_normal.jpg',
#    'screen_name': 'anjacks0n'},
#   {'default_profile_image': True,
#    'id': 106536714,
#    'index': 594,
#    'name': 'Faryaneh',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#    'screen_name': 'Faryane'},
#   {'default_profile_image': False,
#    'id': 19450230,
#    'index': 595,
#    'name': 'Leslie Johnston',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3213794593/62e2f31b19d414b13dd145c479311ae4_normal.jpeg',
#    'screen_name': 'lljohnston'},
#   {'default_profile_image': False,
#    'id': 337124515,
#    'index': 596,
#    'name': 'Martin Klein',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1446884840/mklein_normal.jpg',
#    'screen_name': 'mart1nkle1n'},
#   {'default_profile_image': False,
#    'id': 320276384,
#    'index': 597,
#    'name': 'MPV SEAT COVERS UK',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1406318434/img2_normal.jpg',
#    'screen_name': 'smartfit_atees'},
#   {'default_profile_image': True,
#    'id': 40903501,
#    'index': 598,
#    'name': 'Richard Furuta',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#    'screen_name': 'furuta'},
#   {'default_profile_image': True,
#    'id': 36045574,
#    'index': 599,
#    'name': 'Ahmed Ghozia',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#    'screen_name': 'Ghozia'},
#   {'default_profile_image': False,
#    'id': 278661116,
#    'index': 600,
#    'name': 'Ahmed AlSum',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1398121692/n586360620_2280741_4881_normal.jpg',
#    'screen_name': 'aalsum'},
#   {'default_profile_image': False,
#    'id': 32495546,
#    'index': 601,
#    'name': 'Joan Smith',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2971076407/6190a113bbf895966099782c23aa171a_normal.png',
#    'screen_name': 'joansm1th'},
#   {'default_profile_image': False,
#    'id': 191032987,
#    'index': 602,
#    'name': 'Martha Anderson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1266727478/Martha_001_crop_normal.PNG',
#    'screen_name': 'MarthaBunton'},
#   {'default_profile_image': False,
#    'id': 132900528,
#    'index': 603,
#    'name': 'Web@rchive Austria',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1019901278/LOGO_kl_swift_normal.png',
#    'screen_name': 'AT_Webarchive'},
#   {'default_profile_image': False,
#    'id': 133035766,
#    'index': 604,
#    'name': 'Sorgente Linda',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1307654561/sorgentlinda_normal.png',
#    'screen_name': 'sorgentelinda'},
#   {'default_profile_image': False,
#    'id': 48082526,
#    'index': 605,
#    'name': 'Abbie Grotke',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1407170838/abportraitiris_normal.jpg',
#    'screen_name': 'agrotke'},
#   {'default_profile_image': False,
#    'id': 264874122,
#    'index': 606,
#    'name': 'Pranay Pramod',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/671750996507365376/OczUtImF_normal.png',
#    'screen_name': 'sspranay'},
#   {'default_profile_image': False,
#    'id': 32747579,
#    'index': 607,
#    'name': 'Scott Ainsworth',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000635279956/062717d96d474df009b302dd65197c91_normal.jpeg',
#    'screen_name': 'Galsondor'},
#   {'default_profile_image': False,
#    'id': 22826489,
#    'index': 608,
#    'name': 'Shawn M. Jones',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/460655715896410113/_ZuI5SPe_normal.jpeg',
#    'screen_name': 'shawnmjones'},
#   {'default_profile_image': False,
#    'id': 7136612,
#    'index': 609,
#    'name': 'James Smith',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/55367959/Photo_6-cropped_normal.jpg',
#    'screen_name': 'jgsmith'},
#   {'default_profile_image': False,
#    'id': 44583052,
#    'index': 610,
#    'name': 'Bernhard Haslhofer',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3372122721/04416e32afd6420d3f3cf0812163dc37_normal.jpeg',
#    'screen_name': 'bhaslhofer'},
#   {'default_profile_image': False,
#    'id': 14077727,
#    'index': 611,
#    'name': 'Sarah Shreeves',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/3161392231/487de8f10fe8f9bb910e46effcbfb19a_normal.jpeg',
#    'screen_name': 'sshreeves'},
#   {'default_profile_image': False,
#    'id': 211104907,
#    'index': 612,
#    'name': 'TagTrees',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1157958643/logo_tag_only_500x500_normal.png',
#    'screen_name': 'TagTrees'},
#   {'default_profile_image': False,
#    'id': 48356887,
#    'index': 613,
#    'name': 'Karim B Boughida',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/616615420565393408/TTXob14b_normal.jpg',
#    'screen_name': 'kboughida'},
#   {'default_profile_image': False,
#    'id': 18638955,
#    'index': 614,
#    'name': 'Moustafa Emara',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1631118205/flight_normal.jpg',
#    'screen_name': 'mousta'},
#   {'default_profile_image': True,
#    'id': 241865283,
#    'index': 615,
#    'name': 'Teri Berg',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#    'screen_name': 'TeriBerg96'},
#   {'default_profile_image': False,
#    'id': 15044465,
#    'index': 616,
#    'name': 'Nicholas Taylor',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/541064285019832320/QivgOAYK_normal.jpeg',
#    'screen_name': 'nullhandle'},
#   {'default_profile_image': False,
#    'id': 71089109,
#    'index': 617,
#    'name': 'Marko A. Rodriguez',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/395313322/exterminator_normal.png',
#    'screen_name': 'twarko'},
#   {'default_profile_image': False,
#    'id': 12509892,
#    'index': 618,
#    'name': 'Kaitlin L. Costello',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/834514964677160962/bRYViWNQ_normal.jpg',
#    'screen_name': 'k8lin'},
#   {'default_profile_image': False,
#    'id': 205922124,
#    'index': 619,
#    'name': 'OFFTHEHOOK',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1149731517/smallothlogo_normal.jpg',
#    'screen_name': 'OTHSEAFOOD'},
#   {'default_profile_image': False,
#    'id': 17002009,
#    'index': 620,
#    'name': 'Gene Golovchinsky',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/384632718/LW3N3435-crop_normal.jpg',
#    'screen_name': 'HCIR_GeneG'},
#   {'default_profile_image': False,
#    'id': 201612370,
#    'index': 621,
#    'name': 'Hany SalahEldeen',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/589006417966850048/oS_M-9wr_normal.jpg',
#    'screen_name': 'hanysalaheldeen'},
#   {'default_profile_image': False,
#    'id': 14320209,
#    'index': 622,
#    'name': 'Patrick Hochstenbach',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/483484131427229699/zeLlmy4j_normal.jpeg',
#    'screen_name': 'hochstenbach'},
#   {'default_profile_image': False,
#    'id': 8500742,
#    'index': 623,
#    'name': 'Carlton Northern',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/732036478784708608/djVrvXp9_normal.jpg',
#    'screen_name': 'carltonnorthern'},
#   {'default_profile_image': False,
#    'id': 17369964,
#    'index': 624,
#    'name': 'John S. Erickson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1205664680/erickson_twit_normal.jpg',
#    'screen_name': 'olyerickson'},
#   {'default_profile_image': False,
#    'id': 55361508,
#    'index': 625,
#    'name': 'William J Nixon',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/305911187/william_normal.jpg',
#    'screen_name': 'williamjnixon'},
#   {'default_profile_image': False,
#    'id': 180473295,
#    'index': 626,
#    'name': 'Justin F Brunelle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/643489094476132353/lWNbAJj3_normal.jpg',
#    'screen_name': 'justinfbrunelle'},
#   {'default_profile_image': False,
#    'id': 75550501,
#    'index': 627,
#    'name': 'Michele Weigle',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/466648768389980160/3m8QCmnl_normal.jpeg',
#    'screen_name': 'weiglemc'},
#   {'default_profile_image': False,
#    'id': 16464166,
#    'index': 628,
#    'name': 'Uma Murthy',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/66818453/uma_normal.JPG',
#    'screen_name': 'umurthy'},
#   {'default_profile_image': False,
#    'id': 17163698,
#    'index': 629,
#    'name': 'Bill LeFurgy',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/422052725459668992/vJ4zBpAw_normal.jpeg',
#    'screen_name': 'blefurgy'},
#   {'default_profile_image': True,
#    'id': 123740183,
#    'index': 630,
#    'name': 'Julianne Allen',
#    'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#    'screen_name': 'Julibabe21'},
#   {'default_profile_image': False,
#    'id': 20148603,
#    'index': 631,
#    'name': 'Rob Sanderson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/759196947567697920/ZgO6hvaH_normal.jpg',
#    'screen_name': 'azaroth42'},
#   {'default_profile_image': False,
#    'id': 90083746,
#    'index': 632,
#    'name': 'Herbert',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/844985057811054592/y1eCtANW_normal.jpg',
#    'screen_name': 'hvdsomp'},
#   {'default_profile_image': False,
#    'id': 11137722,
#    'index': 633,
#    'name': 'cathy marshall',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1802710015/me-blurry_normal.jpg',
#    'screen_name': 'ccmarshall'},
#   {'default_profile_image': False,
#    'id': 151901549,
#    'index': 634,
#    'name': 'Michael L. Nelson',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/959295176/mln-ad-100x130_normal.jpg',
#    'screen_name': 'phonedude_mln'}]}

# %%
import networkx as nx
from networkx.readwrite import json_graph

G = json_graph.node_link_graph(data,
                       directed=True,
                       attrs=dict(
                               id='id',
                               key='id',
                               name='name',
                               screen_name='screen_name',
                               image='profile_image_url',
                               source='source',
                               target='target'
                           )
                      )
# this d3 example uses the name attribute for the mouse-hover value,
# so add a name to each node
#for n in G:
#    G.node[n]['name'] = n
# write json formatted data
d = json_graph.node_link_data(G) # node-link format to serialize
# write json
json.dump(d, open('force/force.json','w'))

# %% [markdown]
# &nbsp;
#
# Using `%%javascript` magic load the D3 requirements. Add an `element` to allow for embedding the chart.
#
#
# &nbsp;

# %%
# %%javascript
#
# require.config({
#     paths: {
#         d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.4.8/d3.min'
#     }
# });
#
# element.append("<center><div id='chart'></div></center><style> circle.node { stroke: #fff; stroke-width: 1.5px; } line.link { stroke: #999; stroke-opacity: .6; } </style>");

# %% [markdown]
# &nbsp;
#
# Use string formatting to insert any variables into the javascript.
#
# &nbsp;

# %%
from IPython.display import Javascript

# Modified from http://mbostock.github.com/d3/ex/force.html
Javascript("""
//Constants for the SVG
var w = 800,
    h = 800,
    //Set up the colour scale
    fill = d3.scale.category20();

//Append a SVG to the body of the html page. Assign this SVG as an object to svg
var vis = d3.select("#chart")
  .append("svg:svg")
    .attr("width", w)
    .attr("height", h);

//Set up the force layout
//Creates the graph data structure out of the json data
d3.json("force/force.json", function(json) {
  var force = d3.layout.force()
      .charge(-120)
      .linkDistance(30)
      .nodes(json.nodes)
      .links(json.links)
      .size([w, h])
      .start();

  //Create all the line svgs but without locations yet
  var link = vis.selectAll("line.link")
      .data(json.links)
    .enter().append("svg:line")
      .attr("class", "link")
      .style("stroke-width", function(d) { return Math.sqrt(d.value); })
      .attr("x1", function(d) { return d.source.x; })
      .attr("y1", function(d) { return d.source.y; })
      .attr("x2", function(d) { return d.target.x; })
      .attr("y2", function(d) { return d.target.y; });

  //Do the same with the circles for the nodes - no 
  var node = vis.selectAll("circle.node")
      .data(json.nodes)
    .enter().append("svg:circle")
      .attr("class", "node")
      .attr("cx", function(d) { return d.x; })
      .attr("cy", function(d) { return d.y; })
      .attr("r", 5)
      .style("fill", function(d) { return fill(d.group); })
      .call(force.drag);

  node.append("image")
      .attr("xlink:href", "https://github.com/favicon.ico")
      .attr("x", -8)
      .attr("y", -8)
      .attr("width", 16)
      .attr("height", 16);

  node.append("svg:title")
      .text(function(d) { return d.name; });

  vis.style("opacity", 1e-6)
    .transition()
      .duration(1000)
      .style("opacity", 1);

  //Now we are giving the SVGs co-ordinates - the force layout is generating 
  //the co-ordinates which this code is using to update the attributes of the SVG elements
  force.on("tick", function() {
    link.attr("x1", function(d) { return d.source.x; })
        .attr("y1", function(d) { return d.source.y; })
        .attr("x2", function(d) { return d.target.x; })
        .attr("y2", function(d) { return d.target.y; });

    node.attr("cx", function(d) { return d.x; })
        .attr("cy", function(d) { return d.y; });
  });
});
""")
