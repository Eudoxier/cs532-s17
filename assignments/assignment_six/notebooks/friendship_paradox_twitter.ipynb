# %% [markdown]
# # Get Data for D3 Graphing
#
# -------------------------------------------------
#
# The raw code for this Jupyter notebook is by default hidden for easier reading. The main focus of this particular page of the notebook is on the graphs and their interpretation. To toggle on/off the raw code, click below:

# %%
# Setup Code toggle button
from IPython.core.display import HTML  

HTML(''' 
<center><h3>
<a href="javascript:code_toggle()">Talk is cheap, show me the code.</a>
</center></h3>
<script>
    var code_show=true; //true -> hide code at first

    function code_toggle() {
        $('div.prompt').hide(); // always hide prompt

        if (code_show){
            $('div.input').hide();
        } else {
            $('div.input').show();
        }
        code_show = !code_show
    }
    $( document ).ready(code_toggle);
</script>
''')
# Out:
#
# <center><h3>
# <a href="javascript:code_toggle()">Talk is cheap, show me the code.</a>
# </center></h3>
# <script>
#     var code_show=true; //true -> hide code at first
#
#     function code_toggle() {
#         $('div.prompt').hide(); // always hide prompt
#
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
# </script>

# %%
# Setup notebook theme
from jupyterthemes import get_themes
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme(get_themes()[1])
# Out:
# <style> @font-face {
#  font-family: 'Droid Sans Mono';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Droid Sans Mono'), url('fonts/droid-sans-mono.woff') format('woff');
# }
# @font-face {
#  font-family: 'Exo_2';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Exo_2'), url('fonts/exo-II-regular.ttf') format('truetype');
# }
# @font-face {
#  font-family: 'Fira Code';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Fira Code'), url('fonts/firacode.otf') format('opentype');
# }
# @font-face {
#  font-family: 'Lora';
#  font-weight: normal;
#  font-style: normal;
#  src: local('Lora'), url('fonts/Lora-Regular.ttf') format('truetype');
# }
# div#notebook {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #303030;
# }
# body,
# div.body {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  color: #303030;
#  background-color: #ffffff;
#  background: #ffffff;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #ffffff;
#  background: #ffffff;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: "Exo_2", sans-serif;
#  color: #303030;
# }
# a:hover,
# a:focus {
#  color: #2f2f2f;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #2f2f2f;
#  background-color: #ffffff;
# }
# div#cluster_list_header.row.list_header,
# div#running .row.list_header {
#  font-size: 14pt;
#  color: #303030;
#  background: #eeeeee;
#  background-color: #eeeeee;
#  border-bottom: 2px solid rgba(180,180,180,.30);
# }
# div#cluster_list > div.list_item.row,
# div#cluster_list > div.list_item.row:hover {
#  background: #f7f7f7;
#  background-color: #f7f7f7;
# }
# div#clusters.tab-pane.active {
#  font-size: 12.0pt;
#  padding: 4px 0 4px 0;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #303030;
#  padding: 8px 8px;
#  background: #eeeeee;
#  background-color: #eeeeee;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #303030;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #303030;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #f7f7f7;
#  background-color: #f7f7f7;
#  padding: 2px;
#  border-bottom: 2px solid rgba(180,180,180,.30);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #f7f7f7;
#  background-color: #f7f7f7;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# div.running_list_info.toolbar_info {
#  font-size: 12.0pt;
#  padding: 4px 0 4px 0;
#  height: inherit;
#  line-height: inherit;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #ff7823;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# #project_name {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  margin-bottom: -20px;
#  text-align: -webkit-auto;
#  vertical-align: text-top;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: "Exo_2", sans-serif;
#  font-size: 12.0pt;
# }
# .toolbar_info {
#  font-family: "Exo_2", sans-serif;
#  font-size: 12.0pt;
#  color: #303030;
#  text-shadow: none;
#  border: none;
#  height: inherit;
#  line-height: inherit;
# }
# .list_container {
#  font-size: 12.0pt;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(180,180,180,.14);
#  font-size: 12.0pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-left: 0px;
# }
# .list_header > div input,
# .list_item > div input {
#  top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 12.0pt;
# }
# .item_icon {
#  font-size: 12.0pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: auto;
#  width: 20%;
#  margin: 6px 0 0;
#  margin-top: 1px;
# }
# #button-select-all {
#  height: auto;
#  font-size: 12.0pt;
#  padding: 5px;
#  min-width: 65px;
#  z-index: 0;
# }
# button#tree-selector-btn {
#  height: auto;
#  font-size: 12.0pt;
#  padding: 5px;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 5px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin: 6px 0 0;
#  margin-top: 1px;
#  line-height: normal;
# }
# .list_container a {
#  font-size: 17px;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #2f2f2f;
# }
# div.list_item:hover {
#  background-color: #fafafa;
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #303030;
#  border: none;
#  text-shadow: none !important;
# }
# ul#tabs a {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  font-weight: normal;
#  font-style: normal;
#  border-color: transparent;
#  text-shadow: none !important;
# }
# .nav-tabs {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  font-weight: normal;
#  font-style: normal;
#  background: #ffffff;
#  text-shadow: none !important;
#  border-color: transparent;
#  border-bottom-color: rgba(180,180,180,.30);
# }
# .nav-tabs > li > a:hover {
#  color: #2f2f2f;
#  background-color: rgba(180,180,180,.14);
# }
# .nav-tabs > li > a:active,
# .nav-tabs > li > a:focus,
# .nav-tabs > li.active > a,
# .nav-tabs > li.active > a:focus,
# .nav-tabs > li.active > a:hover,
# .nav-tabs > li.active > a,
# .nav-tabs > li.active > a:hover,
# .nav-tabs > li.active > a:focus {
#  color: #1c1c1c;
#  background-color: #eeeeee;
#  border: 1px solid transparent;
#  border-bottom-color: transparent;
#  cursor: default;
# }
# .nav > li > a:hover,
# .nav > li > a:focus {
#  text-decoration: none;
#  background-color: rgba(180,180,180,.14);
# }
# .nav > li.disabled > a,
# .nav > li.disabled > a:hover {
#  color: #aaaaaa;
# }
# div#notebook {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  padding-top: 4px;
# }
# .notebook_app {
#  background-color: #ffffff;
# }
# #notebook-container {
#  padding: 13px;
#  background-color: #ffffff;
#  min-height: 0px;
#  box-shadow: none;
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
# }
# div#ipython-main-app.container {
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
#  margin-right: auto;
#  margin-left: auto;
# }
# .container {
#  width: 980px;
#  margin-right: auto;
#  margin-left: auto;
# }
# .notebook_app #header {
#  box-shadow: none !important;
#  background-color: #ffffff;
#  border-bottom: 2px solid rgba(180,180,180,.14);
# }
# #header {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  box-shadow: none;
#  background-color: #ffffff;
# }
# #header .header-bar {
#  background: #ffffff;
#  background-color: #ffffff;
# }
# body > #header .header-bar {
#  width: 100%;
#  background: #ffffff;
# }
# #menubar {
#  background-color: #ffffff;
# }
# #menubar .navbar,
# .navbar-default {
#  background-color: #ffffff;
#  margin-bottom: 0px;
# }
# .navbar {
#  border: none;
# }
# .navbar-default {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  background-color: #ffffff;
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
#  padding-bottom: 0px;
# }
# .navbar-default .navbar-nav > li > a {
#  font-family: "Exo_2", sans-serif;
#  font-size: 13pt;
#  color: #303030;
#  display: block;
#  line-height: 1.5em;
#  padding-top: 8px;
#  padding-bottom: 6px;
# }
# .navbar-default .navbar-nav > li > a:hover,
# .navbar-default .navbar-nav > li > a:focus {
#  color: #2f2f2f;
#  background-color: rgba(180,180,180,.14);
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
# }
# .navbar-default .navbar-nav > .open > a,
# .navbar-default .navbar-nav > .open > a:hover,
# .navbar-default .navbar-nav > .open > a:focus {
#  color: #1c1c1c;
#  background-color: rgba(180,180,180,.14);
#  border-color: rgba(180,180,180,.14);
#  line-height: 1.5em;
# }
# .edit_mode .modal_indicator:before {
#  font-size: 13pt;
#  color: #2c85f7;
#  content: "\f040";
# }
# .item_icon {
#  color: #126dce;
# }
# .item_buttons .kernel-name {
#  font-size: 13pt;
#  color: #126dce;
#  line-height: 22px;
# }
# .running_notebook_icon:before {
#  color: #009e07 !important;
# }
# .item_buttons .running-indicator {
#  padding-top: 2px;
#  color: #009e07;
# }
# #modal_indicator {
#  float: right !importan

# %% [markdown]
# &nbsp;
#
# ## Get the Data
#
# For a list of `python-twitter` `User` class attributes see: [https://python-twitter.readthedocs.io/en/latest/_modules/twitter/models.html#User.NewFromJsonDict](https://python-twitter.readthedocs.io/en/latest/_modules/twitter/models.html#User.NewFromJsonDict).
#
# First fetch friends using [GET followers](https://dev.twitter.com/rest/reference/get/followers/list).
#
# &nbsp;

# %%
from followers import Followers

uid = 151901549
f = Followers(uid)
users = f.api.GetFollowers(uid)

users
# Out:
# [User(ID=59860290, ScreenName=ryacca),
#  User(ID=9421452, ScreenName=shebin),
#  User(ID=265517884, ScreenName=ycpdan),
#  User(ID=3979114762, ScreenName=BexAnnalisa),
#  User(ID=756135755190198273, ScreenName=degruyter_lib),
#  User(ID=3158073120, ScreenName=mixnode),
#  User(ID=481260788, ScreenName=no_identd),
#  User(ID=1429810189, ScreenName=JCrueger),
#  User(ID=4008474733, ScreenName=lissertations),
#  User(ID=821042028800802816, ScreenName=Grant_ODU),
#  User(ID=827268804359053313, ScreenName=mmicros1),
#  User(ID=789293970677456896, ScreenName=74paddycakes),
#  User(ID=799272100599046145, ScreenName=digitopia_nl),
#  User(ID=203096228, ScreenName=PruittAL),
#  User(ID=81650379, ScreenName=brendaberkelaar),
#  User(ID=47899646, ScreenName=CassPF),
#  User(ID=899863316, ScreenName=OKMotovlog),
#  User(ID=30802131, ScreenName=mekonkol),
#  User(ID=761396027446398976, ScreenName=Stesker3D),
#  User(ID=825218681252765696, ScreenName=HussamHallak1),
#  User(ID=20255236, ScreenName=carolc16),
#  User(ID=825049390998024192, ScreenName=printuu),
#  User(ID=733536950963994624, ScreenName=dtscnc),
#  User(ID=737852660183932928, ScreenName=Tunaz_Islam),
#  User(ID=9630082, ScreenName=MeredithA),
#  User(ID=258599525, ScreenName=MeghanHoyer),
#  User(ID=3122708646, ScreenName=AntonJRasmussen),
#  User(ID=1634706151, ScreenName=LuytenBram),
#  User(ID=399805362, ScreenName=MohdKamal6),
#  User(ID=269424738, ScreenName=pmyoung84),
#  User(ID=810540893396733953, ScreenName=Karki693),
#  User(ID=1119502988, ScreenName=BL_Labs),
#  User(ID=783440136, ScreenName=IntelligenceTV),
#  User(ID=808893873766432768, ScreenName=maheedhargunnam),
#  User(ID=58880930, ScreenName=nattiyak),
#  User(ID=47985362, ScreenName=marcinwilkowski),
#  User(ID=801186507931455488, ScreenName=minornotez),
#  User(ID=19203768, ScreenName=katestarbird),
#  User(ID=2190533245, ScreenName=ACMSIGIR),
#  User(ID=89504686, ScreenName=claussni),
#  User(ID=192964243, ScreenName=njcomputergroup),
#  User(ID=113647306, ScreenName=ARLIS_NY),
#  User(ID=2936496598, ScreenName=artlibrariannyc),
#  User(ID=3281181511, ScreenName=Wikicite),
#  User(ID=258032124, ScreenName=ChiefScientist),
#  User(ID=3447506422, ScreenName=ODUPeninsulaCtr),
#  User(ID=16564030, ScreenName=lmercereau),
#  User(ID=30047063, ScreenName=Hindawi),
#  User(ID=1695487818, ScreenName=es_land),
#  User(ID=2973715954, ScreenName=KennyDiedrich),
#  User(ID=774187456191160320, ScreenName=JDecourselle),
#  User(ID=3849211272, ScreenName=RikerHampton),
#  User(ID=57750231, ScreenName=ODUAlumni),
#  User(ID=19258241, ScreenName=pampel),
#  User(ID=146209930, ScreenName=stierholz),
#  User(ID=4481168962, ScreenName=salamancaschool),
#  User(ID=16868154, ScreenName=arjenpdevries),
#  User(ID=3354096993, ScreenName=HBee2015),
#  User(ID=193063049, ScreenName=subsublibrary),
#  User(ID=468735081, ScreenName=jubrogers),
#  User(ID=138161380, ScreenName=mbutel),
#  User(ID=17271698, ScreenName=detailmatters),
#  User(ID=3365719153, ScreenName=acquire_UCLA),
#  User(ID=74541831, ScreenName=kzwa),
#  User(ID=5894872, ScreenName=lysander07),
#  User(ID=13645402, ScreenName=ChrisAldrich),
#  User(ID=729223119030751232, ScreenName=sheershasamach1),
#  User(ID=739900844531974144, ScreenName=jcdl2017),
#  User(ID=1668275245, ScreenName=permacc),
#  User(ID=781886520978444288, ScreenName=KhTalha6),
#  User(ID=570294703, ScreenName=Jack_Stran),
#  User(ID=24713262, ScreenName=AngelaWoodall),
#  User(ID=66188615, ScreenName=bruno_leonard_),
#  User(ID=774263152544452608, ScreenName=datacartel1),
#  User(ID=2806160786, ScreenName=RJIJDNA),
#  User(ID=1551367058, ScreenName=FredericikB),
#  User(ID=2852131203, ScreenName=pvanhaitsma),
#  User(ID=4508117621, ScreenName=robin_ruggaber),
#  User(ID=237086573, ScreenName=Cee_Finley),
#  User(ID=161598558, ScreenName=woilgoo),
#  User(ID=11164692, ScreenName=seamuslawless),
#  User(ID=737342173079736321, ScreenName=KevinLevrone3),
#  User(ID=4738176435, ScreenName=Mementoweb),
#  User(ID=7377862, ScreenName=cazzerson),
#  User(ID=833373624, ScreenName=foucaultwelles),
#  User(ID=1393107912, ScreenName=mdzellerCDAL),
#  User(ID=48592998, ScreenName=robinmkatz),
#  User(ID=3321913552, ScreenName=mrchyr),
#  User(ID=134569763, ScreenName=mre1920),
#  User(ID=3412095995, ScreenName=saadaitomation),
#  User(ID=729563714475700224, ScreenName=jessicasmith541),
#  User(ID=267189586, ScreenName=bumdots4eva),
#  User(ID=605923, ScreenName=walkeroh),
#  User(ID=3189940844, ScreenName=CRajaharsha),
#  User(ID=14338221, ScreenName=infod1va),
#  User(ID=33736942, ScreenName=lili_czarina),
#  User(ID=745643383188758528, ScreenName=Oorlogsbronnen),
#  User(ID=745385398134661120, ScreenName=annika_hinze),
#  User(ID=18957805, ScreenName=internetarchive),
#  User(ID=708690890974470145, ScreenName=mridulish),
#  User(ID=118078818, ScreenName=Dr_Abomohra),
#  User(ID=220983330, ScreenName=helgeho),
#  User(ID=9308852, ScreenName=idokius),
#  User(ID=744784018919432194, ScreenName=zhaohuan_wang),
#  User(ID=4497126976, ScreenName=PolitAdArchive),
#  User(ID=7591252, ScreenName=nwatzman),
#  User(ID=24257870, ScreenName=John_B_Howard),
#  User(ID=753571748860293120, ScreenName=CScoutTech),
#  User(ID=2416303724, ScreenName=avadigs),
#  User(ID=45411436, ScreenName=XYOU),
#  User(ID=25187570, ScreenName=theovv),
#  User(ID=24092133, ScreenName=ruebot),
#  User(ID=83170793, ScreenName=_mstevenson),
#  User(ID=1836330308, ScreenName=KingsleySteph),
#  User(ID=373385155, ScreenName=AndreaGoethals),
#  User(ID=256118545, ScreenName=normeu),
#  User(ID=455827771, ScreenName=BelaGipp),
#  User(ID=1200468920, ScreenName=MyriamCTraub),
#  User(ID=238653576, ScreenName=White__Knuckles),
#  User(ID=168780501, ScreenName=TEILandmark),
#  User(ID=38438084, ScreenName=tmeehleib),
#  User(ID=742243474485956608, ScreenName=Mohamma47262302),
#  User(ID=41353586, ScreenName=dbpedia),
#  User(ID=326644141, ScreenName=amlhasbat),
#  User(ID=1009549428, ScreenName=bitarchivist),
#  User(ID=734457556006010885, ScreenName=rebeccaholte),
#  User(ID=173013762, ScreenName=doviethung),
#  User(ID=3935341, ScreenName=chrisfreeland),
#  User(ID=277409211, ScreenName=DavidUnderdown9),
#  User(ID=3111336135, ScreenName=sooraya_sadulla),
#  User(ID=415881007, ScreenName=JakeOrlowitz),
#  User(ID=188811710, ScreenName=CLIRDLF),
#  User(ID=86044173, ScreenName=kraabus),
#  User(ID=2769879696, ScreenName=NicolaJBingham),
#  User(ID=90033276, ScreenName=carole_gagne),
#  User(ID=4151123165, ScreenName=Fernando___Melo),
#  User(ID=720282585277063168, ScreenName=HugoAViana),
#  User(ID=164478889, ScreenName=1n9r1d),
#  User(ID=543394546, ScreenName=Mittrach_garten),
#  User(ID=106677153, ScreenName=ArnoudGoos),
#  User(ID=3042711, ScreenName=MarkGraham),
#  User(ID=6021062, ScreenName=HollyCroft),
#  User(ID=46299743, ScreenName=SPARC_NA),
#  User(ID=708538857940070400, ScreenName=oaisdujour),
#  User(ID=2495140081, ScreenName=KarenKvaughan),
#  User(ID=719570834487144448, ScreenName=6T7VXu11XcTiAbd),
#  User(ID=1606632924, ScreenName=bicho_daniel),
#  User(ID=309420446, ScreenName=abziegler),
#  User(ID=1480422979, ScreenName=TueHLarsen),
#  User(ID=15042751, ScreenName=lookouthoney),
#  User(ID=50379684, ScreenName=hollips),
#  User(ID=782931, ScreenName=GardnerCampbell),
#  User(ID=115917954, ScreenName=Miel_vds),
#  User(ID=127125266, ScreenName=peripatesis),
#  User(ID=2473528178, ScreenName=dswarm),
#  User(ID=54493821, ScreenName=Manoj_Chandra11),
#  User(ID=305614894, ScreenName=DevAhmedhosni),
#  User(ID=118623489, ScreenName=dineshpaladhi),
#  User(ID=376298824, ScreenName=noumenal_woman),
#  User(ID=704273004717613056, ScreenName=rdayMedia),
#  User(ID=1133038710, ScreenName=ErichdotPy),
#  User(ID=1299060908, ScreenName=DanKerchner),
#  User(ID=2586364634, ScreenName=risse691),
#  User(ID=702963405364322306, ScreenName=IuliaCristina12),
#  User(ID=198925162, ScreenName=fromADMwithlove),
#  User(ID=4925540277, ScreenName=AndreeaCorinaM2),
#  User(ID=22277220, ScreenName=PSleeman),
#  User(ID=4879994613, ScreenName=Shaaban_Migo),
#  User(ID=14807028, ScreenName=knmnyn),
#  User(ID=4856503619, ScreenName=mgome0072),
#  User(ID=157985123, ScreenName=majetisiri),
#  User(ID=48378958, ScreenName=futuresma),
#  User(ID=701725615603347457, ScreenName=dhombe3),
#  User(ID=2601589496, ScreenName=SIGIR17),
#  User(ID=1327778215, ScreenName=lmaccork),
#  User(ID=698172818563952640, ScreenName=LarryWilson1942),
#  User(ID=3060184494, ScreenName=JayNuetron),
#  User(ID=4897300665, ScreenName=wospworkshop),
#  User(ID=516787981, ScreenName=NetLab_dk),
#  User(ID=160436528, ScreenName=SalimChemlal),
#  User(ID=386532355, ScreenName=EmeraldIKM),
#  User(ID=42914077, ScreenName=ShathaJY),
#  User(ID=110800099, ScreenName=CrowNaito),
#  User(ID=122038961, ScreenName=EmeraldLibrary),
#  User(ID=4869611475, ScreenName=clem_kev),
#  User(ID=4845001934, ScreenName=digiarchiveteam),
#  User(ID=798668178, ScreenName=9ulovesu),
#  User(ID=3485785534, ScreenName=manoj_chandra_k),
#  User(ID=707840696, ScreenName=landlibrarian),
#  User(ID=203024977, ScreenName=CodioHQ),
#  User(ID=4844579470, ScreenName=johnaberlin),
#  User(ID=14298448, ScreenName=ryanfb),
#  User(ID=25469726, ScreenName=andrewjbtw),
#  User(ID=3436812551, ScreenName=documentnow),
#  User(ID=2830868675, ScreenName=elizhoagcarhart),
#  User(ID=284205655, ScreenName=erikaris),
#  User(ID=4738279701, ScreenName=DanMilanko),
#  User(ID=110465562, ScreenName=j_w_baker),
#  User(ID=2374377426, ScreenName=archivportal),
#  User(ID=127005958, ScreenName=desouzatech),
#  User(ID=10034972, ScreenName=tjowens),
#  User(ID=21789681, ScreenName=badgerhartman),
#  User(ID=2525306964, ScreenName=TrueHiddenFact),
#  User(ID=15970999, ScreenName=keesone),
#  User(ID=2812268522, ScreenName=impactzoneco),
#  User(ID=583619284, ScreenName=KarolHolu),
#  User(ID=727549675, ScreenName=topgolfvabeach),
#  User(ID=4242196667, ScreenName=JohnChangGWU),
#  User(ID=4208606734, ScreenName=icdm2016),
#  User(ID=1121591, ScreenName=mamund),
#  User(ID=4167895879, ScreenName=brijmohanrana4),
#  User(ID=4111220189, ScreenName=imafuturemedic),
#  User(ID=14121668, ScreenName=euanc),
#  User(ID=117267879, ScreenName=dwhitenist),
#  User(ID=191532379, ScreenName=samalanmeister),
#  User(ID=24086900, ScreenName=shirapeltzman),
#  User(ID=10011252, ScreenName=iamtimmo),
#  User(ID=381480281, ScreenName=J_IreneTieman),
#  User(ID=46276118, ScreenName=dmimno),
#  User(ID=2375877384, ScreenName=Pravacana_Mats),
#  User(ID=4058321, ScreenName=daniel_rehn),
#  User(ID=207756340, ScreenName=wwwtxt),
#  User(ID=6758652, ScreenName=docmattweber),
#  User(ID=37367357, ScreenName=fzaker),
#  User(ID=2313982910, ScreenName=ODUAuxServices),
#  User(ID=234090209, ScreenName=skhartmann),
#  User(ID=3951215081, ScreenName=crobinj7074),
#  User(ID=1080065808, ScreenName=Educopia),
#  User(ID=8273852, ScreenName=silvertje),
#  User(ID=3439046147, ScreenName=kaylamarie0110),
#  User(ID=1625743328, ScreenName=WolframElvis),
#  User(ID=153136109, ScreenName=cbmrccc),
#  User(ID=1426135280, ScreenName=zeonfernando),
#  User(ID=245981438, ScreenName=Thaer_samar),
#  User(ID=20585553, ScreenName=alexwade),
#  User(ID=3715588822, ScreenName=WeskerAlbert777),
#  User(ID=3309403210, ScreenName=TPDL2016),
#  User(ID=97436767, ScreenName=ijdl),
#  User(ID=3405639663, ScreenName=jcdl2016),
#  User(ID=36016976, ScreenName=jessili),
#  User(ID=22898537, ScreenName=anatbd),
#  User(ID=3609133037, ScreenName=JoeLemanski),
#  User(ID=20361039, ScreenName=rwincewicz),
#  User(ID=22981285, ScreenName=gjfowler),
#  User(ID=218433245, ScreenName=GraemeEarl),
#  User(ID=36299530, ScreenName=e_mccain),
#  User(ID=41181426, ScreenName=karensnet),
#  User(ID=77531826, ScreenName=involutish),
#  User(ID=3431446607, ScreenName=hdo003),
#  User(ID=3314095728, ScreenName=Naima3704),
#  User(ID=29202483, ScreenName=masroorfreaks),
#  User(ID=3354261519, ScreenName=HamptonRFinest),
#  User(ID=414952959, ScreenName=kennethec1),
#  User(ID=3384538947, ScreenName=oso525gang),
#  User(ID=116974911, ScreenName=vincelebow),
#  User(ID=3263081858, ScreenName=andy_anjoyh),
#  User(ID=2818832635, ScreenName=BrosephElder),
#  User(ID=3271976762, ScreenName=kingswebit),
#  User(ID=16510252, ScreenName=goodenjm),
#  User(ID=34775622, ScreenName=vneblitt),
#  User(ID=584435817, ScreenName=KyleFJackson),
#  User(ID=2396255567, ScreenName=FFuqiang),
#  User(ID=175805760, ScreenName=TaksNz),
#  User(ID=71060978, ScreenName=ziadmatni),
#  User(ID=41493671, ScreenName=westfood),
#  User(ID=863233914, ScreenName=OpenMaze),
#  User(ID=32872183, ScreenName=BrianDavison),
#  User(ID=2991697611, ScreenName=nanopub_org),
#  User(ID=1281526188, ScreenName=txkuhn),
#  User(ID=1094340541, ScreenName=syamiliC),
#  User(ID=93601638, ScreenName=maikhanhlam),
#  User(ID=3317325347, ScreenName=katjakra),
#  User(ID=3241373905, ScreenName=NgYewli),
#  User(ID=6785192, ScreenName=paulwalk),
#  User(ID=145310513, ScreenName=f_nanni),
#  User(ID=1253356783, ScreenName=trinketapp),
#  User(ID=315217260, ScreenName=nichworby),
#  User(ID=30213942, ScreenName=thefaisalahmad),
#  User(ID=68329262, ScreenName=rundavidrun),
#  User(ID=2437409755, ScreenName=ODURugby_),
#  User(ID=26476281, ScreenName=NielsBr),
#  User(ID=14915653, ScreenName=kurtluther),
#  User(ID=333243023, ScreenName=Arkivum),
#  User(ID=45610433, ScreenName=vector_ctrl),
#  User(ID=265772335, ScreenName=calpopp),
#  User(ID=14559196, ScreenName=palewire),
#  User(ID=19648979, ScreenName=JoshCowls),
#  User(ID=3010944035, ScreenName=JS_Smith_71),
#  User(ID=1329490188, ScreenName=downey_cara),
#  User(ID=2343706932, ScreenName=Reloaded2Boot),
#  User(ID=114485232, ScreenName=lintool),
#  User(ID=37421242, ScreenName=johanna_lautner),
#  User(ID=11406742, ScreenName=uskudarli),
#  User(ID=145084142, ScreenName=felipebravom),
#  User(ID=212331168, ScreenName=seahorseadmirer),
#  User(ID=7841792, ScreenName=SteveMcLaugh),
#  User(ID=2780719273, ScreenName=lestextesR),
#  User(ID=1059046910, ScreenName=ArchivingIt),
#  User(ID=30339571, ScreenName=elunca),
#  User(ID=84714362, ScreenName=rosalielack),
#  User(ID=9280142, ScreenName=williamjturkel),
#  User(ID=24961156, ScreenName=ekansa),
#  User(ID=3161452212, ScreenName=AliShamim333),
#  User(ID=2347676396, ScreenName=beyondcitation),
#  User(ID=2787495858, ScreenName=cklk90),
#  User(ID=18485152, ScreenName=bertramlyons),
#  User(ID=3124460498, ScreenName=JStoddert),
#  User(ID=17886323, ScreenName=continuants),
#  User(ID=807717, ScreenName=tsuomela),
#  User(ID=2800045236, ScreenName=SarahBellefleur),
#  User(ID=14676851, ScreenName=DataG),
#  User(ID=36650845, ScreenName=narfman0),
#  User(ID=1862092890, ScreenName=CorrenMcCoy),
#  User(ID=3094776599, ScreenName=wosp2015),
#  User(ID=2412876546, ScreenName=BeeneSteph),
#  User(ID=3077057645, ScreenName=PapachriL),
#  User(ID=398540128, ScreenName=MPanula),
#  User(ID=15842692, ScreenName=JenServenti),
#  User(ID=2332202281, ScreenName=HistWebArchives),
#  User(ID=2810690756, ScreenName=shajid333),
#  User(ID=275243623, ScreenName=prwheatley),
#  User(ID=471700298, ScreenName=JonesWCaleb),
#  User(ID=2825370151, ScreenName=ELittley),
#  User(ID=2986305078, ScreenName=JCDLConf),
#  User(ID=2722863132, ScreenName=AllThingsGraph),
#  User(ID=3011670991, ScreenName=robina_naazli),
#  User(ID=50128998, ScreenName=jessogden),
#  User(ID=274274893, ScreenName=technelily),
#  User(ID=84858636, ScreenName=joemcgonegal),
#  User(ID=35063411, ScreenName=liblaura),
#  User(ID=2369320224, ScreenName=bodhisattvaOS),
#  User(ID=15449070, ScreenName=brettbobley),
#  User(ID=1362108876, ScreenName=ForgetITProject),
#  User(ID=1344928800, ScreenName=oreficeplumbing),
#  User(ID=2965341161, ScreenName=SoftGid_com),
#  User(ID=16632193, ScreenName=LyndaLSF),
#  User(ID=14080897, ScreenName=zimeon),
#  User(ID=197877074, ScreenName=unmil),
#  User(ID=1039531, ScreenName=zittrain),
#  User(ID=1794171, ScreenName=ptrourke),
#  User(ID=2919263380, ScreenName=WessamElhefnawy),
#  User(ID=248487038, ScreenName=Moha_Magdy),
#  User(ID=974961414, ScreenName=gauravguptak1),
#  User(ID=136650757, ScreenName=_akisato),
#  User(ID=495430242, ScreenName=IgorBrigadir),
#  User(ID=988508311, ScreenName=WebART12),
#  User(ID=2907087853, ScreenName=DrAinenwar),
#  User(ID=15649736, ScreenName=lisallynch),
#  User(ID=2558921360, ScreenName=AlinaDeniau),
#  User(ID=545432826, ScreenName=StanfordLibs),
#  User(ID=97686415, ScreenName=digitalfay),
#  User(ID=1178381287, ScreenName=IngeRudomino),
#  User(ID=178073946, ScreenName=5280BigData),
#  User(ID=383505214, ScreenName=karenhansn),
#  User(ID=3007491, ScreenName=todrobbins),
#  User(ID=22943563, ScreenName=abugseye),
#  User(ID=44388993, ScreenName=mlzman),
#  User(ID=17652850, ScreenName=taylor_amy),
#  User(ID=15229740, ScreenName=weblawlib),
#  User(ID=17875198, ScreenName=EJWalters),
#  User(ID=409504445, ScreenName=ReedTechCorp),
#  User(ID=2428028178, ScreenName=LizCohee),
#  User(ID=92718411, ScreenName=WehoMan88),
#  User(ID=52369416, ScreenName=djw0952),
#  User(ID=14673239, ScreenName=cyberlaw),
#  User(ID=18227931, ScreenName=aag1091),
#  User(ID=732773, ScreenName=dhowell),
#  User(ID=2560074793, ScreenName=PoorOldMoot),
#  User(ID=2800100421, ScreenName=jcdl2015),
#  User(ID=2776234795, ScreenName=annediaz01),
#  User(ID=2711199650, ScreenName=Paisadalo),
#  User(ID=2825068825, ScreenName=meterz1),
#  User(ID=2822206502, ScreenName=MildlyBored),
#  User(ID=2752385484, ScreenName=GetDownODU),
#  User(ID=19677430, ScreenName=jkamps),
#  User(ID=64472672, ScreenName=TimelessFuture),
#  User(ID=135509603, ScreenName=GJST),
#  User(ID=211179164, ScreenName=RossiAtanassova),
#  User(ID=19776081, ScreenName=bindonlane),
#  User(ID=178165020, ScreenName=northgardner),
#  User(ID=2800143252, ScreenName=LulwahMA),
#  User(ID=2763613546, ScreenName=momof3inov),
#  User(ID=89239179, ScreenName=emcaulay),
#  User(ID=61243147, ScreenName=doppelen),
#  User(ID=102701235, ScreenName=mgallinger),
#  User(ID=2431482414, ScreenName=MonarchsAimHigh),
#  User(ID=46863710, ScreenName=Sandra_Mason),
#  User(ID=19467275, ScreenName=lnsails),
#  User(ID=49793152, ScreenName=chrislaoscott),
#  User(ID=22779978, ScreenName=save4use),
#  User(ID=2674699039, ScreenName=History2point0),
#  User(ID=41814921, ScreenName=archivelle),
#  User(ID=28267732, ScreenName=jesseajohnston),
#  User(ID=320298773, ScreenName=perrycollins),
#  User(ID=1012488631, ScreenName=BergisJules),
#  User(ID=2527129274, ScreenName=plamen26968325),
#  User(ID=2536466947, ScreenName=webrecorder_io),
#  User(ID=2592291038, ScreenName=acnwala),
#  User(ID=2587811778, ScreenName=isi2015conf),
#  User(ID=423250891, ScreenName=_matef),
#  User(ID=562233477, ScreenName=jotschirr),
#  User(ID=2525271955, ScreenName=forschungsdaten),
#  User(ID=132897897, ScreenName=petrknoth),
#  User(ID=1500687722, ScreenName=GrahamSeaman),
#  User(ID=49970416, ScreenName=n_audenaert),
#  User(ID=36132608, ScreenName=this_phillips),
#  User(ID=2569026047, ScreenName=ohttic),
#  User(ID=398109871, ScreenName=DLWebBnF),
#  User(ID=2511651984, ScreenName=DLWeb_Seb),
#  User(ID=199397791, ScreenName=saraaubry),
#  User(ID=9568712, ScreenName=acocciolo),
#  User(ID=346054122, ScreenName=jefferson_bail),
#  User(ID=14509956, ScreenName=jasonmarkwebber),
#  User(ID=2512551954, ScreenName=WOSP2014),
#  User(ID=17674847, ScreenName=migcosta),
#  User(ID=255681367, ScreenName=ianmilligan1),
#  User(ID=8769542, ScreenName=peterkz_swe),
#  User(ID=27106703, ScreenName=lorcanD),
#  User(ID=2493157534, ScreenName=RaifordGuins),
#  User(ID=104591562, ScreenName=oducs),
#  User(ID=2425674422, ScreenName=iPRESconf),
#  User(ID=15431437, ScreenName=saschel),
#  User(ID=2239079520, ScreenName=DLib2014),
#  User(ID=7223722, ScreenName=jsicot),
#  User(ID=18564459, ScreenName=NeilMonday),
#  User(ID=2383561699, ScreenName=DialUCL),
#  User(ID=2381231737, ScreenName=DrDanetteAllen),
#  User(ID=128943024, ScreenName=K4arkive),
#  User(ID=9329862, ScreenName=squealermusic),
#  User(ID=14465889, ScreenName=jalbertbowdenii),
#  User(ID=1469283758, ScreenName=DigiCultureKCL),
#  User(ID=21880973, ScreenName=xabuci),
#  User(ID=112806109, ScreenName=CommonCrawl),
#  User(ID=2278388744, ScreenName=AutonomyIncub8r),
#  User(ID=44973000, ScreenName=jteevan),
#  User(ID=17981917, ScreenName=dchud),
#  User(ID=104248552, ScreenName=MellissaBuys),
#  User(ID=1455778316, ScreenName=mummifyit),
#  User(ID=519457298, ScreenName=EdelOShea83),
#  User(ID=261232181, ScreenName=erinengle),
#  User(ID=73457328, ScreenName=opba),
#  User(ID=12449732, ScreenName=RSSNewsmaster),
#  User(ID=13180652, ScreenName=zxie),
#  User(ID=56390873, ScreenName=rodwittenberg),
#  User(ID=1878868224, ScreenName=Antenna_Lab),
#  User(ID=1444456622, ScreenName=AnnaPerricci),
#  User(ID=23761309, ScreenName=ruyhliu),
#  User(ID=19597819, ScreenName=Strollerman),
#  User(ID=6355402, ScreenName=kberberi),
#  User(ID=14293580, ScreenName=thabing),
#  User(ID=247370192, ScreenName=unstablearchive),
#  User(ID=50410039, ScreenName=NancyAjarmeh),
#  User(ID=1873691448, ScreenName=amaranaas),
#  User(ID=1511472330, ScreenName=maturban1),
#  User(ID=27301650, ScreenName=SciTechProf),
#  User(ID=19535756, ScreenName=beatles__beatle),
#  User(ID=40052022, ScreenName=KyleStr),
#  User(ID=1937516472, ScreenName=PeterOnymos),
#  User(ID=38632947, ScreenName=MaxKemman),
#  User(ID=1927768428, ScreenName=WebSciDL),
#  User(ID=13686942, ScreenName=jakkbl),
#  User(ID=195447741, ScreenName=samy_tawab),
#  User(ID=12434302, ScreenName=jschneider),
#  User(ID=74956583, ScreenName=Milena_Dobreva),
#  User(ID=78269677, ScreenName=iFromm),
#  User(ID=54163837, ScreenName=Philipp_Mayr),
#  User(ID=562571892, ScreenName=violetailik),
#  User(ID=116461750, ScreenName=cgknowles),
#  User(ID=545003004, ScreenName=GerhardGossen),
#  User(ID=29468552, ScreenName=kvanmalssen),
#  User(ID=50940718, ScreenName=chrisbellekom),
#  User(ID=18714809, ScreenName=itroch),
#  User(ID=56239365, ScreenName=TessaFallon),
#  User(ID=1472127596, ScreenName=toinette1607),
#  User(ID=299932017, ScreenName=StanZheng),
#  User(ID=1646059915, ScreenName=SimpleSimon2013),
#  User(ID=75183681, ScreenName=PeerProd),
#  User(ID=6691152, ScreenName=subotic),
#  User(ID=1430543138, ScreenName=mdiazdigpres),
#  User(ID=26065295, ScreenName=AVArchivist),
#  User(ID=16269358, ScreenName=erikchoi),
#  User(ID=15501426, ScreenName=chglass),
#  User(ID=247148044, ScreenName=usa8951),
#  User(ID=256521914, ScreenName=RajnishMallick),
#  User(ID=105412340, ScreenName=tamingdata),
#  User(ID=21232655, ScreenName=NKrabben),
#  User(ID=1479169362, ScreenName=ISRJINDIA),
#  User(ID=8383552, ScreenName=myerscarpenter),
#  User(ID=11726, ScreenName=smalljones),
#  User(ID=79866108, ScreenName=peplluis7),
#  User(ID=194079156, ScreenName=kristsi),
#  User(ID=22689222, ScreenName=athurman),
#  User(ID=1231314888, ScreenName=covenant_ws),
#  User(ID=28631536, ScreenName=ibnesayeed),
#  User(ID=476100749, ScreenName=pj_webster),
#  User(ID=1217754968, ScreenName=GerdaMueller2),
#  User(ID=618889136, ScreenName=archiveis),
#  User(ID=1381298330, ScreenName=FjellHenning),
#  User(ID=13516042, ScreenName=stevehit),
#  User(ID=21333292, ScreenName=clarellewellyn),
#  User(ID=307755344, ScreenName=UKWebArchive),
#  User(ID=14198245, ScreenName=bethcron),
#  User(ID=246358351, ScreenName=inadlweb),
#  User(ID=41434876, ScreenName=AricAumann),
#  User(ID=139507464, ScreenName=www2013rio),
#  User(ID=1019810725, ScreenName=iPRES2013),
#  User(ID=244173178, ScreenName=metalinker),
#  User(ID=365952591, ScreenName=joc7188),
#  User(ID=35142697, ScreenName=kzakza),
#  User(ID=382427814, ScreenName=ehetzner),
#  User(ID=1188978266, ScreenName=Mercedesew211),
#  User(ID=145080615, ScreenName=archivesmatter),
#  User(ID=221460308, ScreenName=yasmina_anwar),
#  User(ID=1157624052, ScreenName=WSUNDSA),
#  User(ID=539768101, ScreenName=CamtheWicked),
#  User(ID=525880128, ScreenName=RjLyric),
#  User(ID=249127464, ScreenName=aheshamSalem),
#  User(ID=815880932, ScreenName=abrennr),
#  User(ID=556567650, ScreenName=archivetype),
#  User(ID=1031591, ScreenName=mcdonald),
#  User(ID=936881, ScreenName=rdhyee),
#  User(ID=184082385, ScreenName=hryanski),
#  User(ID=14130929, ScreenName=ttso),
#  User(ID=784575811, ScreenName=tpdl2017),
#  User(ID=22066521, ScreenName=stillinsky),
#  User(ID=626791738, ScreenName=NorfolkVA_),
#  User(ID=1217801, ScreenName=klischka),
#  User(ID=135239104, ScreenName=tedlawless),
#  User(ID=94208781, ScreenName=hariharshankar),
#  User(ID=24711165, ScreenName=kevingashley),
#  User(ID=14453338, ScreenName=mjgiarlo),
#  User(ID=14564240, ScreenName=vphill),
#  User(ID=16149989, ScreenName=trevormunoz),
#  User(ID=20870016, ScreenName=WebArchivists),
#  User(ID=13342392, ScreenName=bfluzin),
#  User(ID=15253735, ScreenName=Jakdemir),
#  User(ID=702116713, ScreenName=AlephArchives),
#  User(ID=479013038, ScreenName=GeorgeRBuchanan),
#  User(ID=61743700, ScreenName=wrap_ed),
#  User(ID=474770944, ScreenName=OpenResearchExe),
#  User(ID=12610112, ScreenName=ldmm),
#  User(ID=192056435, ScreenName=ericleasemorgan),
#  User(ID=133887059, ScreenName=pigandpublish),
#  User(ID=182956232, ScreenName=lwynholds),
#  User(ID=618628646, ScreenName=MonicaDYOIart),
#  User(ID=607480844, ScreenName=WPKefi),
#  User(ID=378202816, ScreenName=Milbala),
#  User(ID=606550203, ScreenName=jcdl2013),
#  User(ID=95974012, ScreenName=schuurmanna),
#  User(ID=9796892, ScreenName=mzarro),
#  User(ID=121140906, ScreenName=cni_org),
#  User(ID=594934857, ScreenName=THEBenLeBrun),
#  User(ID=18416299, ScreenName=junklight),
#  User(ID=19288395, ScreenName=gmj2053),
#  User(ID=563703084, ScreenName=Magda69425548),
#  User(ID=17489806, ScreenName=mwittin),
#  User(ID=531307387, ScreenName=JesseforCouncil),
#  User(ID=437818152, ScreenName=BeachAutoBroker),
#  User(ID=547685358, ScreenName=ahmedkalka97),
#  User(ID=537061602, ScreenName=DwiDwisyafitri),
#  User(ID=15007784, ScreenName=grotophorst),
#  User(ID=387831845, ScreenName=maherzog),
#  User(ID=132916189, ScreenName=margymavery),
#  User(ID=45752188, ScreenName=plbogen),
#  User(ID=497825678, ScreenName=xuxomln),
#  User(ID=385020618, ScreenName=SouthernKiaGB),
#  User(ID=199205892, ScreenName=atomotic),
#  User(ID=14331818, ScreenName=edsu),
#  User(ID=479894950, ScreenName=machawk1),
#  User(ID=34713020, ScreenName=kylewilliams87),
#  User(ID=470775438, ScreenName=Alisia1092),
#  User(ID=112950384, ScreenName=pre11e),
#  User(ID=15831818, ScreenName=tywalters1),
#  User(ID=28178451, ScreenName=ldirks),
#  User(ID=413130434, ScreenName=jcdl2012),
#  User(ID=100660566, ScreenName=landeart),
#  User(ID=411169790, ScreenName=witch_doctor81),
#  User(ID=259850415, ScreenName=NetPreserve),
#  User(ID=402772312, ScreenName=NDSA2),
#  User(ID=1711171, ScreenName=pkeane),
#  User(ID=5641552, ScreenName=meblake),
#  User(ID=34698911, ScreenName=unknown_6),
#  User(ID=387069830, ScreenName=BizApproved),
#  User(ID=20610488, ScreenName=Erikfreiser),
#  User(ID=278198164, ScreenName=AAlasaadi),
#  User(ID=355773903, ScreenName=archiveitorg),
#  User(ID=366605043, ScreenName=awptix),
#  User(ID=338504977, ScreenName=klhiggins33),
#  User(ID=35883240, ScreenName=ChuChoResano),
#  User(ID=14149525, ScreenName=fmccown),
#  User(ID=14119157, ScreenName=diglib),
#  User(ID=21586018, ScreenName=hhockx),
#  User(ID=77997105, ScreenName=RobVesse),
#  User(ID=1701371, ScreenName=anjacks0n),
#  User(ID=106536714, ScreenName=Faryane),
#  User(ID=19450230, ScreenName=lljohnston),
#  User(ID=337124515, ScreenName=mart1nkle1n),
#  User(ID=320276384, ScreenName=smartfit_atees),
#  User(ID=40903501, ScreenName=furuta),
#  User(ID=36045574, ScreenName=Ghozia),
#  User(ID=278661116, ScreenName=aalsum),
#  User(ID=32495546, ScreenName=joansm1th),
#  User(ID=191032987, ScreenName=MarthaBunton),
#  User(ID=132900528, ScreenName=AT_Webarchive),
#  User(ID=133035766, ScreenName=sorgentelinda),
#  User(ID=48082526, ScreenName=agrotke),
#  User(ID=264874122, ScreenName=sspranay),
#  User(ID=32747579, ScreenName=Galsondor),
#  User(ID=22826489, ScreenName=shawnmjones),
#  User(ID=7136612, ScreenName=jgsmith),
#  User(ID=44583052, ScreenName=bhaslhofer),
#  User(ID=14077727, ScreenName=sshreeves),
#  User(ID=211104907, ScreenName=TagTrees),
#  User(ID=48356887, ScreenName=kboughida),
#  User(ID=18638955, ScreenName=mousta),
#  User(ID=241865283, ScreenName=TeriBerg96),
#  User(ID=15044465, ScreenName=nullhandle),
#  User(ID=71089109, ScreenName=twarko),
#  User(ID=12509892, ScreenName=k8lin),
#  User(ID=205922124, ScreenName=OTHSEAFOOD),
#  User(ID=17002009, ScreenName=HCIR_GeneG),
#  User(ID=201612370, ScreenName=hanysalaheldeen),
#  User(ID=14320209, ScreenName=hochstenbach),
#  User(ID=8500742, ScreenName=carltonnorthern),
#  User(ID=17369964, ScreenName=olyerickson),
#  User(ID=55361508, ScreenName=williamjnixon),
#  User(ID=180473295, ScreenName=justinfbrunelle),
#  User(ID=75550501, ScreenName=weiglemc),
#  User(ID=16464166, ScreenName=umurthy),
#  User(ID=17163698, ScreenName=blefurgy),
#  User(ID=123740183, ScreenName=Julibabe21),
#  User(ID=20148603, ScreenName=azaroth42),
#  User(ID=90083746, ScreenName=hvdsomp),
#  User(ID=11137722, ScreenName=ccmarshall)]

# %% [markdown]
# &nbsp;
#
# We want the subject in the graph too so append the `User` object, then create a dictionary to hold the nodes and links between them. From each `User` object put only the needed data into a `dict` and append it to the list of nodes.
#
# &nbsp;

# %%
users.append(f.api.GetUser(user_id=uid))

data = { 'nodes' : [], 'links' : [] }
for user in users:
    user_data = {   'id': user.id,
                    'name': user.name,
                    'profile_image_url': user.profile_image_url,
                    'screen_name': user.screen_name,
                    'default_profile_image': user.default_profile_image
                }
    data['nodes'].append(dict(user_data))
    
data['nodes']
# Out:
# [{'default_profile_image': False,
#   'id': 59860290,
#   'name': 'Ryan Yacyshyn',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/796184339687931905/--nSmCcF_normal.jpg',
#   'screen_name': 'ryacca'},
#  {'default_profile_image': False,
#   'id': 9421452,
#   'name': 'Shebin',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/608858046731673600/nwm8reMF_normal.jpg',
#   'screen_name': 'shebin'},
#  {'default_profile_image': False,
#   'id': 265517884,
#   'name': 'Daniel',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2839957630/6742066915c916b9448b513314bab9f2_normal.jpeg',
#   'screen_name': 'ycpdan'},
#  {'default_profile_image': False,
#   'id': 3979114762,
#   'name': 'Rebecca Dallavalle',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/822219089049452546/yjbE3trx_normal.jpg',
#   'screen_name': 'BexAnnalisa'},
#  {'default_profile_image': False,
#   'id': 756135755190198273,
#   'name': 'De Gruyter Libraries',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/756137216254980096/2Bj3kfSP_normal.jpg',
#   'screen_name': 'degruyter_lib'},
#  {'default_profile_image': False,
#   'id': 3158073120,
#   'name': 'Mixnode',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/804823765964029952/3h6CTIMX_normal.jpg',
#   'screen_name': 'mixnode'},
#  {'default_profile_image': False,
#   'id': 481260788,
#   'name': '@no identd',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/758644713201238016/HX7JPMfX_normal.jpg',
#   'screen_name': 'no_identd'},
#  {'default_profile_image': False,
#   'id': 1429810189,
#   'name': 'Jens Crueger',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/765152493877751808/FolWjb2D_normal.jpg',
#   'screen_name': 'JCrueger'},
#  {'default_profile_image': False,
#   'id': 4008474733,
#   'name': 'Alissa M.',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/738710122512285697/Zkf_pHcT_normal.jpg',
#   'screen_name': 'lissertations'},
#  {'default_profile_image': True,
#   'id': 821042028800802816,
#   'name': 'Grant Atkins',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#   'screen_name': 'Grant_ODU'},
#  {'default_profile_image': True,
#   'id': 827268804359053313,
#   'name': 'MichaelMicros',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#   'screen_name': 'mmicros1'},
#  {'default_profile_image': False,
#   'id': 789293970677456896,
#   'name': 'Patrick Cox',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/789296122233847808/fmHjla7Q_normal.jpg',
#   'screen_name': '74paddycakes'},
#  {'default_profile_image': False,
#   'id': 799272100599046145,
#   'name': 'René Voorburg',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/799931370516647940/K0TkfBPi_normal.jpg',
#   'screen_name': 'digitopia_nl'},
#  {'default_profile_image': False,
#   'id': 203096228,
#   'name': 'Adrienne Pruitt',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/717376345865478144/HcRuXWSC_normal.jpg',
#   'screen_name': 'PruittAL'},
#  {'default_profile_image': False,
#   'id': 81650379,
#   'name': 'Brenda Berkelaar',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/665158896525312000/O9o0G7Wd_normal.jpg',
#   'screen_name': 'brendaberkelaar'},
#  {'default_profile_image': False,
#   'id': 47899646,
#   'name': 'Cassie Findlay',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/503770380146716672/-ZqPskdq_normal.jpeg',
#   'screen_name': 'CassPF'},
#  {'default_profile_image': False,
#   'id': 899863316,
#   'name': 'OK Rider/Motorcu',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/747873690654769154/TaKbM-_u_normal.jpg',
#   'screen_name': 'OKMotovlog'},
#  {'default_profile_image': False,
#   'id': 30802131,
#   'name': 'Margaret Konkol',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/612467215862927360/zgZk9y9K_normal.jpg',
#   'screen_name': 'mekonkol'},
#  {'default_profile_image': False,
#   'id': 761396027446398976,
#   'name': 'Stesker3D',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/777132624846348288/lYylOWVP_normal.jpg',
#   'screen_name': 'Stesker3D'},
#  {'default_profile_image': False,
#   'id': 825218681252765696,
#   'name': 'Hussam Hallak',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/828693167197204481/LezWYLYV_normal.jpg',
#   'screen_name': 'HussamHallak1'},
#  {'default_profile_image': True,
#   'id': 20255236,
#   'name': 'Carol Castle',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#   'screen_name': 'carolc16'},
#  {'default_profile_image': False,
#   'id': 825049390998024192,
#   'name': 'Printuu',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/825421424718389249/vd2bmbni_normal.jpg',
#   'screen_name': 'printuu'},
#  {'default_profile_image': False,
#   'id': 733536950963994624,
#   'name': 'Data Science',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/828865856021155840/fordY9bZ_normal.jpg',
#   'screen_name': 'dtscnc'},
#  {'default_profile_image': False,
#   'id': 737852660183932928,
#   'name': 'Tunazzina Islam',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/744945448964751360/BYD6pYSi_normal.jpg',
#   'screen_name': 'Tunaz_Islam'},
#  {'default_profile_image': False,
#   'id': 9630082,
#   'name': 'Meredith Artley',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/421350001134948352/oWP39w4L_normal.jpeg',
#   'screen_name': 'MeredithA'},
#  {'default_profile_image': False,
#   'id': 258599525,
#   'name': 'Meghan Hoyer',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/643884814119104512/9Pew3YSv_normal.jpg',
#   'screen_name': 'MeghanHoyer'},
#  {'default_profile_image': False,
#   'id': 3122708646,
#   'name': 'Anton',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/756657049606512644/geQDpH31_normal.jpg',
#   'screen_name': 'AntonJRasmussen'},
#  {'default_profile_image': False,
#   'id': 1634706151,
#   'name': 'Bram Luyten',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/740611666887462912/cAztghSl_normal.jpg',
#   'screen_name': 'LuytenBram'},
#  {'default_profile_image': False,
#   'id': 399805362,
#   'name': 'Mohd Kamal',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/588399194395652096/tS649QUm_normal.jpg',
#   'screen_name': 'MohdKamal6'},
#  {'default_profile_image': False,
#   'id': 269424738,
#   'name': 'Paul Young',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/698409181653684224/ZTJHMEvy_normal.jpg',
#   'screen_name': 'pmyoung84'},
#  {'default_profile_image': True,
#   'id': 810540893396733953,
#   'name': 'Karki',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#   'screen_name': 'Karki693'},
#  {'default_profile_image': False,
#   'id': 1119502988,
#   'name': 'British Library Labs',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/458627032255963136/LrfmDsum_normal.png',
#   'screen_name': 'BL_Labs'},
#  {'default_profile_image': False,
#   'id': 783440136,
#   'name': 'Pôle #AI au #Québec',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/807696707089813504/VA-7_NUn_normal.jpg',
#   'screen_name': 'IntelligenceTV'},
#  {'default_profile_image': True,
#   'id': 808893873766432768,
#   'name': 'Maheedhar Gunnam',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#   'screen_name': 'maheedhargunnam'},
#  {'default_profile_image': False,
#   'id': 58880930,
#   'name': 'Nattiya Kanhabua',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3727028789/2c275bed6ef62c97f7071c82877d4445_normal.png',
#   'screen_name': 'nattiyak'},
#  {'default_profile_image': False,
#   'id': 47985362,
#   'name': 'Marcin Wilkowski',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/461050206742540288/0WEsLaiN_normal.jpeg',
#   'screen_name': 'marcinwilkowski'},
#  {'default_profile_image': False,
#   'id': 801186507931455488,
#   'name': 'James Dill',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/801704756116762625/XySpif1b_normal.jpg',
#   'screen_name': 'minornotez'},
#  {'default_profile_image': False,
#   'id': 19203768,
#   'name': 'Kate Starbird',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/822692976304340993/jMQjWo1h_normal.jpg',
#   'screen_name': 'katestarbird'},
#  {'default_profile_image': False,
#   'id': 2190533245,
#   'name': 'ACM SIGIR',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/776809490909896704/OVX1OArZ_normal.jpg',
#   'screen_name': 'ACMSIGIR'},
#  {'default_profile_image': False,
#   'id': 89504686,
#   'name': 'Ralf Claussnitzer',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/747697618122334208/ZvNFvCNv_normal.jpg',
#   'screen_name': 'claussni'},
#  {'default_profile_image': False,
#   'id': 192964243,
#   'name': 'NJ Computer Group',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/643449617858719744/bZNSoGOy_normal.png',
#   'screen_name': 'njcomputergroup'},
#  {'default_profile_image': False,
#   'id': 113647306,
#   'name': 'ARLIS/NA New York',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1192193415/twitter_normal.jpg',
#   'screen_name': 'ARLIS_NY'},
#  {'default_profile_image': False,
#   'id': 2936496598,
#   'name': 'Sumitra Duncan',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/553623454000222208/IZUaqZve_normal.jpeg',
#   'screen_name': 'artlibrariannyc'},
#  {'default_profile_image': False,
#   'id': 3281181511,
#   'name': 'WikiCite',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/739367095532703744/3hhZSGOn_normal.jpg',
#   'screen_name': 'Wikicite'},
#  {'default_profile_image': False,
#   'id': 258032124,
#   'name': 'ussr.io',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/768894884543463424/FGaQuAar_normal.jpg',
#   'screen_name': 'ChiefScientist'},
#  {'default_profile_image': False,
#   'id': 3447506422,
#   'name': 'ODU Peninsula Center',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/796765515972833280/KTxASFB8_normal.jpg',
#   'screen_name': 'ODUPeninsulaCtr'},
#  {'default_profile_image': False,
#   'id': 16564030,
#   'name': 'Lance Mercereau',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/560111601043243009/xfgOG4by_normal.jpeg',
#   'screen_name': 'lmercereau'},
#  {'default_profile_image': False,
#   'id': 30047063,
#   'name': 'Hindawi',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/771636621741395968/oBKO_LC1_normal.jpg',
#   'screen_name': 'Hindawi'},
#  {'default_profile_image': False,
#   'id': 1695487818,
#   'name': 'Esperanza Salazar',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/712373189884530688/i-6-HCic_normal.jpg',
#   'screen_name': 'es_land'},
#  {'default_profile_image': False,
#   'id': 2973715954,
#   'name': 'Kenneth Diedrich',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/554395111883161600/07kSP8Z0_normal.jpeg',
#   'screen_name': 'KennyDiedrich'},
#  {'default_profile_image': False,
#   'id': 774187456191160320,
#   'name': 'Joffrey Decourselle',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/774188246679056384/DU3oHLC1_normal.jpg',
#   'screen_name': 'JDecourselle'},
#  {'default_profile_image': False,
#   'id': 3849211272,
#   'name': 'Riker',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/673899174002167808/XAsJadQe_normal.jpg',
#   'screen_name': 'RikerHampton'},
#  {'default_profile_image': False,
#   'id': 57750231,
#   'name': 'ODUAlumniAssociation',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/531839614709796864/ArNBPO_0_normal.jpeg',
#   'screen_name': 'ODUAlumni'},
#  {'default_profile_image': False,
#   'id': 19258241,
#   'name': 'Heinz Pampel',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000761485499/2e08c904773ac15d05a7c43b1e702800_normal.jpeg',
#   'screen_name': 'pampel'},
#  {'default_profile_image': False,
#   'id': 146209930,
#   'name': 'Katrina Stierholz',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000039320464/3c6afd264d037cfb5316a3059053eb03_normal.jpeg',
#   'screen_name': 'stierholz'},
#  {'default_profile_image': False,
#   'id': 4481168962,
#   'name': 'School of Salamanca',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/827135250534907906/AWab8rL1_normal.jpg',
#   'screen_name': 'salamancaschool'},
#  {'default_profile_image': False,
#   'id': 16868154,
#   'name': 'Arjen P. de Vries',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2875589913/b361e1c80a05f80c887c97619cc1b6fe_normal.jpeg',
#   'screen_name': 'arjenpdevries'},
#  {'default_profile_image': False,
#   'id': 3354096993,
#   'name': 'Helena Byrne',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/687005921659215872/30iKj1xn_normal.jpg',
#   'screen_name': 'HBee2015'},
#  {'default_profile_image': False,
#   'id': 193063049,
#   'name': 'Ben Vershbow',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1251454027/doppelganger_normal.jpg',
#   'screen_name': 'subsublibrary'},
#  {'default_profile_image': False,
#   'id': 468735081,
#   'name': 'Julie Rogers',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/839248056751165440/E-YyhQD8_normal.jpg',
#   'screen_name': 'jubrogers'},
#  {'default_profile_image': False,
#   'id': 138161380,
#   'name': 'Matías Butelman',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/751793992883380224/4Czuql6q_normal.jpg',
#   'screen_name': 'mbutel'},
#  {'default_profile_image': False,
#   'id': 17271698,
#   'name': 'andrea davis',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/794631184001052672/XVRqXj_m_normal.jpg',
#   'screen_name': 'detailmatters'},
#  {'default_profile_image': False,
#   'id': 3365719153,
#   'name': 'UCLA Acquisitions',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/637406673070493696/3WGMAjWH_normal.png',
#   'screen_name': 'acquire_UCLA'},
#  {'default_profile_image': False,
#   'id': 74541831,
#   'name': 'Kate Zwaard',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/765274696547962880/IHHBZH3P_normal.jpg',
#   'screen_name': 'kzwa'},
#  {'default_profile_image': False,
#   'id': 5894872,
#   'name': 'Harald Sack',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/799905753087803392/5CUa32Or_normal.jpg',
#   'screen_name': 'lysander07'},
#  {'default_profile_image': False,
#   'id': 13645402,
#   'name': 'ChrisAldrich',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000823803940/e500bc8cba99417f27ac3392e7503aa0_normal.jpeg',
#   'screen_name': 'ChrisAldrich'},
#  {'default_profile_image': False,
#   'id': 729223119030751232,
#   'name': 'www.sheershasamachar',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/739958609904205824/YXMRGiUw_normal.jpg',
#   'screen_name': 'sheershasamach1'},
#  {'default_profile_image': False,
#   'id': 739900844531974144,
#   'name': 'JCDL2017',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/783699658459770880/6ToHFp2t_normal.jpg',
#   'screen_name': 'jcdl2017'},
#  {'default_profile_image': False,
#   'id': 1668275245,
#   'name': 'perma.cc',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/744949592618209280/QlVQwm-X_normal.jpg',
#   'screen_name': 'permacc'},
#  {'default_profile_image': True,
#   'id': 781886520978444288,
#   'name': 'Kh Talha',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#   'screen_name': 'KhTalha6'},
#  {'default_profile_image': False,
#   'id': 570294703,
#   'name': 'Jan Strack',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/746824862249914369/rQMEiGO2_normal.jpg',
#   'screen_name': 'Jack_Stran'},
#  {'default_profile_image': False,
#   'id': 24713262,
#   'name': 'Angela Woodall',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000475083959/a8e8d6a253012ace417926b216c273cc_normal.jpeg',
#   'screen_name': 'AngelaWoodall'},
#  {'default_profile_image': True,
#   'id': 66188615,
#   'name': 'Bruno Leonard',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_3_normal.png',
#   'screen_name': 'bruno_leonard_'},
#  {'default_profile_image': False,
#   'id': 774263152544452608,
#   'name': 'Data Cartel',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/774274418390528000/kgf38QtT_normal.jpg',
#   'screen_name': 'datacartel1'},
#  {'default_profile_image': False,
#   'id': 2806160786,
#   'name': 'JDNA',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/638719030350622720/YqAoN5AH_normal.jpg',
#   'screen_name': 'RJIJDNA'},
#  {'default_profile_image': False,
#   'id': 1551367058,
#   'name': 'Fredericik Begbeder',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000710311151/9cbd8006a5899a6118dc8368f790d274_normal.jpeg',
#   'screen_name': 'FredericikB'},
#  {'default_profile_image': False,
#   'id': 2852131203,
#   'name': 'Pamela VanHaitsma',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/839647802384842755/jAKXKwDo_normal.jpg',
#   'screen_name': 'pvanhaitsma'},
#  {'default_profile_image': False,
#   'id': 4508117621,
#   'name': 'Robin Ruggaber',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/807640801790595072/yYBSC7oJ_normal.jpg',
#   'screen_name': 'robin_ruggaber'},
#  {'default_profile_image': False,
#   'id': 237086573,
#   'name': 'Charlene Finley',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/775198667783282688/LjZDMnds_normal.jpg',
#   'screen_name': 'Cee_Finley'},
#  {'default_profile_image': False,
#   'id': 161598558,
#   'name': 'Roceys',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2359431553/i7mwta6u4h90lmcvfr3y_normal.jpeg',
#   'screen_name': 'woilgoo'},
#  {'default_profile_image': False,
#   'id': 11164692,
#   'name': 'Seamus Lawless',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1662654879/SciCom_Profile_normal.jpg',
#   'screen_name': 'seamuslawless'},
#  {'default_profile_image': False,
#   'id': 737342173079736321,
#   'name': 'Kevin Levrone',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/737368290222346241/YjvgWlJt_normal.jpg',
#   'screen_name': 'KevinLevrone3'},
#  {'default_profile_image': False,
#   'id': 4738176435,
#   'name': 'MementoWeb',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/770345340344082433/RdLol102_normal.jpg',
#   'screen_name': 'Mementoweb'},
#  {'default_profile_image': False,
#   'id': 7377862,
#   'name': 'Jason Casden',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1285825913/casden_hood_garden_normal.jpg',
#   'screen_name': 'cazzerson'},
#  {'default_profile_image': False,
#   'id': 833373624,
#   'name': 'Brooke F Welles',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2626756569/Brooke-Headshot-Small_normal.jpg',
#   'screen_name': 'foucaultwelles'},
#  {'default_profile_image': False,
#   'id': 1393107912,
#   'name': 'Micah Zeller',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/816351501916454914/SAEtdwW__normal.jpg',
#   'screen_name': 'mdzellerCDAL'},
#  {'default_profile_image': False,
#   'id': 48592998,
#   'name': 'Robin M. Katz',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/590689039776411648/U97Pn_IQ_normal.jpg',
#   'screen_name': 'robinmkatz'},
#  {'default_profile_image': False,
#   'id': 3321913552,
#   'name': 'Christopher Chyr',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/610957360320765952/a5OOcBKO_normal.jpg',
#   'screen_name': 'mrchyr'},
#  {'default_profile_image': False,
#   'id': 134569763,
#   'name': 'Meredith Evans',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/481629489051361281/V8hh32Pv_normal.jpeg',
#   'screen_name': 'mre1920'},
#  {'default_profile_image': False,
#   'id': 3412095995,
#   'name': 'Saad Ehsan',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/630638865850703872/-zYYKKCo_normal.png',
#   'screen_name': 'saadaitomation'},
#  {'default_profile_image': False,
#   'id': 729563714475700224,
#   'name': 'Jessica Smith',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/729568662642823170/6BVoSMfV_normal.jpg',
#   'screen_name': 'jessicasmith541'},
#  {'default_profile_image': False,
#   'id': 267189586,
#   'name': 'bakare oluwabunmi',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/775045842411655168/VK1D_sfL_normal.jpg',
#   'screen_name': 'bumdots4eva'},
#  {'default_profile_image': False,
#   'id': 605923,
#   'name': 'Shawn Walker',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1256136674/shawn_normal.jpg',
#   'screen_name': 'walkeroh'},
#  {'default_profile_image': True,
#   'id': 3189940844,
#   'name': '.',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#   'screen_name': 'CRajaharsha'},
#  {'default_profile_image': False,
#   'id': 14338221,
#   'name': 'Laura J. Smart',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/723280931235069952/kcVyyYGC_normal.jpg',
#   'screen_name': 'infod1va'},
#  {'default_profile_image': False,
#   'id': 33736942,
#   'name': 'Liz Neely',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/764516080828186628/LHlRWO-b_normal.jpg',
#   'screen_name': 'lili_czarina'},
#  {'default_profile_image': False,
#   'id': 745643383188758528,
#   'name': 'Oorlogsbronnen',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/748180024793120768/biWSprjf_normal.jpg',
#   'screen_name': 'Oorlogsbronnen'},
#  {'default_profile_image': False,
#   'id': 745385398134661120,
#   'name': 'Annika Hinze',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/745386763586240512/HPTiHaEi_normal.jpg',
#   'screen_name': 'annika_hinze'},
#  {'default_profile_image': False,
#   'id': 18957805,
#   'name': 'Internet Archive',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/717127559134056448/BYGRuZmj_normal.jpg',
#   'screen_name': 'internetarchive'},
#  {'default_profile_image': False,
#   'id': 708690890974470145,
#   'name': 'Mridul Sen',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/774509666080612352/bSts9phn_normal.jpg',
#   'screen_name': 'mridulish'},
#  {'default_profile_image': False,
#   'id': 118078818,
#   'name': 'Abd El-Fatah',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/757461371973885952/ynT2yK3a_normal.jpg',
#   'screen_name': 'Dr_Abomohra'},
#  {'default_profile_image': False,
#   'id': 220983330,
#   'name': 'Helge Holzmann',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000254082716/b168fa08a6f03ea6520759a73f2c5dbe_normal.jpeg',
#   'screen_name': 'helgeho'},
#  {'default_profile_image': False,
#   'id': 9308852,
#   'name': 'Îďȫʞ Šĕčủrıtƴ',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/573613604089393152/Y3URTCCY_normal.jpeg',
#   'screen_name': 'idokius'},
#  {'default_profile_image': False,
#   'id': 744784018919432194,
#   'name': 'Zhaohuan Wang',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/832587358977482752/22n7eDNz_normal.jpg',
#   'screen_name': 'zhaohuan_wang'},
#  {'default_profile_image': False,
#   'id': 4497126976,
#   'name': 'PoliticalTVAdArchive',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/677600361742393344/2SU5t8q7_normal.png',
#   'screen_name': 'PolitAdArchive'},
#  {'default_profile_image': False,
#   'id': 7591252,
#   'name': 'Nancy Watzman',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/460868826301607936/UT81WeaF_normal.png',
#   'screen_name': 'nwatzman'},
#  {'default_profile_image': False,
#   'id': 24257870,
#   'name': 'John Howard',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2375478079/145tl6jf9vlcosn2v0wb_normal.jpeg',
#   'screen_name': 'John_B_Howard'},
#  {'default_profile_image': False,
#   'id': 753571748860293120,
#   'name': 'Context Scout',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/753585746729111552/lc4VNXJ1_normal.jpg',
#   'screen_name': 'CScoutTech'},
#  {'default_profile_image': False,
#   'id': 2416303724,
#   'name': 'Ava Forte Vitali',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/449622377203122176/5nauM2wG_normal.jpeg',
#   'screen_name': 'avadigs'},
#  {'default_profile_image': False,
#   'id': 45411436,
#   'name': 'Malte',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/549269273315528705/RouLc2qh_normal.png',
#   'screen_name': 'XYOU'},
#  {'default_profile_image': False,
#   'id': 25187570,
#   'name': 'theo van veen',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000591868880/b4218d0c3ed1f355b8630efe803414ff_normal.jpeg',
#   'screen_name': 'theovv'},
#  {'default_profile_image': False,
#   'id': 24092133,
#   'name': 'nick ruest',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/842569942373347328/UlrQ4KCD_normal.jpg',
#   'screen_name': 'ruebot'},
#  {'default_profile_image': False,
#   'id': 83170793,
#   'name': 'Michael Stevenson',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3708722324/db88b85e00e6489d531ef98f355f14c5_normal.jpeg',
#   'screen_name': '_mstevenson'},
#  {'default_profile_image': False,
#   'id': 1836330308,
#   'name': 'Stephanie A Kingsley',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/767900043206537216/GdMbgQR1_normal.jpg',
#   'screen_name': 'KingsleySteph'},
#  {'default_profile_image': False,
#   'id': 373385155,
#   'name': 'Andrea Goethals',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1775755066/Dp01_white_small_normal.png',
#   'screen_name': 'AndreaGoethals'},
#  {'default_profile_image': False,
#   'id': 256118545,
#   'name': 'Norman Meuschke',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/745982367869902848/A1JUKXNM_normal.jpg',
#   'screen_name': 'normeu'},
#  {'default_profile_image': False,
#   'id': 455827771,
#   'name': 'Bela',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000476238431/9d88000e3889e6bf18771991938efebf_normal.jpeg',
#   'screen_name': 'BelaGipp'},
#  {'default_profile_image': False,
#   'id': 1200468920,
#   'name': 'Myriam',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/780532806141304833/J-sI3XW0_normal.jpg',
#   'screen_name': 'MyriamCTraub'},
#  {'default_profile_image': False,
#   'id': 238653576,
#   'name': "Brendan O'Hallarn",
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1218358427/WhiteKnucklesSquare2_normal.jpg',
#   'screen_name': 'White__Knuckles'},
#  {'default_profile_image': False,
#   'id': 168780501,
#   'name': 'TEI Landmark',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/722804725591093249/k0Fi8aH0_normal.jpg',
#   'screen_name': 'TEILandmark'},
#  {'default_profile_image': False,
#   'id': 38438084,
#   'name': 'tmeehleib',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/663796679867539456/cSax5DdB_normal.png',
#   'screen_name': 'tmeehleib'},
#  {'default_profile_image': True,
#   'id': 742243474485956608,
#   'name': 'Mohammad Obaidullah',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#   'screen_name': 'Mohamma47262302'},
#  {'default_profile_image': False,
#   'id': 41353586,
#   'name': 'DBpedia',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/721301450962432000/L9ehCZfC_normal.jpg',
#   'screen_name': 'dbpedia'},
#  {'default_profile_image': False,
#   'id': 326644141,
#   'name': 'aml eyde',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/740846073648939009/uRO1YGQj_normal.jpg',
#   'screen_name': 'amlhasbat'},
#  {'default_profile_image': False,
#   'id': 1009549428,
#   'name': 'Tim Walsh',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/834043436634349568/xIUU-7Zc_normal.jpg',
#   'screen_name': 'bitarchivist'},
#  {'default_profile_image': True,
#   'id': 734457556006010885,
#   'name': 'Rebecca Holte',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_6_normal.png',
#   'screen_name': 'rebeccaholte'},
#  {'default_profile_image': False,
#   'id': 173013762,
#   'name': 'Hung V. Do',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/732767610098593792/jxOfVd82_normal.jpg',
#   'screen_name': 'doviethung'},
#  {'default_profile_image': False,
#   'id': 3935341,
#   'name': 'Chris Freeland',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/771773683425746944/0XhwTy28_normal.jpg',
#   'screen_name': 'chrisfreeland'},
#  {'default_profile_image': False,
#   'id': 277409211,
#   'name': 'David Underdown',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1301232266/profile_pic_normal.jpg',
#   'screen_name': 'DavidUnderdown9'},
#  {'default_profile_image': True,
#   'id': 3111336135,
#   'name': 'sooraya sadulla',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#   'screen_name': 'sooraya_sadulla'},
#  {'default_profile_image': False,
#   'id': 415881007,
#   'name': 'Jake Orlowitz',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000605465423/a2cdf125277b292f48ef09aaa9ec78b4_normal.jpeg',
#   'screen_name': 'JakeOrlowitz'},
#  {'default_profile_image': False,
#   'id': 188811710,
#   'name': 'The DLF',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2281460457/kwiy5bwtqifnubwguo4n_normal.jpeg',
#   'screen_name': 'CLIRDLF'},
#  {'default_profile_image': False,
#   'id': 86044173,
#   'name': 'Peeter Rahuvarm',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/496527267/Picture-007_normal.jpg',
#   'screen_name': 'kraabus'},
#  {'default_profile_image': False,
#   'id': 2769879696,
#   'name': 'N J Bingham',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/757564608701923329/_VukIVy-_normal.jpg',
#   'screen_name': 'NicolaJBingham'},
#  {'default_profile_image': False,
#   'id': 90033276,
#   'name': 'Carole Gagné',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/719134990085275648/vOIxcVCc_normal.jpg',
#   'screen_name': 'carole_gagne'},
#  {'default_profile_image': True,
#   'id': 4151123165,
#   'name': 'Fernando Melo',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#   'screen_name': 'Fernando___Melo'},
#  {'default_profile_image': False,
#   'id': 720282585277063168,
#   'name': 'Hugo Viana',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/720721845574594563/7fr-SoUI_normal.jpg',
#   'screen_name': 'HugoAViana'},
#  {'default_profile_image': False,
#   'id': 164478889,
#   'name': 'Ingrid Mason',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/730195200346181632/65zdisgN_normal.jpg',
#   'screen_name': '1n9r1d'},
#  {'default_profile_image': True,
#   'id': 543394546,
#   'name': 'Michelle  M',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#   'screen_name': 'Mittrach_garten'},
#  {'default_profile_image': False,
#   'id': 106677153,
#   'name': 'Arnoud Goos',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/720315609846710272/O90HKTK6_normal.jpg',
#   'screen_name': 'ArnoudGoos'},
#  {'default_profile_image': False,
#   'id': 3042711,
#   'name': 'Mark Graham',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/656968483679305728/fe5IAXyK_normal.jpg',
#   'screen_name': 'MarkGraham'},
#  {'default_profile_image': False,
#   'id': 6021062,
#   'name': 'Holly Croft',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/790361524930015232/Dtj8uuv8_normal.jpg',
#   'screen_name': 'HollyCroft'},
#  {'default_profile_image': False,
#   'id': 46299743,
#   'name': 'SPARC',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/686944586095280128/2qdjeRBm_normal.jpg',
#   'screen_name': 'SPARC_NA'},
#  {'default_profile_image': False,
#   'id': 708538857940070400,
#   'name': 'OAIS du Jour',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/708668570050306048/9i7kDvSk_normal.jpg',
#   'screen_name': 'oaisdujour'},
#  {'default_profile_image': True,
#   'id': 2495140081,
#   'name': 'Karen Vaughan',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#   'screen_name': 'KarenKvaughan'},
#  {'default_profile_image': False,
#   'id': 719570834487144448,
#   'name': 'عبدالاله رحومه',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/719844201945571329/_GvbVmU1_normal.jpg',
#   'screen_name': '6T7VXu11XcTiAbd'},
#  {'default_profile_image': False,
#   'id': 1606632924,
#   'name': 'Daniel Bicho',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/648253528411119616/8gJkwJdb_normal.jpg',
#   'screen_name': 'bicho_daniel'},
#  {'default_profile_image': False,
#   'id': 309420446,
#   'name': 'Adam Ziegler',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/634028104646721536/IPLtVAjR_normal.jpg',
#   'screen_name': 'abziegler'},
#  {'default_profile_image': False,
#   'id': 1480422979,
#   'name': 'Tue Hejlskov Larsen',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/591521652925718528/mKXfZStl_normal.png',
#   'screen_name': 'TueHLarsen'},
#  {'default_profile_image': False,
#   'id': 15042751,
#   'name': 'C C Mumma',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/681553175/Photo_119_normal.jpg',
#   'screen_name': 'lookouthoney'},
#  {'default_profile_image': False,
#   'id': 50379684,
#   'name': 'holly phillips',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/688031054/S-Arapaho-Pk-Marmot-3_normal.gif',
#   'screen_name': 'hollips'},
#  {'default_profile_image': False,
#   'id': 782931,
#   'name': 'Gardner Campbell',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/448479095249051649/VCU6dhSU_normal.jpeg',
#   'screen_name': 'GardnerCampbell'},
#  {'default_profile_image': False,
#   'id': 115917954,
#   'name': 'Miel Vander Sande',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1369602895/P1010137_normal.JPG',
#   'screen_name': 'Miel_vds'},
#  {'default_profile_image': False,
#   'id': 127125266,
#   'name': 'Jacquelyn Clements',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/725436531612225536/mrju8reK_normal.jpg',
#   'screen_name': 'peripatesis'},
#  {'default_profile_image': False,
#   'id': 2473528178,
#   'name': 'd:swarm',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/538041186347266048/6sAqrv8z_normal.png',
#   'screen_name': 'dswarm'},
#  {'default_profile_image': False,
#   'id': 54493821,
#   'name': 'manoj Kompalli',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/709387424477155328/HTm2wPZN_normal.jpg',
#   'screen_name': 'Manoj_Chandra11'},
#  {'default_profile_image': False,
#   'id': 305614894,
#   'name': 'Ahmed Hosni',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1369779719/000j050I4JB_normal.jpg',
#   'screen_name': 'DevAhmedhosni'},
#  {'default_profile_image': True,
#   'id': 118623489,
#   'name': 'dinesh kumar paladhi',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#   'screen_name': 'dineshpaladhi'},
#  {'default_profile_image': False,
#   'id': 376298824,
#   'name': 'Lindsey E. Jones',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/772890738501808130/pCczLbRM_normal.jpg',
#   'screen_name': 'noumenal_woman'},
#  {'default_profile_image': False,
#   'id': 704273004717613056,
#   'name': 'rdayMedia',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/802426216875753473/ED8hj2Gp_normal.jpg',
#   'screen_name': 'rdayMedia'},
#  {'default_profile_image': False,
#   'id': 1133038710,
#   'name': 'Erich',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/640666206421299200/SJnT-Hs3_normal.png',
#   'screen_name': 'ErichdotPy'},
#  {'default_profile_image': False,
#   'id': 1299060908,
#   'name': 'Dan Kerchner',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000069362401/0aad64b6a3b77f843a31ef510a9336cb_normal.jpeg',
#   'screen_name': 'DanKerchner'},
#  {'default_profile_image': False,
#   'id': 2586364634,
#   'name': 'Thomas Risse',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/843766358064189440/S_U9o1Y7_normal.jpg',
#   'screen_name': 'risse691'},
#  {'default_profile_image': False,
#   'id': 702963405364322306,
#   'name': 'Iulia Dobre',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/703316361259384832/VIOxHtQ3_normal.jpg',
#   'screen_name': 'IuliaCristina12'},
#  {'default_profile_image': False,
#   'id': 198925162,
#   'name': 'Alex Dolan-Mescal',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/838831625974632448/OyWkAGQu_normal.jpg',
#   'screen_name': 'fromADMwithlove'},
#  {'default_profile_image': False,
#   'id': 4925540277,
#   'name': 'ILOVEPINK',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/715283862318936064/xeJMBzEC_normal.jpg',
#   'screen_name': 'AndreeaCorinaM2'},
#  {'default_profile_image': False,
#   'id': 22277220,
#   'name': 'psleeman',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3327176206/6e8f5dffd4e46d02f511cde4d0608640_normal.jpeg',
#   'screen_name': 'PSleeman'},
#  {'default_profile_image': True,
#   'id': 4879994613,
#   'name': 'Mohamed Shaaban',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#   'screen_name': 'Shaaban_Migo'},
#  {'default_profile_image': False,
#   'id': 14807028,
#   'name': 'Min-Yen Kan',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2708961519/cd5cfb634647cee2e13fb00c9946e0d7_normal.jpeg',
#   'screen_name': 'knmnyn'},
#  {'default_profile_image': False,
#   'id': 4856503619,
#   'name': 'mg',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/694415071129264128/CvZLa_eO_normal.jpg',
#   'screen_name': 'mgome0072'},
#  {'default_profile_image': False,
#   'id': 157985123,
#   'name': 'majetisiri',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/709832107959427073/P1uUGaHA_normal.jpg',
#   'screen_name': 'majetisiri'},
#  {'default_profile_image': False,
#   'id': 48378958,
#   'name': 'Greggory Rodgers  II',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/841253864745684992/F3XGOtBO_normal.jpg',
#   'screen_name': 'futuresma'},
#  {'default_profile_image': False,
#   'id': 701725615603347457,
#   'name': 'dhombe',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/701753923762126848/SJKcoeQn_normal.jpg',
#   'screen_name': 'dhombe3'},
#  {'default_profile_image': False,
#   'id': 2601589496,
#   'name': 'ACM SIGIR 2017',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/701651828870504449/1lJSEgM7_normal.png',
#   'screen_name': 'SIGIR17'},
#  {'default_profile_image': False,
#   'id': 1327778215,
#   'name': 'lyn maccorkle',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000849844019/fea2d70458a0c0dc5ad3e7eb319d6c66_normal.jpeg',
#   'screen_name': 'lmaccork'},
#  {'default_profile_image': False,
#   'id': 698172818563952640,
#   'name': 'Larry Wayne Wilson',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/698175404079599616/u6dCwTWj_normal.png',
#   'screen_name': 'LarryWilson1942'},
#  {'default_profile_image': False,
#   'id': 3060184494,
#   'name': 'Jimmy Lee(PMG)',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/837476986599714820/QXFPP4Sw_normal.jpg',
#   'screen_name': 'JayNuetron'},
#  {'default_profile_image': False,
#   'id': 4897300665,
#   'name': 'WOSP Workshop',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/833733153374220288/LVx7RQLx_normal.jpg',
#   'screen_name': 'wospworkshop'},
#  {'default_profile_image': False,
#   'id': 516787981,
#   'name': 'NetLab',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/765522876803977216/hfpBrBdu_normal.jpg',
#   'screen_name': 'NetLab_dk'},
#  {'default_profile_image': False,
#   'id': 160436528,
#   'name': 'Salim Chemlal',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/811901813712560129/HSTLRG6Q_normal.jpg',
#   'screen_name': 'SalimChemlal'},
#  {'default_profile_image': False,
#   'id': 386532355,
#   'name': 'EmeraldIKM',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/816957039129886720/MUfbQ2YB_normal.jpg',
#   'screen_name': 'EmeraldIKM'},
#  {'default_profile_image': False,
#   'id': 42914077,
#   'name': 'Shatha Jayyousi',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/696346944738820096/HcDUJa3e_normal.jpg',
#   'screen_name': 'ShathaJY'},
#  {'default_profile_image': True,
#   'id': 110800099,
#   'name': 'Huan Huang',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#   'screen_name': 'CrowNaito'},
#  {'default_profile_image': False,
#   'id': 122038961,
#   'name': 'Emerald Library',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/818814262764302336/hKEx3vbP_normal.jpg',
#   'screen_name': 'EmeraldLibrary'},
#  {'default_profile_image': True,
#   'id': 4869611475,
#   'name': 'Kev Clem',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#   'screen_name': 'clem_kev'},
#  {'default_profile_image': False,
#   'id': 4845001934,
#   'name': 'Digi Archives Team',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/753342863610552320/thW3Je4x_normal.jpg',
#   'screen_name': 'digiarchiveteam'},
#  {'default_profile_image': False,
#   'id': 798668178,
#   'name': '9ulovesu',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/471096249655889920/_w8DZcce_normal.jpeg',
#   'screen_name': '9ulovesu'},
#  {'default_profile_image': True,
#   'id': 3485785534,
#   'name': 'Manoj Chandra',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#   'screen_name': 'manoj_chandra_k'},
#  {'default_profile_image': False,
#   'id': 707840696,
#   'name': 'Karl Blumenthal',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/778410530524520449/qjjG4ltb_normal.jpg',
#   'screen_name': 'landlibrarian'},
#  {'default_profile_image': False,
#   'id': 203024977,
#   'name': 'Codio',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/539672501895196672/gPeKlutZ_normal.png',
#   'screen_name': 'CodioHQ'},
#  {'default_profile_image': False,
#   'id': 4844579470,
#   'name': 'John Berlin',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/691507288901685249/mMYopFJn_normal.jpg',
#   'screen_name': 'johnaberlin'},
#  {'default_profile_image': False,
#   'id': 14298448,
#   'name': 'Ryan Baumann',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/818200227849142273/0Uzp4q48_normal.jpg',
#   'screen_name': 'ryanfb'},
#  {'default_profile_image': False,
#   'id': 25469726,
#   'name': 'Andrew Berger',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/610827188435202048/QkRgIQKH_normal.jpg',
#   'screen_name': 'andrewjbtw'},
#  {'default_profile_image': False,
#   'id': 3436812551,
#   'name': 'DocumentingTheNow',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/728713121884311552/Yjoenpxp_normal.png',
#   'screen_name': 'documentnow'},
#  {'default_profile_image': False,
#   'id': 2830868675,
#   'name': 'Elizabeth',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/688505773987631104/wrIG-zIE_normal.jpg',
#   'screen_name': 'elizhoagcarhart'},
#  {'default_profile_image': False,
#   'id': 284205655,
#   'name': 'erika siregar',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/707802054643863552/0qY4GvI9_normal.jpg',
#   'screen_name': 'erikaris'},
#  {'default_profile_image': False,
#   'id': 4738279701,
#   'name': 'slobodan milanko',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/685216849819234304/bfeA7d1y_normal.jpg',
#   'screen_name': 'DanMilanko'},
#  {'default_profile_image': False,
#   'id': 110465562,
#   'name': 'James Baker',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/788722932000362496/pWmJ5Ris_normal.jpg',
#   'screen_name': 'j_w_baker'},
#  {'default_profile_image': False,
#   'id': 2374377426,
#   'name': 'Archivportal-D',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/644468934062796800/Z40QjJwV_normal.png',
#   'screen_name': 'archivportal'},
#  {'default_profile_image': False,
#   'id': 127005958,
#   'name': 'João Costa de Souza',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/826111786042662913/ZYIybHUw_normal.jpg',
#   'screen_name': 'desouzatech'},
#  {'default_profile_image': False,
#   'id': 10034972,
#   'name': 'Trevor Owens',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/809222576916615169/eUjP_XZ1_normal.jpg',
#   'screen_name': 'tjowens'},
#  {'default_profile_image': False,
#   'id': 21789681,
#   'name': 'Cathy Hartman',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/219625525/CATHYPHOTOheadSmall_normal.JPG',
#   'screen_name': 'badgerhartman'},
#  {'default_profile_image': False,
#   'id': 2525306964,
#   'name': 'Secrets Fact',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/544555543092662272/-rzTUIyx_normal.jpeg',
#   'screen_name': 'TrueHiddenFact'},
#  {'default_profile_image': False,
#   'id': 15970999,
#   'name': 'Kees Teszelszky',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/844827616154562560/80BKen7C_normal.jpg',
#   'screen_name': 'keesone'},
#  {'default_profile_image': False,
#   'id': 2812268522,
#   'name': 'Impact Zone',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/808849886619668480/qUAmjK2x_normal.jpg',
#   'screen_name': 'impactzoneco'},
#  {'default_profile_image': False,
#   'id': 583619284,
#   'name': 'Karolina Holub',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/689192593666736129/E8OZggL6_normal.jpg',
#   'screen_name': 'KarolHolu'},
#  {'default_profile_image': False,
#   'id': 727549675,
#   'name': 'Topgolf Va. Beach',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/534433699740151809/OY8IcGC1_normal.png',
#   'screen_name': 'topgolfvabeach'},
#  {'default_profile_image': False,
#   'id': 4242196667,
#   'name': 'John Chang',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/668052580287688704/xuR4sW60_normal.jpg',
#   'screen_name': 'JohnChangGWU'},
#  {'default_profile_image': False,
#   'id': 4208606734,
#   'name': 'ICDM 2016',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/666542091959459840/LbyNFrwJ_normal.jpg',
#   'screen_name': 'icdm2016'},
#  {'default_profile_image': False,
#   'id': 1121591,
#   'name': 'Mike Amundsen',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/340449683/madmen_icon_normal.jpg',
#   'screen_name': 'mamund'},
#  {'default_profile_image': False,
#   'id': 4167895879,
#   'name': 'brij mohan rana',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/663324641960656896/8FXh6j9N_normal.jpg',
#   'screen_name': 'brijmohanrana4'},
#  {'default_profile_image': False,
#   'id': 4111220189,
#   'name': 'OTL National Event',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/813426080421974017/EunwaViM_normal.jpg',
#   'screen_name': 'imafuturemedic'},
#  {'default_profile_image': False,
#   'id': 14121668,
#   'name': 'Euan Cochrane',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/817238025507897345/XlRIH1CC_normal.jpg',
#   'screen_name': 'euanc'},
#  {'default_profile_image': False,
#   'id': 117267879,
#   'name': 'Douglas White',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/716802959/nsl2small_normal.gif',
#   'screen_name': 'dwhitenist'},
#  {'default_profile_image': False,
#   'id': 191532379,
#   'name': 'sam meister',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/470626724103720960/eiz5xR7x_normal.jpeg',
#   'screen_name': 'samalanmeister'},
#  {'default_profile_image': False,
#   'id': 24086900,
#   'name': 'Shira Peltzman',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/580390651641995264/IHcTkNbH_normal.jpg',
#   'screen_name': 'shirapeltzman'},
#  {'default_profile_image': False,
#   'id': 10011252,
#   'name': 'Amadou Waddawannadou',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2666455117/f312dee54d59354bd525e04a46c66552_normal.jpeg',
#   'screen_name': 'iamtimmo'},
#  {'default_profile_image': False,
#   'id': 381480281,
#   'name': 'Jessica Tieman',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/821486656758878208/mtFfQtHP_normal.jpg',
#   'screen_name': 'J_IreneTieman'},
#  {'default_profile_image': False,
#   'id': 46276118,
#   'name': 'David Mimno',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/653947113819140096/3jn3UL-t_normal.jpg',
#   'screen_name': 'dmimno'},
#  {'default_profile_image': False,
#   'id': 2375877384,
#   'name': 'ExpressYourInnerYogi',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/627183437607112704/YFJUBtc9_normal.jpg',
#   'screen_name': 'Pravacana_Mats'},
#  {'default_profile_image': False,
#   'id': 4058321,
#   'name': 'Daniel Rehn',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/769885136707997699/iU-8QHF4_normal.jpg',
#   'screen_name': 'daniel_rehn'},
#  {'default_profile_image': False,
#   'id': 207756340,
#   'name': 'wwwtxt (1980-94)',
# ...
#   'screen_name': 'DwiDwisyafitri'},
#  {'default_profile_image': False,
#   'id': 15007784,
#   'name': 'Wally',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/437664439970848768/vnOztzei_normal.jpeg',
#   'screen_name': 'grotophorst'},
#  {'default_profile_image': False,
#   'id': 387831845,
#   'name': 'Michael A. Herzog',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/756744495815884800/U8V4r63S_normal.jpg',
#   'screen_name': 'maherzog'},
#  {'default_profile_image': False,
#   'id': 132916189,
#   'name': 'Margy Avery',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/528667158285664256/XuAICK_t_normal.jpeg',
#   'screen_name': 'margymavery'},
#  {'default_profile_image': False,
#   'id': 45752188,
#   'name': 'Paul Logasa Bogen II',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/766026693056266240/pDg1R0oS_normal.jpg',
#   'screen_name': 'plbogen'},
#  {'default_profile_image': True,
#   'id': 497825678,
#   'name': 'xuxomln',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#   'screen_name': 'xuxomln'},
#  {'default_profile_image': False,
#   'id': 385020618,
#   'name': 'SHAGGreenbrier',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1587093050/Greenbrier_normal.png',
#   'screen_name': 'SouthernKiaGB'},
#  {'default_profile_image': False,
#   'id': 199205892,
#   'name': 'Raffaele Messuti',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/682508583649570816/T1t6M1PI_normal.png',
#   'screen_name': 'atomotic'},
#  {'default_profile_image': False,
#   'id': 14331818,
#   'name': 'Ed Summers',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/803663094777974784/jgMuBer0_normal.jpg',
#   'screen_name': 'edsu'},
#  {'default_profile_image': False,
#   'id': 479894950,
#   'name': 'Mat Kelly',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/598110235920834560/lFLE-mX7_normal.png',
#   'screen_name': 'machawk1'},
#  {'default_profile_image': False,
#   'id': 34713020,
#   'name': 'Kyle Williams',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/676785599693615104/ifMpRS-8_normal.jpg',
#   'screen_name': 'kylewilliams87'},
#  {'default_profile_image': False,
#   'id': 470775438,
#   'name': 'Alisia',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/825152020193619968/yx56M7kr_normal.jpg',
#   'screen_name': 'Alisia1092'},
#  {'default_profile_image': True,
#   'id': 112950384,
#   'name': 'matpre',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#   'screen_name': 'pre11e'},
#  {'default_profile_image': False,
#   'id': 15831818,
#   'name': 'Tyler Walters',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/58153334/tyler0704_normal.jpg',
#   'screen_name': 'tywalters1'},
#  {'default_profile_image': False,
#   'id': 28178451,
#   'name': 'Lee Dirks',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/117754788/Mmm_Beer_normal.jpg',
#   'screen_name': 'ldirks'},
#  {'default_profile_image': False,
#   'id': 413130434,
#   'name': 'jcdl2012',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1640378418/jcdl_logo_normal.gif',
#   'screen_name': 'jcdl2012'},
#  {'default_profile_image': False,
#   'id': 100660566,
#   'name': 'Lisa Lande',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/619247417/landeart_normal.jpg',
#   'screen_name': 'landeart'},
#  {'default_profile_image': False,
#   'id': 411169790,
#   'name': 'John McManus',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1636194783/image_normal.jpg',
#   'screen_name': 'witch_doctor81'},
#  {'default_profile_image': False,
#   'id': 259850415,
#   'name': 'IIPC',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2179744751/IIPC_Twitter_ProfilePic_normal.gif',
#   'screen_name': 'NetPreserve'},
#  {'default_profile_image': False,
#   'id': 402772312,
#   'name': 'NDSA',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/723223701836181505/yShs_hqK_normal.jpg',
#   'screen_name': 'NDSA2'},
#  {'default_profile_image': False,
#   'id': 1711171,
#   'name': 'Peter Keane',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/634320167/Photo_35_normal.jpg',
#   'screen_name': 'pkeane'},
#  {'default_profile_image': False,
#   'id': 5641552,
#   'name': 'Miriam Blake',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/24241162/ebook_normal.jpg',
#   'screen_name': 'meblake'},
#  {'default_profile_image': True,
#   'id': 34698911,
#   'name': 'teknicaldy',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#   'screen_name': 'unknown_6'},
#  {'default_profile_image': True,
#   'id': 387069830,
#   'name': 'Darryl Young',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#   'screen_name': 'BizApproved'},
#  {'default_profile_image': False,
#   'id': 20610488,
#   'name': 'Erik Freiser',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/747217925791055872/2yCk_Uy7_normal.jpg',
#   'screen_name': 'Erikfreiser'},
#  {'default_profile_image': False,
#   'id': 278198164,
#   'name': 'Abdulla Alasaadi',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/838796115742961664/qkOgpCsi_normal.jpg',
#   'screen_name': 'AAlasaadi'},
#  {'default_profile_image': False,
#   'id': 355773903,
#   'name': 'Archive-It',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/750715520534675456/RD0TeRLZ_normal.jpg',
#   'screen_name': 'archiveitorg'},
#  {'default_profile_image': False,
#   'id': 366605043,
#   'name': 'Brooks Childers',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1553616744/110313-133951_normal.jpg',
#   'screen_name': 'awptix'},
#  {'default_profile_image': False,
#   'id': 338504977,
#   'name': 'Kasey McNamara',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1451138485/21980_1391365183312_1207598399_31173717_286737_n_normal.jpg',
#   'screen_name': 'klhiggins33'},
#  {'default_profile_image': False,
#   'id': 35883240,
#   'name': 'Sebastian Resano',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/776206440352677888/hnGSK1Hu_normal.jpg',
#   'screen_name': 'ChuChoResano'},
#  {'default_profile_image': False,
#   'id': 14149525,
#   'name': 'Frank McCown',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2565544139/klyl8kkare4d2vnb6pyg_normal.jpeg',
#   'screen_name': 'fmccown'},
#  {'default_profile_image': False,
#   'id': 14119157,
#   'name': 'diglib',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/634436589855178752/Eo3MdjLI_normal.jpg',
#   'screen_name': 'diglib'},
#  {'default_profile_image': False,
#   'id': 21586018,
#   'name': 'Helen Hockx-Yu',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/612142333065330688/7km0xDHs_normal.jpg',
#   'screen_name': 'hhockx'},
#  {'default_profile_image': False,
#   'id': 77997105,
#   'name': 'Rob Vesse',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000349276734/a092a1a7f910c343f6710554b0fd82b4_normal.jpeg',
#   'screen_name': 'RobVesse'},
#  {'default_profile_image': False,
#   'id': 1701371,
#   'name': 'Andy Jackson',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/748614773831516160/lY83E4kt_normal.jpg',
#   'screen_name': 'anjacks0n'},
#  {'default_profile_image': True,
#   'id': 106536714,
#   'name': 'Faryaneh',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_4_normal.png',
#   'screen_name': 'Faryane'},
#  {'default_profile_image': False,
#   'id': 19450230,
#   'name': 'Leslie Johnston',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3213794593/62e2f31b19d414b13dd145c479311ae4_normal.jpeg',
#   'screen_name': 'lljohnston'},
#  {'default_profile_image': False,
#   'id': 337124515,
#   'name': 'Martin Klein',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1446884840/mklein_normal.jpg',
#   'screen_name': 'mart1nkle1n'},
#  {'default_profile_image': False,
#   'id': 320276384,
#   'name': 'MPV SEAT COVERS UK',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1406318434/img2_normal.jpg',
#   'screen_name': 'smartfit_atees'},
#  {'default_profile_image': True,
#   'id': 40903501,
#   'name': 'Richard Furuta',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#   'screen_name': 'furuta'},
#  {'default_profile_image': True,
#   'id': 36045574,
#   'name': 'Ahmed Ghozia',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_5_normal.png',
#   'screen_name': 'Ghozia'},
#  {'default_profile_image': False,
#   'id': 278661116,
#   'name': 'Ahmed AlSum',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1398121692/n586360620_2280741_4881_normal.jpg',
#   'screen_name': 'aalsum'},
#  {'default_profile_image': False,
#   'id': 32495546,
#   'name': 'Joan Smith',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2971076407/6190a113bbf895966099782c23aa171a_normal.png',
#   'screen_name': 'joansm1th'},
#  {'default_profile_image': False,
#   'id': 191032987,
#   'name': 'Martha Anderson',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1266727478/Martha_001_crop_normal.PNG',
#   'screen_name': 'MarthaBunton'},
#  {'default_profile_image': False,
#   'id': 132900528,
#   'name': 'Web@rchive Austria',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1019901278/LOGO_kl_swift_normal.png',
#   'screen_name': 'AT_Webarchive'},
#  {'default_profile_image': False,
#   'id': 133035766,
#   'name': 'Sorgente Linda',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1307654561/sorgentlinda_normal.png',
#   'screen_name': 'sorgentelinda'},
#  {'default_profile_image': False,
#   'id': 48082526,
#   'name': 'Abbie Grotke',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1407170838/abportraitiris_normal.jpg',
#   'screen_name': 'agrotke'},
#  {'default_profile_image': False,
#   'id': 264874122,
#   'name': 'Pranay Pramod',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/671750996507365376/OczUtImF_normal.png',
#   'screen_name': 'sspranay'},
#  {'default_profile_image': False,
#   'id': 32747579,
#   'name': 'Scott Ainsworth',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000635279956/062717d96d474df009b302dd65197c91_normal.jpeg',
#   'screen_name': 'Galsondor'},
#  {'default_profile_image': False,
#   'id': 22826489,
#   'name': 'Shawn M. Jones',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/460655715896410113/_ZuI5SPe_normal.jpeg',
#   'screen_name': 'shawnmjones'},
#  {'default_profile_image': False,
#   'id': 7136612,
#   'name': 'James Smith',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/55367959/Photo_6-cropped_normal.jpg',
#   'screen_name': 'jgsmith'},
#  {'default_profile_image': False,
#   'id': 44583052,
#   'name': 'Bernhard Haslhofer',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3372122721/04416e32afd6420d3f3cf0812163dc37_normal.jpeg',
#   'screen_name': 'bhaslhofer'},
#  {'default_profile_image': False,
#   'id': 14077727,
#   'name': 'Sarah Shreeves',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/3161392231/487de8f10fe8f9bb910e46effcbfb19a_normal.jpeg',
#   'screen_name': 'sshreeves'},
#  {'default_profile_image': False,
#   'id': 211104907,
#   'name': 'TagTrees',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1157958643/logo_tag_only_500x500_normal.png',
#   'screen_name': 'TagTrees'},
#  {'default_profile_image': False,
#   'id': 48356887,
#   'name': 'Karim B Boughida',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/616615420565393408/TTXob14b_normal.jpg',
#   'screen_name': 'kboughida'},
#  {'default_profile_image': False,
#   'id': 18638955,
#   'name': 'Moustafa Emara',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1631118205/flight_normal.jpg',
#   'screen_name': 'mousta'},
#  {'default_profile_image': True,
#   'id': 241865283,
#   'name': 'Teri Berg',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_2_normal.png',
#   'screen_name': 'TeriBerg96'},
#  {'default_profile_image': False,
#   'id': 15044465,
#   'name': 'Nicholas Taylor',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/541064285019832320/QivgOAYK_normal.jpeg',
#   'screen_name': 'nullhandle'},
#  {'default_profile_image': False,
#   'id': 71089109,
#   'name': 'Marko A. Rodriguez',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/395313322/exterminator_normal.png',
#   'screen_name': 'twarko'},
#  {'default_profile_image': False,
#   'id': 12509892,
#   'name': 'Kaitlin L. Costello',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/834514964677160962/bRYViWNQ_normal.jpg',
#   'screen_name': 'k8lin'},
#  {'default_profile_image': False,
#   'id': 205922124,
#   'name': 'OFFTHEHOOK',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1149731517/smallothlogo_normal.jpg',
#   'screen_name': 'OTHSEAFOOD'},
#  {'default_profile_image': False,
#   'id': 17002009,
#   'name': 'Gene Golovchinsky',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/384632718/LW3N3435-crop_normal.jpg',
#   'screen_name': 'HCIR_GeneG'},
#  {'default_profile_image': False,
#   'id': 201612370,
#   'name': 'Hany SalahEldeen',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/589006417966850048/oS_M-9wr_normal.jpg',
#   'screen_name': 'hanysalaheldeen'},
#  {'default_profile_image': False,
#   'id': 14320209,
#   'name': 'Patrick Hochstenbach',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/483484131427229699/zeLlmy4j_normal.jpeg',
#   'screen_name': 'hochstenbach'},
#  {'default_profile_image': False,
#   'id': 8500742,
#   'name': 'Carlton Northern',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/732036478784708608/djVrvXp9_normal.jpg',
#   'screen_name': 'carltonnorthern'},
#  {'default_profile_image': False,
#   'id': 17369964,
#   'name': 'John S. Erickson',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1205664680/erickson_twit_normal.jpg',
#   'screen_name': 'olyerickson'},
#  {'default_profile_image': False,
#   'id': 55361508,
#   'name': 'William J Nixon',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/305911187/william_normal.jpg',
#   'screen_name': 'williamjnixon'},
#  {'default_profile_image': False,
#   'id': 180473295,
#   'name': 'Justin F Brunelle',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/643489094476132353/lWNbAJj3_normal.jpg',
#   'screen_name': 'justinfbrunelle'},
#  {'default_profile_image': False,
#   'id': 75550501,
#   'name': 'Michele Weigle',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/466648768389980160/3m8QCmnl_normal.jpeg',
#   'screen_name': 'weiglemc'},
#  {'default_profile_image': False,
#   'id': 16464166,
#   'name': 'Uma Murthy',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/66818453/uma_normal.JPG',
#   'screen_name': 'umurthy'},
#  {'default_profile_image': False,
#   'id': 17163698,
#   'name': 'Bill LeFurgy',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/422052725459668992/vJ4zBpAw_normal.jpeg',
#   'screen_name': 'blefurgy'},
#  {'default_profile_image': True,
#   'id': 123740183,
#   'name': 'Julianne Allen',
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png',
#   'screen_name': 'Julibabe21'},
#  {'default_profile_image': False,
#   'id': 20148603,
#   'name': 'Rob Sanderson',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/759196947567697920/ZgO6hvaH_normal.jpg',
#   'screen_name': 'azaroth42'},
#  {'default_profile_image': False,
#   'id': 90083746,
#   'name': 'Herbert',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/843216000271220736/R028NOzi_normal.jpg',
#   'screen_name': 'hvdsomp'},
#  {'default_profile_image': False,
#   'id': 11137722,
#   'name': 'cathy marshall',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1802710015/me-blurry_normal.jpg',
#   'screen_name': 'ccmarshall'},
#  {'default_profile_image': False,
#   'id': 151901549,
#   'name': 'Michael L. Nelson',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/959295176/mln-ad-100x130_normal.jpg',
#   'screen_name': 'phonedude_mln'}]

# %% [markdown]
# &nbsp;
#
# Now to determine to determine the the links between each `User` we can use [https://dev.twitter.com/rest/reference/get/friendships/show](https://dev.twitter.com/rest/reference/get/friendships/show).
#
# &nbsp;

# %%
f.api.ShowFriendship(source_user_id=uid, target_screen_name=users[5].screen_name)
# Out:
# {'relationship': {'source': {'all_replies': None,
#    'blocked_by': None,
#    'blocking': None,
#    'can_dm': True,
#    'followed_by': True,
#    'following': False,
#    'following_received': None,
#    'following_requested': None,
#    'id': 151901549,
#    'id_str': '151901549',
#    'live_following': False,
#    'marked_spam': None,
#    'muting': None,
#    'notifications_enabled': None,
#    'screen_name': 'phonedude_mln',
#    'want_retweets': None},
#   'target': {'followed_by': False,
#    'following': True,
#    'following_received': None,
#    'following_requested': None,
#    'id': 3158073120,
#    'id_str': '3158073120',
#    'screen_name': 'mixnode'}}}

# %% [markdown]
# &nbsp;
#
# Wrap this up in a function for use in a loop to get links.
#
# &nbsp;

# %%
import json

def friends(src_username, target_username):
    friendship = f.api.ShowFriendship(source_screen_name=src_username, \
                                      target_screen_name=target_username)

    following = friendship['relationship']['source']['following']
    followed = friendship['relationship']['source']['followed_by']        
    return (following, followed)

friends('phonedude_mln', users[10].screen_name)
# Out:
# (False, True)

# %% [markdown]
# &nbsp;
#
# Iterate over all users to generate the link data. Note that the `python-twitter` API is instantiated with `sleep_on_rate_limit=True` so that will be the cause if this takes a long time. Use of `itertools.combinations()` ensures no wasted calls eat up more time than needed.
#
# &nbsp;

# %%
from time import sleep
from itertools import combinations

for alice, bob in combinations(users, 2):
    friendship = friends(alice.screen_name, bob.screen_name) #?
    if friendship[0]: # alice following bob
        link = { 'source': alice.screen_name,
                 'target': bob.screen_name
               }
        data['links'].append(dict(link))
    if friendship[1]: # alice followed by bob
        link = { 'source': bob.screen_name,
                 'target': alice.screen_name
               }
        data['links'].append(dict(link))
    sleep(5.05) # for bug in python-twitter rate-limit timing (23 Mär 2017)

print(data)

# This data is precious time write it out now
data_file = 'graph_data.json'
with open(data_file, 'w') as outfile:
    json.dump(data, outfile)

# %%
with open(data_file, 'r') as infile:
    complete_data = json.load(infile)
